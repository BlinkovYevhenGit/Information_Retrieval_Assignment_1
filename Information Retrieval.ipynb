# %% [markdown]
# ## Data loading

# %%
import json
import re
import traceback 
from pyspark.sql import SparkSession
from elasticsearch import Elasticsearch, helpers
import requests, json, os, csv
from nltk.corpus import stopwords
import string
import unidecode
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
from flashtext import KeywordProcessor
import spacy
import pytextrank
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.stem import WordNetLemmatizer
import pprint

# %%
spark = SparkSession \
    .builder \
    .appName("ElasticSpark-1") \
    .config("spark.driver.extraClassPath", "/path/elasticsearch-hadoop-7.6.2/dist/elasticsearch-spark-20_2.11-7.6.2.jar") \
    .config("spark.es.port","9200") \
    .config("spark.driver.memory", "8G") \
    .config("spark.executor.memory", "12G") \
    .getOrCreate()

# %%
path = 'metadata.csv'
metadata_df = spark.read.csv(path, multiLine=True, header=True)
metadata_df.show(1)
# Out:
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |cord_uid|                 sha|source_x|               title|                 doi|   pmcid|pubmed_id|license|            abstract|publish_time|             authors|       journal|mag_id|who_covidence_id|arxiv_id|      pdf_json_files|      pmc_json_files|                 url|s2_id|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |ug7v899j|d1aafb70c066a2068...|     PMC|Clinical features...|10.1186/1471-2334...|PMC35282| 11472636|  no-cc|OBJECTIVE: This r...|  2001-07-04|Madani, Tariq A; ...|BMC Infect Dis|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# only showing top 1 row

# %%
metadata_df = metadata_df.select("*").limit(1000)

# %%
metadata_df.show(3)
# Out:
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |cord_uid|                 sha|source_x|               title|                 doi|   pmcid|pubmed_id|license|            abstract|publish_time|             authors|       journal|mag_id|who_covidence_id|arxiv_id|      pdf_json_files|      pmc_json_files|                 url|s2_id|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |ug7v899j|d1aafb70c066a2068...|     PMC|Clinical features...|10.1186/1471-2334...|PMC35282| 11472636|  no-cc|OBJECTIVE: This r...|  2001-07-04|Madani, Tariq A; ...|BMC Infect Dis|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# |02tnwd4m|6b0567729c2143a66...|     PMC|Nitric oxide: a p...|        10.1186/rr14|PMC59543| 11667967|  no-cc|Inflammatory dise...|  2000-08-15|Vliet, Albert van...|    Respir Res|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# |ejv2xln0|06ced00a5fc042159...|     PMC|Surfactant protei...|        10.1186/rr19|PMC59549| 11667972|  no-cc|Surfactant protei...|  2000-08-25|     Crouch, Erika C|    Respir Res|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# only showing top 3 rows

# %%
metadata_table = metadata_df.toPandas()

# %%
metadata_table
# Out:
#      cord_uid                                       sha source_x  \
# 0    ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1    02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2    ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3    2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4    9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# ..        ...                                       ...      ...
# 995  880nqc0f  ed2de3694f5580ea38f4adf24bd1c8b46862df1f      PMC
# 996  01b0vnnm  2a7c951e191425fd9fa5ac108f07a1f02eb75872      PMC
# 997  5b29wtim  854e623d1f875e4605b2ffd3f72599d063a56cc0      PMC
# 998  z65xxk1f  3695704554777889f8232a9ea086df70bf17ff58      PMC
# 999  iuglkdcp  5a054a570f409d5c2006369f19addc98d024b6c1      PMC
#
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                doi       pmcid pubmed_id license  \
# 0            10.1186/1471-2334-1-6    PMC35282  11472636   no-cc
# 1                     10.1186/rr14    PMC59543  11667967   no-cc
# 2                     10.1186/rr19    PMC59549  11667972   no-cc
# 3                     10.1186/rr44    PMC59574  11686871   no-cc
# 4                     10.1186/rr61    PMC59580  11686888   no-cc
# ..                             ...         ...       ...     ...
# 995            10.2147/copd.s33714  PMC3514010  23226013   no-cc
# 996          10.1186/2047-9158-1-9  PMC3514090  23210447   cc-by
# 997        10.1186/1746-6148-8-201  PMC3514206  23098237   cc-by
# 998   10.1371/journal.pone.0049778  PMC3514223  23226502   cc-by
# 999  10.1093/bioinformatics/bts575  PMC3516145  23044552   cc-by
#
#                                               abstract publish_time  \
# 0    OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1    Inflammatory diseases of the respiratory tract...   2000-08-15
# 2    Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4    Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# ..                                                 ...          ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...   2012-11-23
# 996  It has been nearly a century since the early d...   2012-04-24
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...   2012-10-25
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...   2012-12-04
# 999  Motivation: Laboratory RNA structure determina...   2012-12-01
#
#                                                authors  \
# 0                  Madani, Tariq A; Al-Ghamdi, Aisha A
# 1    Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                      Crouch, Erika C
# 3    Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4    Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# ..                                                 ...
# 995  Albert, Richard K; Connett, John; Curtis, Jeff...
# 996                    Luo, Xiao-Guang; Chen, Sheng-Di
# 997  Borriello, Giorgia; Lucibelli, Maria G; Pescia...
# 998  Burté, Florence; Brown, Biobele J.; Orimadegun...
# 999  Sperschneider, Jana; Datta, Amitava; Wise, Mic...
#
#                              journal mag_id who_covidence_id arxiv_id  \
# 0                     BMC Infect Dis   None             None     None
# 1                         Respir Res   None             None     None
# 2                         Respir Res   None             None     None
# 3                         Respir Res   None             None     None
# 4                         Respir Res   None             None     None
# ..                               ...    ...              ...      ...
# 995  Int J Chron Obstruct Pulmon Dis   None             None     None
# 996              Transl Neurodegener   None             None     None
# 997                      BMC Vet Res   None             None     None
# 998                         PLoS One   None             None     None
# 999                   Bioinformatics   None             None     None
#
#                                         pdf_json_files  \
# 0    document_parses/pdf_json/d1aafb70c066a2068b027...
# 1    document_parses/pdf_json/6b0567729c2143a66d737...
# 2    document_parses/pdf_json/06ced00a5fc04215949aa...
# 3    document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4    document_parses/pdf_json/5f48792a5fa08bed9f560...
# ..                                                 ...
# 995  document_parses/pdf_json/ed2de3694f5580ea38f4a...
# 996  document_parses/pdf_json/2a7c951e191425fd9fa5a...
# 997  document_parses/pdf_json/854e623d1f875e4605b2f...
# 998  document_parses/pdf_json/3695704554777889f8232...
# 999  document_parses/pdf_json/5a054a570f409d5c20063...
#
#                                    pmc_json_files  \
# 0      document_parses/pmc_json/PMC35282.xml.json
# 1      document_parses/pmc_json/PMC59543.xml.json
# 2      document_parses/pmc_json/PMC59549.xml.json
# 3      document_parses/pmc_json/PMC59574.xml.json
# 4      document_parses/pmc_json/PMC59580.xml.json
# ..                                            ...
# 995  document_parses/pmc_json/PMC3514010.xml.json
# 996  document_parses/pmc_json/PMC3514090.xml.json
# 997  document_parses/pmc_json/PMC3514206.xml.json
# 998  document_parses/pmc_json/PMC3514223.xml.json
# 999  document_parses/pmc_json/PMC3516145.xml.json
#
#                                                    url s2_id
# 0    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 1    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 2    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 3    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 4    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# ..                                                 ...   ...
# 995  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 996  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 997  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 998  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 999  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
#
# [1000 rows x 19 columns]

# %%
for i in range(0,len(metadata_table)):
    metadata_table.at[i,'publish_time']=str(metadata_table.at[i,'publish_time'])+" "
    metadata_table.at[i,'arxiv_id']=str(metadata_table.at[i,'arxiv_id'])+" "

# %%
metadata_table[:50]
# Out:
#     cord_uid                                       sha source_x  \
# 0   ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1   02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2   ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3   2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4   9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# 5   zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
# 6   5yhe786e  3bb07ea10432f7738413dff9816809cc90f03f99      PMC
# 7   8zchiykl  5806726a24dc91de3954001effbdffd7a82d54e2      PMC
# 8   8qnrcgnk  faaf1022ccfe93b032c5608097a53543ba24aedb      PMC
# 9   jg13scgo  5b44feca5d6ffaaeb66501fa84cc6dd44d06660a      PMC
# 10  5tkvsudh  9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9      PMC
# 11  6lvn10f4  14e0cac6e86d62859e6c9f1351ab67466d89e5b3      PMC
# 12  tvxpckxo  d09b79026117ec9faebba46a8d13aa9b23ec751e      PMC
# 13  mcuixluu  44102e3e69e70ad2a73e753133283334ce1f8736      PMC
# 14  6iu1dtyl  6e8517cb25ff228cb48da90a9c97d9c274dc8031      PMC
# 15  t35n7bk9  30a4842a2e257f725cc041e32fd682c495111a50      PMC
# 16  eiqypt0m  6a8ac55ea2a1fbd99deb683e24dd986e55e707b3      PMC
# 17  sgmk96vr  367af6bb9a8bbda02206506a819656bb6f14ce4c      PMC
# 18  di0fcy0j  4df2c6eecb985fcb20da3c5ed46e3b910c7077ab      PMC
# 19  4k8f7ou1  83b05e8afa6cbe7a68170ee155f7eca37c91d51f      PMC
# 20  wnnsmx60  025339bfce1cb8efa81c5accdabefe04dcdac9d2      PMC
# 21  gdsfkw1b  8d7400a2b387820cd391d7df8194642e50402a0c      PMC
# 22  yba7mdtb  f1d1b9694aa43c837d9b758cb2d45d8a24d293e3      PMC
# 23  bbvxu8op  867e1b0f6ca8757f2a32a625d99b23888ab40d49      PMC
# 24  e62cfqt7  b022e6ee1e7b9a0a822b1255c2fa12f81ddc52fd      PMC
# 25  4cvy9u28  f1bbb1b2e330c440acd6ff3d8a0f0d2e5adedd70      PMC
# 26  zowp10ts  03203ab50eb64271a9e825f94a1b1a6c46ea14b3      PMC
# 27  5dk231qs  a77badb297bf4927419481e660ea8f1806ed91b1      PMC
# 28  snqdma0s  93c6eef32a1a511ee989a259eab0e12174dc6859      PMC
# 29  1pq6dkl5  184aded923f0ac3cbdbcf74d2a5b42cda0f414c2      PMC
# 30  754nln40  40e41f0c52b39669dee24e37875d7a9fabc38636      PMC
# 31  p34ezktf  d77233dd9085c9c76787c84ee9a1e249424b283a      PMC
# 32  l3z27806  7d624acf891472c3452b1deb89e0dc44a40d0c94      PMC
# 33  yz2wbpuu  d706e82e2ebc8571e70654d1acf0ffd3969ab2d3      PMC
# 34  kvhoa2se  ada57a9f084a016deb20b6f83c442072e6e37955      PMC
# 35  cgl34ykt  6eeaffdb22b4e310867262d1891a1442769c7803      PMC
# 36  ajlctjeb  dff6195f5e24ebfa2fb4060142611b48021f673c      PMC
# 37  cl9gpt9w  95aec306660c1b7519e9f019d92cc3a8206481e4      PMC
# 38  t40ybhgb  d450fc8885843d48772df9a898552302f8c80b98      PMC
# 39  zwbc7nnn  ae19236936b05793ceac08ed5d58269c25486320      PMC
# 40  1r65yam5  0a1533470817bc5ef0d0d0af56386a96b505dc0d      PMC
# 41  qva0jt86  4ba79e54ecf81b30b56461a6aec2094eaf7b7f06      PMC
# 42  vw8xjo9t  c6202f96bd4b2aea699d5fbe867f311498dca3aa      PMC
# 43  bnnl700a  a78fd1b34372e1e54bf2a192d04aa36670cea307      PMC
# 44  m71xkuo9  c6bf372c094f035a514975c35a7f9c094abbe493      PMC
# 45  s64v656n  1cafb8587a42557c4f96ed28b2dc5717ff54d20d      PMC
# 46  oluq7v0h  ccc36b04ad5c71de61967624f7f739e868d7c0a5      PMC
# 47  tw6wusxe  c8213638a9602d46f2f7ff6ba62b0df69beb0001      PMC
# 48  58czem0j  a1b6c2b3b808e995697f94d9676d5d5c85180177      PMC
# 49  x7wg7e9s  e7f311d3c752063f75f28de85abd5f82eacab413      PMC
#
#                                                 title  \
# 0   Clinical features of culture-proven Mycoplasma...
# 1   Nitric oxide: a pro-inflammatory mediator in l...
# 2     Surfactant protein-D and pulmonary host defense
# 3                Role of endothelin-1 in lung disease
# 4   Gene expression in epithelial cells in respons...
# 5   Sequence requirements for RNA strand transfer ...
# 6   Debate: Transfusing to normal haemoglobin leve...
# 7   The 21st International Symposium on Intensive ...
# 8   Heme oxygenase-1 and carbon monoxide in pulmon...
# 9   Technical Description of RODS: A Real-time Pub...
# 10  Conservation of polyamine regulation by transl...
# 11  Heterogeneous nuclear ribonucleoprotein A1 reg...
# 12  A Method to Identify p62's UBA Domain Interact...
# 13  Vaccinia virus infection disrupts microtubule ...
# 14  The site of origin of the 1918 influenza pande...
# 15  Multi-faceted, multi-versatile microarray: sim...
# 16  Herpes simplex virus type 1 and normal protein...
# 17  Logistics of community smallpox control throug...
# 18  Protection of pulmonary epithelial cells from ...
# 19  Bioinformatic mapping of AlkB homology domains...
# 20  Managing emerging infectious diseases: Is a fe...
# 21  Protein secretion in Lactococcus lactis : an e...
# 22  Detection and characterization of horizontal t...
# 23  Comparisons of substitution, insertion and del...
# 24  A Gene Encoding Sialic-Acid-Specific 9-O-Acety...
# 25  The role of mast cells in the pathogenesis of ...
# 26  Recombination Every Day: Abundant Recombinatio...
# 27  Torsional restraint: a new twist on frameshift...
# 28  Correcting errors in synthetic DNA through con...
# 29  Towards standardization of RNA quality assessm...
# 30  Factors affecting translation at the programme...
# 31     Australian public health policy in 2003 – 2004
# 32  GIDEON: a comprehensive Web-based resource for...
# 33                           Globalization and Health
# 34  The 'polysemous' codon--a codon with multiple ...
# 35  A universal BMV-based RNA recombination system...
# 36  Neutrophil elastase, an acid-independent serin...
# 37  The influence of locked nucleic acid residues ...
# 38  Draft versus finished sequence data for DNA an...
# 39  An ontology for immune epitopes: application t...
# 40  Evaluation of potential reference genes in rea...
# 41  Relevance of human metapneumovirus in exacerba...
# 42  Bioethical Implications of Globalization: An I...
# 43  Public awareness of risk factors for cancer am...
# 44  Sequence specific visual detection of LAMP rea...
# 45  Injection drug use and HIV/AIDS in China: Revi...
# 46  Development of a humanized monoclonal antibody...
# 47  Local public health workers' perceptions towar...
# 48  On pandemics and the duty to care: whose duty?...
# 49  Epicatechins Purified from Green Tea (Camellia...
#
#                              doi       pmcid pubmed_id    license  \
# 0          10.1186/1471-2334-1-6    PMC35282  11472636      no-cc
# 1                   10.1186/rr14    PMC59543  11667967      no-cc
# 2                   10.1186/rr19    PMC59549  11667972      no-cc
# 3                   10.1186/rr44    PMC59574  11686871      no-cc
# 4                   10.1186/rr61    PMC59580  11686888      no-cc
# 5       10.1093/emboj/20.24.7220   PMC125340  11742998   green-oa
# 6                  10.1186/cc987   PMC137267  11299062      no-cc
# 7                 10.1186/cc1013   PMC137274  11353930      no-cc
# 8          10.1186/1465-9921-4-7   PMC193681  12964953      no-cc
# 9            10.1197/jamia.m1345   PMC212776  12807803  bronze-oa
# 10       10.1093/emboj/19.8.1907   PMC302018  10775274      no-cc
# 11      10.1093/emboj/19.17.4701   PMC302072  10970862   green-oa
# 12                 10.1251/bpo66   PMC302190  14702098      no-cc
# 13      10.1093/emboj/19.15.3932   PMC306617  10921875   green-oa
# 14         10.1186/1479-5876-2-3   PMC340389  14733617      no-cc
# 15        10.1186/1742-4690-1-11   PMC420498  15169556      no-cc
# 16                10.1186/cc2850   PMC468896  15153242      no-cc
# 17        10.1186/1471-2458-4-34   PMC520756  15298713      cc-by
# 18        10.1186/1465-9921-5-16   PMC521691  15450125      cc-by
# 19         10.1186/1471-2164-6-1   PMC544882  15627404      cc-by
# 20         10.1186/1743-8462-1-7   PMC544965  15679928      cc-by
# 21         10.1186/1475-2859-4-2   PMC545053  15631634      cc-by
# 22            10.1093/nar/gni004   PMC546175  15653627      no-cc
# 23            10.1093/nar/gni034   PMC549431  15722479      no-cc
# 24     10.1155/s1110724304307084   PMC551583  15292578      no-cc
# 25         10.1186/1471-230x-5-8   PMC554992  15745445      cc-by
# 26  10.1371/journal.pbio.0030089  PMC1054884  15737066      cc-by
# 27            10.1093/nar/gki329  PMC1072802  15800212      no-cc
# 28            10.1093/nar/gni053  PMC1072806  15800206      no-cc
# 29            10.1093/nar/gni054  PMC1072807  15800207      no-cc
# 30            10.1093/nar/gki521  PMC1083427  15843686      no-cc
# 31         10.1186/1743-8462-2-7  PMC1087471  15811192      cc-by
# 32        10.1186/1476-072x-4-10  PMC1090610  15847698      cc-by
# 33         10.1186/1744-8603-1-1  PMC1143779  15847699      cc-by
# 34       10.1093/emboj/16.5.1122  PMC1169711   9118950      no-cc
# 35            10.1093/nar/gni106  PMC1174899  16002784      no-cc
# 36        10.1186/1743-422x-2-48  PMC1180477  15927073      cc-by
# 37            10.1093/nar/gki789  PMC1201327  16155181      no-cc
# 38            10.1093/nar/gki896  PMC1266063  16243783      no-cc
# 39         10.1186/1745-7580-1-2  PMC1287064  16305755      cc-by
# 40        10.1186/1471-2199-6-21  PMC1314898  16293192      cc-by
# 41       10.1186/1465-9921-6-150  PMC1334186  16371156      cc-by
# 42  10.1371/journal.pmed.0030043  PMC1351155  16420098      cc-by
# 43         10.1186/1471-2458-6-2  PMC1351169  16403223      cc-by
# 44         10.1186/1472-6750-6-3  PMC1373654  16401354      cc-by
# 45         10.1186/1477-7517-3-4  PMC1402269  16451717      cc-by
# 46                10.1038/nm1240  PMC1458527  15852016      no-cc
# 47        10.1186/1471-2458-6-99  PMC1459127  16620372      cc-by
# 48         10.1186/1472-6939-7-5  PMC1459179  16626488      cc-by
# 49           10.1093/ecam/nel003  PMC1475929  16786054      no-cc
#
#                                              abstract  \
# 0   OBJECTIVE: This retrospective chart review des...
# 1   Inflammatory diseases of the respiratory tract...
# 2   Surfactant protein-D (SP-D) participates in th...
# 3   Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4   Respiratory syncytial virus (RSV) and pneumoni...
# 5   Nidovirus subgenomic mRNAs contain a leader se...
# 6   Recent evidence suggests that critically ill p...
# 7   The 21st International Symposium on Intensive ...
# 8   Heme oxygenase-1 (HO-1), an inducible stress p...
# 9   This report describes the design and implement...
# 10  Regulation of ornithine decarboxylase in verte...
# 11  Heterogeneous nuclear ribonucleoprotein (hnRNP...
# 12  The UBA domain is a conserved sequence motif a...
# 13  We examined the role of the microtubule cytosk...
# 14                                               None
# 15  There are hundreds of viruses that infect diff...
# 16  INTRODUCTION: The pathogenicity of late respir...
# 17  BACKGROUND: Previous smallpox ring vaccination...
# 18  BACKGROUND: Oxygen toxicity is a major cause o...
# 19  BACKGROUND: AlkB-like proteins are members of ...
# 20  In the 1980's and 1990's HIV/AIDS was the emer...
# 21  Lactococcus lactis, the model lactic acid bact...
# 22  Horizontal DNA transfer is an important factor...
# 23  Although oligonucleotide probes complementary ...
# 24  Using differential display RT-PCR, we identifi...
# 25  BACKGROUND: The biological basis of pain in ch...
# 26  Viral recombination can dramatically impact ev...
# 27  mRNA pseudoknots have a stimulatory function i...
# 28  Although efficient methods exist to assemble s...
# 29  While it is universally accepted that intact R...
# 30  The ratio between proteins P27 and replicase o...
# 31  In Australia, compared with other developed co...
# 32  GIDEON (Global Infectious Diseases and Epidemi...
# 33  This debut editorial of Globalization and Heal...
# 34  In some Candida species, the universal CUG leu...
# 35  At present, there is no doubt that RNA recombi...
# 36  BACKGROUND: Mammalian reoviruses naturally inf...
# 37  The influence of locked nucleic acid (LNA) res...
# 38  Sequencing pathogen genomes is costly, demandi...
# 39  BACKGROUND: Epitopes can be defined as the mol...
# 40  BACKGROUND: Salmonid fishes are among the most...
# 41  BACKGROUND AND METHODS: Human metapneumovirus ...
# 42  The BIG project looks at some of the ethical c...
# 43  BACKGROUND: The present study aimed to provide...
# 44  BACKGROUND: Development of a practical gene po...
# 45  "Illicit drug abuse and HIV/AIDS have increase...
# 46  Neutralization of West Nile virus (WNV) in viv...
# 47  "BACKGROUND: Current national preparedness pla...
# 48  BACKGROUND: As a number of commentators have n...
# 49  The anticancer potential of catechins derived ...
#
#                                          publish_time  \
# 0                                         2001-07-04
# 1                                         2000-08-15
# 2                                         2000-08-25
# 3                                         2001-02-22
# 4                                         2001-05-11
# 5                                         2001-12-17
# 6                                         2001-03-08
# 7                                         2001-05-02
# 8                                         2003-08-07
# 9                                         2003-09-01
# 10                                        2000-04-17
# 11                                        2000-09-01
# 12                                        2003-12-12
# 13                                        2000-08-01
# 14                                        2004-01-20
# 15                                        2004-05-26
# 16                                        2004-03-31
# 17                                        2004-08-06
# 18                                        2004-09-27
# 19                                        2005-01-03
# 20                                        2004-11-19
# 21                                        2005-01-04
# 22                                        2005-01-13
# 23                                        2005-02-18
# 24                                        2004-07-29
# 25                                        2005-03-03
# 26                                        2005-03-01
# 27                                        2005-03-30
# 28                                        2005-03-30
# 29                                        2005-03-30
# 30                                        2005-04-20
# 31                                        2005-04-06
# 32                                        2005-04-22
# 33                                        2005-04-22
# 34                                        1997-03-03
# 35                                        2005-07-07
# 36                                        2005-05-31
# 37                                        2005-09-09
# 38                                        2005-10-20
# 39                                        2005-09-20
# 40                                        2005-11-17
# 41                                        2005-12-21
# 42                                        2006-01-24
# 43                                        2006-01-10
# 44                                        2006-01-10
# 45   China has also become an increasingly importa...
# 46                                        2005-04-24
# 47   we surveyed 308 employees at three health dep...
# 48                                        2006-04-20
# 49                                        2006-04-25
#
#                                               authors  \
# 0                 Madani, Tariq A; Al-Ghamdi, Aisha A
# 1   Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                     Crouch, Erika C
# 3   Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4   Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# 5   Pasternak, Alexander O.; van den Born, Erwin; ...
# 6     Alvarez, Gonzalo; Hébert, Paul C; Szick, Sharyn
# 7                       Ball, Jonathan; Venn, Richard
# 8   Slebos, Dirk-Jan; Ryter, Stefan W; Choi, Augus...
# 9   Tsui, Fu-Chiang; Espino, Jeremy U.; Dato, Virg...
# 10  Ivanov, Ivaylo P.; Matsufuji, Senya; Murakami,...
# 11  Shi, Stephanie T.; Huang, Peiyong; Li, Hsin-Pa...
# 12  Pridgeon, Julia W.; Geetha, Thangiah; Wooten, ...
# 13  Ploubidou, Aspasia; Moreau, Violaine; Ashman, ...
# 14                                      Barry, John M
# 15                          Shieh, Biehuoy; Li, Ching
# 16  Verheij, Joanne; Groeneveld, AB Johan; Beishui...
# 17  Porco, Travis C; Holbrook, Karen A; Fernyak, S...
# 18  Kremer, Ted M; Rinne, Mikael L; Xu, Yi; Chen, ...
# 19                    Bratlie, Marit S; Drabløs, Finn
# 20                                   Howse, Genevieve
# 21  Le Loir, Yves; Azevedo, Vasco; Oliveira, Sergi...
# 22  Dufraigne, Christine; Fertil, Bernard; Lespina...
# 23  Karaman, Mazen W.; Groshen, Susan; Lee, Chi-Ch...
# 24  Zhu, Hu; Chang Chan, Hsiao; Zhou, Zuoming; Li,...
# 25  Hoogerwerf, Willemijntje A; Gondesen, Kelly; X...
# 26  Froissart, Remy; Roze, Denis; Uzest, Marilyne;...
# 27                Plant, Ewan P.; Dinman, Jonathan D.
# 28  Binkowski, Brock F.; Richmond, Kathryn E.; Kay...
# 29  Imbeaud, Sandrine; Graudens, Esther; Boulanger...
# 30              Mäkeläinen, Katri; Mäkinen, Kristiina
# 31                   Lin, Vivian; Robinson, Priscilla
# 32                                  Berger, Stephen A
# 33                                       Martin, Greg
# 34                    Suzuki, T; Ueda, T; Watanabe, K
# 35  Alejska, Magdalena; Figlerowicz, Magdalena; Ma...
# 36                 Golden, Joseph W; Schiff, Leslie A
# 37  Kierzek, Elzbieta; Ciesielska, Anna; Pasternak...
# 38  Gardner, Shea N.; Lam, Marisa W.; Smith, Jason...
# 39  Sathiamurthy, Muthuraman; Peters, Bjoern; Bui,...
# 40  Olsvik, Pål A; Lie, Kai K; Jordal, Ann-Elise O...
# 41  Rohde, G; Borg, I; Arinir, U; Kronsbein, J; Ra...
# 42  Novotny, Thomas E; Mordini, Emilio; Chadwick, ...
# 43  Inoue, Manami; Iwasaki, Motoki; Otani, Tetsuya...
# 44  Mori, Yasuyoshi; Hirano, Tsuyoshi; Notomi, Tsu...
# 45   and many share needles. IDU has contributed t...
# 46  Oliphant, Theodore; Engle, Michael; Nybakken, ...
# 47   on factors that may influence their ability a...
# 48  Ruderman, Carly; Tracy, C Shawn; Bensimon, Céc...
# 49  Ravindranath, Mepur H.; Saravanan, Thiruverkad...
#
#                                               journal  \
# 0                                      BMC Infect Dis
# 1                                          Respir Res
# 2                                          Respir Res
# 3                                          Respir Res
# 4                                          Respir Res
# 5                                    The EMBO Journal
# 6                                           Crit Care
# 7                                           Crit Care
# 8                                          Respir Res
# 9   Journal of the American Medical Informatics As...
# 10                                             EMBO J
# 11                                   The EMBO Journal
# 12                                 Biol Proced Online
# 13                                   The EMBO Journal
# 14                                       J Transl Med
# 15                                      Retrovirology
# 16                                          Crit Care
# 17                                  BMC Public Health
# 18                                         Respir Res
# 19                                       BMC Genomics
# 20                     Aust New Zealand Health Policy
# 21                                   Microb Cell Fact
# 22                                  Nucleic Acids Res
# 23                                  Nucleic Acids Res
# 24                                J Biomed Biotechnol
# 25                                  BMC Gastroenterol
# 26                                          PLoS Biol
# 27                                  Nucleic Acids Res
# 28                                  Nucleic Acids Res
# 29                                  Nucleic Acids Res
# 30                                  Nucleic Acids Res
# 31                     Aust New Zealand Health Policy
# 32                                 Int J Health Geogr
# 33                                      Global Health
# 34                                             EMBO J
# 35                                  Nucleic Acids Res
# 36                                            Virol J
# 37                                  Nucleic Acids Res
# 38                                  Nucleic Acids Res
# 39                                       Immunome Res
# 40                                       BMC Mol Biol
# 41                                         Respir Res
# 42                                           PLoS Med
# 43                                  BMC Public Health
# 44                                     BMC Biotechnol
# 45   which conflict with harm reduction policies o...
# 46                                            Nat Med
# 47   and perception of the importance of one's rol...
# 48                                     BMC Med Ethics
# 49                 Evid Based Complement Alternat Med
#
#                                                mag_id  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45   the central government has outlined a series ...
# 46                                               None
# 47                                         2006-04-18
# 48                                               None
# 49                                               None
#
#                                      who_covidence_id            arxiv_id  \
# 0                                                None               None
# 1                                                None               None
# 2                                                None               None
# 3                                                None               None
# 4                                                None               None
# 5                                                None               None
# 6                                                None               None
# 7                                                None               None
# 8                                                None               None
# 9                                                None               None
# 10                                               None               None
# 11                                               None               None
# 12                                               None               None
# 13                                               None               None
# 14                                               None               None
# 15                                               None               None
# 16                                               None               None
# 17                                               None               None
# 18                                               None               None
# 19                                               None               None
# 20                                               None               None
# 21                                               None               None
# 22                                               None               None
# 23                                               None               None
# 24                                               None               None
# 25                                               None               None
# 26                                               None               None
# 27                                               None               None
# 28                                               None               None
# 29                                               None               None
# 30                                               None               None
# 31                                               None               None
# 32                                               None               None
# 33                                               None               None
# 34                                               None               None
# 35                                               None               None
# 36                                               None               None
# 37                                               None               None
# 38                                               None               None
# 39                                               None               None
# 40                                               None               None
# 41                                               None               None
# 42                                               None               None
# 43                                               None               None
# 44                                               None               None
# 45   some local governments have not fully mobiliz...         2006-02-01
# 46                                               None               None
# 47  Balicer, Ran D; Omer, Saad B; Barnett, Daniel ...  BMC Public Health
# 48                                               None               None
# 49                                               None               None
#
#                                        pdf_json_files  \
# 0   document_parses/pdf_json/d1aafb70c066a2068b027...
# 1   document_parses/pdf_json/6b0567729c2143a66d737...
# 2   document_parses/pdf_json/06ced00a5fc04215949aa...
# 3   document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4   document_parses/pdf_json/5f48792a5fa08bed9f560...
# 5   document_parses/pdf_json/b2897e1277f56641193a6...
# 6   document_parses/pdf_json/3bb07ea10432f7738413d...
# 7   document_parses/pdf_json/5806726a24dc91de39540...
# 8   document_parses/pdf_json/faaf1022ccfe93b032c56...
# 9   document_parses/pdf_json/5b44feca5d6ffaaeb6650...
# 10  document_parses/pdf_json/9d4e3e8eb092d5ed282d0...
# 11  document_parses/pdf_json/14e0cac6e86d62859e6c9...
# 12  document_parses/pdf_json/d09b79026117ec9faebba...
# 13  document_parses/pdf_json/44102e3e69e70ad2a73e7...
# 14  document_parses/pdf_json/6e8517cb25ff228cb48da...
# 15  document_parses/pdf_json/30a4842a2e257f725cc04...
# 16  document_parses/pdf_json/6a8ac55ea2a1fbd99deb6...
# 17  document_parses/pdf_json/367af6bb9a8bbda022065...
# 18  document_parses/pdf_json/4df2c6eecb985fcb20da3...
# 19  document_parses/pdf_json/83b05e8afa6cbe7a68170...
# 20  document_parses/pdf_json/025339bfce1cb8efa81c5...
# 21  document_parses/pdf_json/8d7400a2b387820cd391d...
# 22  document_parses/pdf_json/f1d1b9694aa43c837d9b7...
# 23  document_parses/pdf_json/867e1b0f6ca8757f2a32a...
# 24  document_parses/pdf_json/b022e6ee1e7b9a0a822b1...
# 25  document_parses/pdf_json/f1bbb1b2e330c440acd6f...
# 26  document_parses/pdf_json/03203ab50eb64271a9e82...
# 27  document_parses/pdf_json/a77badb297bf492741948...
# 28  document_parses/pdf_json/93c6eef32a1a511ee989a...
# 29  document_parses/pdf_json/184aded923f0ac3cbdbcf...
# 30  document_parses/pdf_json/40e41f0c52b39669dee24...
# 31  document_parses/pdf_json/d77233dd9085c9c76787c...
# 32  document_parses/pdf_json/7d624acf891472c3452b1...
# 33  document_parses/pdf_json/d706e82e2ebc8571e7065...
# 34  document_parses/pdf_json/ada57a9f084a016deb20b...
# 35  document_parses/pdf_json/6eeaffdb22b4e31086726...
# 36  document_parses/pdf_json/dff6195f5e24ebfa2fb40...
# 37  document_parses/pdf_json/95aec306660c1b7519e9f...
# 38  document_parses/pdf_json/d450fc8885843d48772df...
# 39  document_parses/pdf_json/ae19236936b05793ceac0...
# 40  document_parses/pdf_json/0a1533470817bc5ef0d0d...
# 41  document_parses/pdf_json/4ba79e54ecf81b30b5646...
# 42  document_parses/pdf_json/c6202f96bd4b2aea699d5...
# 43  document_parses/pdf_json/a78fd1b34372e1e54bf2a...
# 44  document_parses/pdf_json/c6bf372c094f035a51497...
# 45  Qian, Han-Zhu; Schumacher, Joseph E; Chen, Hue...
# 46  document_parses/pdf_json/ccc36b04ad5c71de61967...
# 47                                               None
# 48  document_parses/pdf_json/a1b6c2b3b808e995697f9...
# 49  document_parses/pdf_json/e7f311d3c752063f75f28...
#
#                                   pmc_json_files  \
# 0     document_parses/pmc_json/PMC35282.xml.json
# 1     document_parses/pmc_json/PMC59543.xml.json
# 2     document_parses/pmc_json/PMC59549.xml.json
# 3     document_parses/pmc_json/PMC59574.xml.json
# 4     document_parses/pmc_json/PMC59580.xml.json
# 5    document_parses/pmc_json/PMC125340.xml.json
# 6    document_parses/pmc_json/PMC137267.xml.json
# 7    document_parses/pmc_json/PMC137274.xml.json
# 8    document_parses/pmc_json/PMC193681.xml.json
# 9    document_parses/pmc_json/PMC212776.xml.json
# 10   document_parses/pmc_json/PMC302018.xml.json
# 11   document_parses/pmc_json/PMC302072.xml.json
# 12   document_parses/pmc_json/PMC302190.xml.json
# 13   document_parses/pmc_json/PMC306617.xml.json
# 14   document_parses/pmc_json/PMC340389.xml.json
# 15   document_parses/pmc_json/PMC420498.xml.json
# 16   document_parses/pmc_json/PMC468896.xml.json
# 17   document_parses/pmc_json/PMC520756.xml.json
# 18   document_parses/pmc_json/PMC521691.xml.json
# 19   document_parses/pmc_json/PMC544882.xml.json
# 20   document_parses/pmc_json/PMC544965.xml.json
# 21   document_parses/pmc_json/PMC545053.xml.json
# 22   document_parses/pmc_json/PMC546175.xml.json
# 23   document_parses/pmc_json/PMC549431.xml.json
# 24   document_parses/pmc_json/PMC551583.xml.json
# 25   document_parses/pmc_json/PMC554992.xml.json
# 26  document_parses/pmc_json/PMC1054884.xml.json
# 27  document_parses/pmc_json/PMC1072802.xml.json
# 28  document_parses/pmc_json/PMC1072806.xml.json
# 29  document_parses/pmc_json/PMC1072807.xml.json
# 30  document_parses/pmc_json/PMC1083427.xml.json
# 31  document_parses/pmc_json/PMC1087471.xml.json
# 32  document_parses/pmc_json/PMC1090610.xml.json
# 33  document_parses/pmc_json/PMC1143779.xml.json
# 34                                          None
# 35  document_parses/pmc_json/PMC1174899.xml.json
# 36  document_parses/pmc_json/PMC1180477.xml.json
# 37  document_parses/pmc_json/PMC1201327.xml.json
# 38  document_parses/pmc_json/PMC1266063.xml.json
# 39  document_parses/pmc_json/PMC1287064.xml.json
# 40  document_parses/pmc_json/PMC1314898.xml.json
# 41  document_parses/pmc_json/PMC1334186.xml.json
# 42  document_parses/pmc_json/PMC1351155.xml.json
# 43  document_parses/pmc_json/PMC1351169.xml.json
# 44  document_parses/pmc_json/PMC1373654.xml.json
# 45                                 Harm Reduct J
# 46  document_parses/pmc_json/PMC1458527.xml.json
# 47                                          None
# 48  document_parses/pmc_json/PMC1459179.xml.json
# 49  document_parses/pmc_json/PMC1475929.xml.json
#
#                                                   url  \
# 0   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 2   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 3   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 4   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 5   http://europepmc.org/articles/pmc125340?pdf=re...
# 6   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 7   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 8   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 9   https://academic.oup.com/jamia/article-pdf/10/...
# 10  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 11  http://europepmc.org/articles/pmc302072?pdf=re...
# 12  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 13  http://europepmc.org/articles/pmc306617?pdf=re...
# 14  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 15  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 16  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 17  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 18  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 19  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 20  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 21  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 22  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 23  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 24  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 25  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 26  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 27  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 28  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 29  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 30  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 31  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 32  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 33  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 34  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 35  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 36  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 37  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 38  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 39  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 40  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 41  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 42  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 43  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 44  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 45                                               None
# 46  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 47                                               None
# 48  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 49  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
#
#                                                 s2_id
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47  document_parses/pdf_json/c8213638a9602d46f2f7f...
# 48                                               None
# 49                                               None

# %%
res = requests.get('http://localhost:9200')
print (res.content)
es = Elasticsearch([{'host': 'localhost', 'port': '9200'}])
# Out:
# b'{\n  "name" : "DESKTOP-K0D65LT",\n  "cluster_name" : "elasticsearch",\n  "cluster_uuid" : "P8VwA_sWSl-ykHakwwPzXQ",\n  "version" : {\n    "number" : "7.10.2",\n    "build_flavor" : "default",\n    "build_type" : "zip",\n    "build_hash" : "747e1cc71def077253878a59143c1f785afa92b9",\n    "build_date" : "2021-01-13T00:42:12.435326Z",\n    "build_snapshot" : false,\n    "lucene_version" : "8.7.0",\n    "minimum_wire_compatibility_version" : "6.8.0",\n    "minimum_index_compatibility_version" : "6.0.0-beta1"\n  },\n  "tagline" : "You Know, for Search"\n}\n'

# %%
mapping = {
    'settings':{
        'number_of_shards': 1, 
        'number_of_replicas': 1
    },
    'mappings': {
        'properties': {
            'cord_uid': {
                'index': 'false', 
                'type': 'text'
            },
            'sha': {
                'index': 'true', 
                'type': 'text'
            },
            'source_x': {
                'index': 'true', 
                'type': 'text'
            },
            'title': {
                'index': 'true',
                'type': 'text', 
                'similarity': 'BM25'
            },
            'doi': {
                'index': 'true', 
                'type': 'text'
            },
            'pmcid': {
                'index': 'true',
                'type': 'text'
            },
            'license': {
                'index': 'true',
                'type': 'text'
            },
            'abstract': {
                'index': 'true',
                'type': 'text',
                'similarity': 'BM25'
            },
            'publish_time': {
                'index': 'true', 
                'type': 'text'
            },
            'authors': {
                'index': 'true',
                'type': 'text'
            },
            'journal': {
                'index': 'true',
                'type': 'text'
            },
            'who_covidence_id': {
                'index': 'true',
                'type': 'text'
            },
            'arxiv_id': {
                'index': 'true',
                'type': 'text'
            },
            'pdf_json_files': {
                'index': 'true',
                'type': 'text'
            },
            'pmc_json_files': {
                'index': 'true', 
                'type': 'text'
            },
            'url': {
                'index': 'true',
                'type': 'text'
            },
            's2_id': {
                'index': 'true', 
                'type': 'text'
            }
         }
     }
}

# %%
if es.indices.exists("covid"):
    es.indices.delete("covid") 
    
es.indices.create(index="covid",body=mapping)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'covid'}

# %% [markdown]
# ## Sentence Splitting, Tokenization and Normalization

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in c:\conda\lib\site-packages (1.2.0)

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\conda\lib\site-packages (3.8.3)
# Requirement already satisfied: six>=1.5.0 in c:\conda\lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\conda\lib\site-packages (from gensim) (3.0.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\conda\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\conda\lib\site-packages (from gensim) (1.18.4)
# Requirement already satisfied: Cython==0.29.14 in c:\conda\lib\site-packages (from gensim) (0.29.14)
# Requirement already satisfied: requests in c:\conda\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2020.12.5)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)

# %%
class TextNormalizer:
    def __init__(self):
        self.punctuation_table = str.maketrans('','',string.punctuation)

    def normalize_text(self,text):
        if text==None:
            return None
        try: 
            normalized_sentences = []
            text = re.sub(' +',' ', text)
            text = unidecode.unidecode(text)
            text = text.lower()
            sentences = sent_tokenize(text)
        except:
            print("ERROR:", text)
            traceback.print_exc()
            return None
        
        for sentence in sentences:
            #remove punctuation
            sentence=re.sub("["+string.punctuation+"\d*]"," ",sentence)
            #strip leading/trailing whitespace
            sentence = sentence.strip()
            words = word_tokenize(sentence)
            new_sentence = ' '.join(words)
            normalized_sentences.append(new_sentence)
        return normalized_sentences

# %%
normaliser = TextNormalizer()

# %%
table_to_process=metadata_table[["title","abstract"]]

# %%
table_to_process
# Out:
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                               abstract
# 0    OBJECTIVE: This retrospective chart review des...
# 1    Inflammatory diseases of the respiratory tract...
# 2    Surfactant protein-D (SP-D) participates in th...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4    Respiratory syncytial virus (RSV) and pneumoni...
# ..                                                 ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...
# 996  It has been nearly a century since the early d...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...
# 999  Motivation: Laboratory RNA structure determina...
#
# [1000 rows x 2 columns]

# %%
table_to_process["title"]=table_to_process["title"].apply(lambda x: normaliser.normalize_text(x))
# Out:
# C:\Conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
table_to_process["abstract"]=table_to_process["abstract"].apply(lambda x: normaliser.normalize_text(x))
# Out:
# C:\Conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
table_to_process
# Out:
#                                                  title  \
# 0    [clinical features of culture proven mycoplasm...
# 1    [nitric oxide a pro inflammatory mediator in l...
# 2    [surfactant protein d and pulmonary host defense]
# 3                 [role of endothelin in lung disease]
# 4    [gene expression in epithelial cells in respon...
# ..                                                 ...
# 995  [mannose binding lectin deficiency and acute e...
# 996  [the changing phenotype of microglia from home...
# 997  [diversity of salmonella spp, serovars isolate...
# 998  [severe childhood malaria syndromes defined by...
# 999  [predicting pseudoknotted structures across tw...
#
#                                               abstract
# 0    [objective this retrospective chart review des...
# 1    [inflammatory diseases of the respiratory trac...
# 2    [surfactant protein d sp d participates in the...
# 3    [endothelin et is a amino acid peptide with di...
# 4    [respiratory syncytial virus rsv and pneumonia...
# ..                                                 ...
# 995  [background mannose binding lectin is a collec...
# 996  [it has been nearly a century since the early ...
# 997  [background salmonellosis in water buffalo bub...
# 998  [background cerebral malaria cm and severe mal...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Selecting key words

# %%
table_to_process
# Out:
#                                                  title  \
# 0    [clinical features of culture proven mycoplasm...
# 1    [nitric oxide a pro inflammatory mediator in l...
# 2    [surfactant protein d and pulmonary host defense]
# 3                 [role of endothelin in lung disease]
# 4    [gene expression in epithelial cells in respon...
# ..                                                 ...
# 995  [mannose binding lectin deficiency and acute e...
# 996  [the changing phenotype of microglia from home...
# 997  [diversity of salmonella spp, serovars isolate...
# 998  [severe childhood malaria syndromes defined by...
# 999  [predicting pseudoknotted structures across tw...
#
#                                               abstract
# 0    [objective this retrospective chart review des...
# 1    [inflammatory diseases of the respiratory trac...
# 2    [surfactant protein d sp d participates in the...
# 3    [endothelin et is a amino acid peptide with di...
# 4    [respiratory syncytial virus rsv and pneumonia...
# ..                                                 ...
# 995  [background mannose binding lectin is a collec...
# 996  [it has been nearly a century since the early ...
# 997  [background salmonellosis in water buffalo bub...
# 998  [background cerebral malaria cm and severe mal...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 2 columns]

# %%
table_to_process.loc[0,"abstract"]
# Out:
# ['objective this retrospective chart review describes the epidemiology and clinical features of patients with culture proven mycoplasma pneumoniae infections at king abdulaziz university hospital jeddah saudi arabia',
#  'methods patients with positive m pneumoniae cultures from respiratory specimens from january through december were identified through the microbiology records',
#  'charts of patients were reviewed',
#  'results patients were identified of whom required admission',
#  'most infections were community acquired',
#  'the infection affected all age groups but was most common in infants and pre school children',
#  'it occurred year round but was most common in the fall and spring',
#  'more than three quarters of patients had comorbidities',
#  'twenty four isolates were associated with pneumonia with upper respiratory tract infections and with bronchiolitis',
#  'cough fever and malaise were the most common symptoms and crepitations and wheezes were the most common signs',
#  'most patients with pneumonia had crepitations but only had bronchial breathing',
#  'immunocompromised patients were more likely than non immunocompromised patients to present with pneumonia versus p',
#  'of the patients with pneumonia had uneventful recovery recovered following some complications died because of m pneumoniae infection and died due to underlying comorbidities',
#  'the patients who died of m pneumoniae pneumonia had other comorbidities',
#  'conclusion our results were similar to published data except for the finding that infections were more common in infants and preschool children and that the mortality rate of pneumonia in patients with comorbidities was high']

# %%
s_top_words = set(stopwords.words('english'))

# %%
def remove_stop_words(text):
    if text==None:
        return
    for index,sentence in enumerate(text):
        sentence = sentence.split(" ")
        sentence = [word for word in sentence if word not in s_top_words and len(word)>2]
        sentence=" ".join(sentence)
        text[index]=sentence
    return text

# %%
table_to_process["title"]=table_to_process["title"].apply(lambda x: remove_stop_words(x))
# Out:
# C:\Conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
table_to_process["abstract"]=table_to_process["abstract"].apply(lambda x: remove_stop_words(x))
# Out:
# C:\Conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
table_to_process
# Out:
#                                                  title  \
# 0    [clinical features culture proven mycoplasma p...
# 1    [nitric oxide pro inflammatory mediator lung d...
# 2          [surfactant protein pulmonary host defense]
# 3                       [role endothelin lung disease]
# 4    [gene expression epithelial cells response pne...
# ..                                                 ...
# 995  [mannose binding lectin deficiency acute exace...
# 996  [changing phenotype microglia homeostasis dise...
# 997  [diversity salmonella spp, serovars isolated i...
# 998  [severe childhood malaria syndromes defined pl...
# 999  [predicting pseudoknotted structures across tw...
#
#                                               abstract
# 0    [objective retrospective chart review describe...
# 1    [inflammatory diseases respiratory tract commo...
# 2    [surfactant protein participates innate respon...
# 3    [endothelin amino acid peptide diverse biologi...
# 4    [respiratory syncytial virus rsv pneumonia vir...
# ..                                                 ...
# 995  [background mannose binding lectin collectin i...
# 996  [nearly century since early description microg...
# 997  [background salmonellosis water buffalo bubalu...
# 998  [background cerebral malaria severe malarial a...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 2 columns]

# %%
def get_words_corpus(table):
    words_corpus=[]
    for i in range(0, len(table)):
        row=table.loc[i]
        title_sentences = row["title"]
        abstract_sentences = row["abstract"]
        
        if title_sentences!=None:
            for i in range(0,len(title_sentences)):
                words_corpus.extend(title_sentences[i].split())
                
        if  abstract_sentences!=None:
            for i in range(0,len(abstract_sentences)):
                words_corpus.extend(abstract_sentences[i].split())
    return words_corpus

# %%
words_corpus=get_words_corpus(table_to_process)

# %%
len(words_corpus)
# Out:
# 133627

# %%
dist = nltk.FreqDist(words_corpus) #Creating a distribution of words' frequencies
grams=dist.most_common(1000) #Obtaining the most frequent words
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()

# %%
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(words_corpus)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(words_corpus)

# %%
print("Showing first",2000,"top-freqent words")
grams = pd.DataFrame(grams) #Building data table to represent selected by POS tagger word features 
grams.index = range(1,len(grams)+1)
grams.columns = ["Word", "Frequency"]
grams
# Out:
# Showing first 2000 top-freqent words
#             Word  Frequency
# 1          virus        985
# 2      influenza        945
# 3      infection        740
# 4          cells        711
# 5       patients        587
# ...          ...        ...
# 996         find         28
# 997        great         28
# 998     duration         28
# 999   initiation         28
# 1000       sirna         28
#
# [1000 rows x 2 columns]

# %%
bigramFinder.apply_freq_filter(7)

# %%
bigramPMITable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)

# %%
bigramPMITable
# Out:
#                         bigram        PMI
# 0               (rift, valley)  13.857927
# 1     (endoplasmic, reticulum)  13.705924
# 2    (bronchoalveolar, lavage)  13.327412
# 3           (coronary, artery)  13.327412
# 4      (vesicular, stomatitis)  13.327412
# ..                         ...        ...
# 863             (cells, cells)   1.665403
# 864           (disease, virus)   1.581372
# 865       (infection, results)   1.548103
# 866          (pandemic, virus)   1.325173
# 867         (infection, human)   1.179704
#
# [868 rows x 2 columns]

# %%
trigramFinder.apply_freq_filter(5)

# %%
trigramPMITable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['trigram','PMI']).sort_values(by='PMI', ascending=False)

# %%
len(trigramPMITable)
# Out:
# 224

# %%
trigramPMITable
# Out:
#                                       trigram        PMI
# 0                           (mov, avg, cusum)  29.411848
# 1            (cortex, magnoliae, officinalis)  29.148813
# 2            (systemic, lupus, erythematosus)  25.663387
# 3             (autoimmune, hemolytic, anemia)  25.052889
# 4    (methicillin, resistant, staphylococcus)  24.947180
# ..                                        ...        ...
# 219           (influenza, virus, replication)   9.049636
# 220            (influenza, virus, infections)   8.849042
# 221          (pandemic, influenza, infection)   8.659061
# 222              (response, influenza, virus)   8.532673
# 223                 (human, influenza, virus)   7.425360
#
# [224 rows x 2 columns]

# %%
bigramPMITable["bigram"]=bigramPMITable["bigram"].apply(lambda x: ' '.join(x))

# %%
bigramPMITable
# Out:
#                      bigram        PMI
# 0               rift valley  13.857927
# 1     endoplasmic reticulum  13.705924
# 2    bronchoalveolar lavage  13.327412
# 3           coronary artery  13.327412
# 4      vesicular stomatitis  13.327412
# ..                      ...        ...
# 863             cells cells   1.665403
# 864           disease virus   1.581372
# 865       infection results   1.548103
# 866          pandemic virus   1.325173
# 867         infection human   1.179704
#
# [868 rows x 2 columns]

# %%
trigramPMITable["trigram"]=trigramPMITable["trigram"].apply(lambda x: ' '.join(x))

# %%
trigramPMITable
# Out:
#                                   trigram        PMI
# 0                           mov avg cusum  29.411848
# 1            cortex magnoliae officinalis  29.148813
# 2            systemic lupus erythematosus  25.663387
# 3             autoimmune hemolytic anemia  25.052889
# 4    methicillin resistant staphylococcus  24.947180
# ..                                    ...        ...
# 219           influenza virus replication   9.049636
# 220            influenza virus infections   8.849042
# 221          pandemic influenza infection   8.659061
# 222              response influenza virus   8.532673
# 223                 human influenza virus   7.425360
#
# [224 rows x 2 columns]

# %%
gram_dict=grams.set_index('Word').T.to_dict('list')

# %%
bigramPMIDict=bigramPMITable.set_index('bigram').T.to_dict('list')

# %%
trigramPMIDict=trigramPMITable.set_index('trigram').T.to_dict('list')

# %%
# !pip install flashtext
# Out:
# Requirement already satisfied: flashtext in c:\conda\lib\site-packages (2.7)

# %%
keyword_processor = KeywordProcessor()

# %%
textrank_keyword_processor = KeywordProcessor()

# %%
gram_dict.update(bigramPMIDict)

# %%
bigramPMIDict.update(trigramPMIDict)

# %%
gram_dict
# Out:
# {'virus': [985],
#  'influenza': [945],
#  'infection': [740],
#  'cells': [711],
#  'patients': [587],
#  'human': [558],
#  'disease': [544],
#  'viral': [525],
#  'cell': [509],
#  'results': [494],
#  'protein': [484],
#  'study': [441],
#  'using': [437],
#  'data': [389],
#  'pandemic': [379],
#  'viruses': [376],
#  'also': [366],
#  'health': [365],
#  'associated': [351],
#  'may': [351],
#  'expression': [332],
#  'analysis': [322],
#  'used': [322],
#  'specific': [320],
#  'high': [317],
#  'based': [309],
#  'respiratory': [305],
#  'host': [299],
#  'proteins': [297],
#  'gene': [296],
#  'background': [294],
#  'rna': [288],
#  'methods': [287],
#  'two': [282],
#  'clinical': [280],
#  'time': [273],
#  'response': [259],
#  'new': [259],
#  'model': [259],
#  'hiv': [254],
#  'different': [249],
#  'activity': [247],
#  'role': [245],
#  'immune': [239],
#  'risk': [237],
#  'however': [236],
#  'one': [235],
#  'studies': [234],
#  'genes': [229],
#  'acute': [228],
#  'system': [228],
#  'non': [226],
#  'novel': [223],
#  'infected': [223],
#  'lung': [221],
#  'type': [221],
#  'treatment': [218],
#  'findings': [217],
#  'well': [214],
#  'important': [212],
#  'potential': [211],
#  'infections': [208],
#  'identified': [208],
#  'diseases': [207],
#  'mice': [205],
#  'cases': [204],
#  'binding': [203],
#  'development': [199],
#  'including': [198],
#  'among': [197],
#  'conclusions': [196],
#  'transmission': [195],
#  'found': [194],
#  'first': [193],
#  'vaccine': [193],
#  'factors': [192],
#  'infectious': [192],
#  'control': [190],
#  'showed': [185],
#  'number': [182],
#  'replication': [181],
#  'dna': [179],
#  'public': [178],
#  'severe': [178],
#  'case': [178],
#  'within': [177],
#  'related': [176],
#  'use': [175],
#  'mortality': [172],
#  'population': [172],
#  'increased': [170],
#  'levels': [169],
#  'method': [167],
#  'pcr': [166],
#  'responses': [164],
#  'induced': [161],
#  'ifn': [161],
#  'observed': [159],
#  'sequence': [157],
#  'genome': [157],
#  'species': [157],
#  'early': [157],
#  'present': [156],
#  'vaccination': [156],
#  'significantly': [155],
#  'significant': [155],
#  'molecular': [154],
#  'sequences': [153],
#  'children': [152],
#  'care': [152],
#  'highly': [152],
#  'detection': [149],
#  'cellular': [143],
#  'several': [142],
#  'low': [142],
#  'three': [141],
#  'could': [141],
#  'single': [141],
#  'reported': [140],
#  'major': [139],
#  'antibodies': [138],
#  'show': [137],
#  'provide': [137],
#  'compared': [137],
#  'review': [136],
#  'production': [136],
#  'effective': [136],
#  'spread': [136],
#  'antiviral': [136],
#  'developed': [135],
#  'positive': [134],
#  'structure': [134],
#  'multiple': [133],
#  'known': [132],
#  'samples': [132],
#  'receptor': [132],
#  'conclusion': [131],
#  'like': [131],
#  'acid': [130],
#  'information': [129],
#  'rate': [128],
#  'detected': [128],
#  'effects': [126],
#  'strains': [126],
#  'avian': [125],
#  'pneumonia': [124],
#  'epidemic': [124],
#  'research': [124],
#  'pathogens': [123],
#  'years': [122],
#  'genetic': [121],
#  'group': [121],
#  'surveillance': [120],
#  'large': [119],
#  'mediated': [119],
#  'higher': [119],
#  'models': [117],
#  'available': [117],
#  'mechanisms': [116],
#  'many': [116],
#  'effect': [116],
#  'anti': [115],
#  'level': [115],
#  'approach': [115],
#  'diagnosis': [115],
#  'following': [114],
#  'target': [114],
#  'functional': [114],
#  'due': [113],
#  'addition': [113],
#  'function': [112],
#  'suggest': [111],
#  'antibody': [111],
#  'activation': [111],
#  'vitro': [110],
#  'blood': [110],
#  'syndrome': [110],
#  'factor': [110],
#  'age': [108],
#  'evidence': [108],
#  'domain': [107],
#  'immunity': [107],
#  'primary': [106],
#  'confirmed': [106],
#  'site': [105],
#  'identify': [104],
#  'interactions': [104],
#  'changes': [104],
#  'common': [103],
#  'peptide': [103],
#  'inflammatory': [102],
#  'therapy': [102],
#  'days': [102],
#  'strain': [102],
#  'strategies': [101],
#  'involved': [101],
#  'thus': [101],
#  'dengue': [101],
#  'current': [100],
#  'critical': [100],
#  'assay': [100],
#  'report': [99],
#  'demonstrate': [99],
#  'evolution': [99],
#  'although': [98],
#  'cause': [98],
#  'various': [97],
#  'humans': [97],
#  'illness': [97],
#  'revealed': [97],
#  'groups': [95],
#  'complex': [95],
#  'dependent': [94],
#  'required': [93],
#  'patient': [92],
#  'individuals': [92],
#  'vaccines': [92],
#  'antigen': [92],
#  'principal': [92],
#  'membrane': [92],
#  'support': [91],
#  'bacterial': [91],
#  'vivo': [91],
#  'systems': [91],
#  'impact': [91],
#  'pulmonary': [90],
#  'drug': [90],
#  'ards': [89],
#  'pathogen': [89],
#  'range': [89],
#  'expressed': [88],
#  'mrna': [88],
#  'outbreak': [88],
#  'small': [88],
#  'without': [88],
#  'structural': [88],
#  'recent': [87],
#  'understanding': [87],
#  'laboratory': [87],
#  'outbreaks': [87],
#  'global': [87],
#  'therapeutic': [87],
#  'likely': [86],
#  'mechanism': [86],
#  'cancer': [86],
#  'seasonal': [86],
#  'process': [85],
#  'liver': [85],
#  'interaction': [85],
#  'recombinant': [85],
#  'hospital': [84],
#  'four': [84],
#  'surface': [84],
#  'chronic': [84],
#  'family': [84],
#  'demonstrated': [84],
#  'region': [84],
#  'methodology': [84],
#  'presence': [83],
#  'signaling': [83],
#  'serum': [83],
#  'cross': [83],
#  'similar': [82],
#  'respectively': [82],
#  'functions': [82],
#  'mouse': [82],
#  'wild': [82],
#  'reduced': [82],
#  'either': [80],
#  'strategy': [80],
#  'significance': [80],
#  'hbov': [80],
#  'conditions': [79],
#  'possible': [79],
#  'patterns': [78],
#  'ability': [78],
#  'limited': [78],
#  'association': [78],
#  'severity': [78],
#  'selection': [78],
#  'epithelial': [77],
#  'pathogenesis': [77],
#  'key': [77],
#  'ventilation': [77],
#  'tissue': [77],
#  'identification': [77],
#  'emerging': [77],
#  'china': [77],
#  'animals': [77],
#  'biological': [76],
#  'provides': [76],
#  'real': [76],
#  'caused': [76],
#  'pathogenic': [76],
#  'pathway': [76],
#  'assays': [76],
#  'tested': [76],
#  'challenge': [75],
#  'previously': [75],
#  'network': [75],
#  'evaluated': [75],
#  'countries': [75],
#  'epitope': [75],
#  'malaria': [75],
#  'lower': [74],
#  'recently': [74],
#  'regions': [74],
#  'less': [74],
#  'dynamics': [74],
#  'interferon': [74],
#  'total': [73],
#  'obtained': [73],
#  'derived': [72],
#  'might': [72],
#  'amino': [72],
#  'failure': [72],
#  'growth': [72],
#  'design': [72],
#  'rapid': [72],
#  'via': [72],
#  'protective': [72],
#  'approaches': [71],
#  'therefore': [71],
#  'essential': [71],
#  'stem': [71],
#  'community': [70],
#  'performed': [70],
#  'characterized': [70],
#  'quality': [70],
#  'antigens': [69],
#  'exposure': [69],
#  'result': [69],
#  'increase': [69],
#  'general': [69],
#  'measures': [69],
#  'describe': [69],
#  'conserved': [68],
#  'investigated': [68],
#  'resistance': [68],
#  'knowledge': [68],
#  'genotype': [68],
#  'phase': [68],
#  'peptides': [68],
#  'death': [68],
#  'intensive': [67],
#  'suggesting': [67],
#  'post': [67],
#  'enhanced': [67],
#  'screening': [67],
#  'entry': [67],
#  'plasma': [67],
#  'fever': [66],
#  'symptoms': [66],
#  'inflammation': [66],
#  'outcome': [66],
#  'overall': [66],
#  'hepatitis': [66],
#  'active': [66],
#  'efficient': [65],
#  'since': [65],
#  'characteristics': [65],
#  'codon': [65],
#  'useful': [65],
#  'neutralizing': [65],
#  'tumor': [65],
#  'injury': [64],
#  'inhibition': [64],
#  'pattern': [64],
#  'play': [63],
#  'negative': [63],
#  'conducted': [63],
#  'world': [63],
#  'ace': [63],
#  'affected': [62],
#  'regulation': [62],
#  'distress': [62],
#  'contact': [62],
#  'test': [62],
#  'furthermore': [62],
#  'need': [62],
#  'mutations': [62],
#  'year': [61],
#  'would': [61],
#  'work': [61],
#  'five': [61],
#  'controls': [61],
#  'mutation': [61],
#  'hcv': [61],
#  'properties': [60],
#  'efficacy': [60],
#  'survival': [60],
#  'individual': [60],
#  'length': [60],
#  'long': [60],
#  'future': [60],
#  'natural': [60],
#  'features': [59],
#  'transcription': [59],
#  'targets': [59],
#  'inhibitors': [59],
#  'initial': [59],
#  'pathways': [59],
#  'icu': [59],
#  'innate': [58],
#  'targeting': [58],
#  'areas': [58],
#  'microarray': [58],
#  'diagnostic': [58],
#  'form': [58],
#  'emergence': [58],
#  'regulated': [58],
#  'upon': [58],
#  'free': [58],
#  'receptors': [58],
#  'agents': [57],
#  'previous': [57],
#  'even': [57],
#  'translation': [57],
#  'populations': [57],
#  'whether': [57],
#  'set': [57],
#  'paper': [57],
#  'animal': [57],
#  'admission': [56],
#  'pre': [56],
#  'molecules': [56],
#  'cytokines': [56],
#  'recombination': [56],
#  'suggests': [56],
#  'sepsis': [56],
#  'shown': [56],
#  'contrast': [56],
#  'examined': [56],
#  'particles': [56],
#  'induction': [56],
#  'independent': [56],
#  'differences': [56],
#  'drugs': [56],
#  'investigate': [56],
#  'develop': [56],
#  'monoclonal': [56],
#  'management': [56],
#  'better': [56],
#  'swine': [56],
#  'often': [55],
#  'synthesis': [55],
#  'central': [55],
#  'base': [55],
#  'importance': [55],
#  'networks': [55],
#  'applied': [55],
#  'mechanical': [55],
#  'lead': [55],
#  'domains': [55],
#  'genomes': [55],
#  'delivery': [55],
#  'still': [55],
#  'healthy': [55],
#  'rates': [55],
#  'structures': [55],
#  'quantitative': [55],
#  'considered': [55],
#  'envelope': [55],
#  'collected': [55],
#  'period': [55],
#  'hrv': [55],
#  'distinct': [54],
#  'studied': [54],
#  'sensitivity': [54],
#  'distribution': [54],
#  'ratio': [54],
#  'flu': [54],
#  'combination': [54],
#  'indicate': [54],
#  'epitopes': [54],
#  'cytokine': [54],
#  'wide': [53],
#  'genomic': [53],
#  'numbers': [53],
#  'given': [53],
#  'life': [53],
#  'scale': [53],
#  'travel': [53],
#  'variants': [53],
#  'score': [53],
#  'denv': [53],
#  'formation': [52],
#  'containing': [52],
#  'protection': [52],
#  'regulatory': [52],
#  'included': [52],
#  'expressing': [52],
#  'analyzed': [52],
#  'testing': [52],
#  'phylogenetic': [52],
#  'determined': [52],
#  'isolates': [51],
#  'underlying': [51],
#  'medicine': [51],
#  'ribosomal': [51],
#  'relative': [51],
#  'decreased': [51],
#  'prediction': [51],
#  'incidence': [51],
#  'interventions': [51],
#  'greater': [51],
#  'tests': [51],
#  'prevalence': [51],
#  'ceacam': [51],
#  'defense': [50],
#  'able': [50],
#  'database': [50],
#  'analyses': [50],
#  'mammalian': [50],
#  'day': [50],
#  'assess': [50],
#  'improved': [50],
#  'enzyme': [50],
#  'reports': [50],
#  'size': [50],
#  'fusion': [50],
#  'adult': [50],
#  'across': [50],
#  'determine': [50],
#  'preparedness': [50],
#  'combined': [50],
#  'strong': [50],
#  'culture': [49],
#  'reaction': [49],
#  'end': [49],
#  'whereas': [49],
#  'described': [49],
#  'contacts': [49],
#  'provided': [49],
#  'experimental': [49],
#  'presented': [49],
#  'despite': [49],
#  'medical': [49],
#  'events': [49],
#  'little': [48],
#  'frequency': [48],
#  'defined': [48],
#  'residues': [48],
#  'simple': [48],
#  'chinese': [48],
#  'old': [48],
#  'induce': [48],
#  'systemic': [48],
#  'temperature': [48],
#  'activated': [48],
#  'macrophages': [47],
#  'isolated': [47],
#  'organ': [47],
#  'frameshifting': [47],
#  'vector': [47],
#  'prevention': [47],
#  'evaluate': [47],
#  'recognition': [47],
#  'particular': [47],
#  'developing': [47],
#  'people': [47],
#  'lipid': [46],
#  'established': [46],
#  'processes': [46],
#  'efficiency': [46],
#  'frequently': [46],
#  'introduction': [46],
#  'per': [46],
#  'local': [46],
#  'order': [46],
#  'mean': [46],
#  'dose': [46],
#  'epidemiological': [46],
#  'resistant': [46],
#  'tlr': [46],
#  'class': [46],
#  'alveolar': [45],
#  'polymerase': [45],
#  'improve': [45],
#  'currently': [45],
#  'reduction': [45],
#  'least': [45],
#  'pressure': [45],
#  'short': [45],
#  'whole': [45],
#  'markers': [45],
#  'additional': [45],
#  'term': [45],
#  'resulting': [45],
#  'needed': [45],
#  'remains': [45],
#  'tools': [45],
#  'distance': [45],
#  'activities': [44],
#  'specifically': [44],
#  'variation': [44],
#  'normal': [44],
#  'international': [44],
#  'roles': [44],
#  'tool': [44],
#  'measured': [44],
#  'social': [44],
#  'challenges': [44],
#  'nucleotide': [44],
#  'national': [44],
#  'discovery': [44],
#  'selected': [44],
#  'glycoprotein': [44],
#  'poultry': [44],
#  'alternative': [43],
#  'damage': [43],
#  'statistical': [43],
#  'loop': [43],
#  'throughput': [43],
#  'application': [43],
#  'open': [43],
#  'environmental': [43],
#  'specificity': [43],
#  'generated': [43],
#  'estimated': [43],
#  'cleavage': [43],
#  'epidemics': [43],
#  'together': [43],
#  'types': [43],
#  'vectors': [43],
#  'tnf': [43],
#  'kinase': [43],
#  'pregnancy': [43],
#  'basis': [42],
#  'influence': [42],
#  'discuss': [42],
#  'complete': [42],
#  'sites': [42],
#  'suggested': [42],
#  'worldwide': [42],
#  'isolation': [42],
#  'course': [42],
#  'capacity': [42],
#  'planning': [42],
#  'conventional': [42],
#  'stable': [42],
#  'measure': [42],
#  'much': [42],
#  'causes': [42],
#  'broad': [42],
#  'terminal': [42],
#  'represent': [42],
#  'sample': [42],
#  'amplification': [42],
#  'potentially': [42],
#  'yet': [42],
#  'evolutionary': [42],
#  'porcine': [42],
#  'season': [42],
#  'endothelial': [42],
#  'mabs': [42],
#  'standard': [41],
#  'multi': [41],
#  'exposed': [41],
#  'country': [41],
#  'usage': [41],
#  'proposed': [41],
#  'encoding': [41],
#  'fold': [41],
#  'designed': [41],
#  'second': [41],
#  'sequencing': [41],
#  'recognized': [41],
#  'part': [41],
#  'women': [41],
#  'secondary': [41],
#  'subtypes': [41],
#  'zoonotic': [41],
#  'uptake': [41],
#  'stress': [40],
#  'biology': [40],
#  'critically': [40],
#  'state': [40],
#  'resource': [40],
#  'intracellular': [40],
#  'direct': [40],
#  'signal': [40],
#  'diversity': [40],
#  'nucleic': [40],
#  'assessed': [40],
#  'increasing': [40],
#  'responsible': [40],
#  'treated': [40],
#  'optimal': [40],
#  'reviews': [40],
#  'workers': [40],
#  'inhibited': [40],
#  'existing': [40],
#  'framework': [40],
#  'parameters': [40],
#  'susceptibility': [40],
#  'correlation': [40],
#  'lack': [40],
#  'tract': [39],
#  'literature': [39],
#  'apoptosis': [39],
#  'array': [39],
#  'strongly': [39],
#  'ill': [39],
#  'controlled': [39],
#  'states': [39],
#  'techniques': [39],
#  'mutant': [39],
#  'tissues': [39],
#  'series': [39],
#  'correlated': [39],
#  'bacteria': [39],
#  'particularly': [39],
#  'field': [39],
#  'predicted': [39],
#  'self': [39],
#  'article': [39],
#  'change': [39],
#  'relevant': [39],
#  'adults': [39],
#  'occurred': [38],
#  'transfer': [38],
#  'unique': [38],
#  'detect': [38],
#  'include': [38],
#  'indicated': [38],
#  'produced': [38],
#  'acids': [38],
#  'sensitive': [38],
#  'full': [38],
#  'poor': [38],
#  'capable': [38],
#  'estimate': [38],
#  'evaluation': [38],
#  'brain': [38],
#  'circulating': [38],
#  'orf': [38],
#  'molecule': [38],
#  'healthcare': [38],
#  'bone': [38],
#  'consistent': [37],
#  'focus': [37],
#  'reactive': [37],
#  'newly': [37],
#  'unknown': [37],
#  'certain': [37],
#  'comparison': [37],
#  'followed': [37],
#  'protease': [37],
#  'directly': [37],
#  'modified': [37],
#  'linked': [37],
#  'live': [37],
#  'monitoring': [37],
#  'virulence': [37],
#  'unit': [37],
#  'gag': [37],
#  'elevated': [36],
#  'variety': [36],
#  'profiles': [36],
#  'tracing': [36],
#  'context': [36],
#  'absence': [36],
#  'accurate': [36],
#  'regarding': [36],
#  'source': [36],
#  'chemical': [36],
#  'understand': [36],
#  'reproduction': [36],
#  'value': [36],
#  'weeks': [36],
#  'acquired': [35],
#  'diverse': [35],
#  'contribute': [35],
#  'understood': [35],
#  'reduce': [35],
#  'implications': [35],
#  'spatial': [35],
#  'yeast': [35],
#  'core': [35],
#  'characterization': [35],
#  'plant': [35],
#  'occur': [35],
#  'aim': [35],
#  'finally': [35],
#  'leading': [35],
#  'especially': [35],
#  'families': [35],
#  'moreover': [35],
#  'neuraminidase': [35],
#  'subtype': [35],
#  'ali': [35],
#  'nss': [35],
#  'commonly': [34],
#  'generation': [34],
#  'outcomes': [34],
#  'transcriptional': [34],
#  'become': [34],
#  'technology': [34],
#  'prior': [34],
#  'secretion': [34],
#  'access': [34],
#  'prevent': [34],
#  'virions': [34],
#  'modeling': [34],
#  'six': [34],
#  'air': [34],
#  'point': [34],
#  'median': [34],
#  'predict': [34],
#  'making': [34],
#  'components': [34],
#  'immunization': [34],
#  'murine': [34],
#  'lps': [34],
#  'hemagglutinin': [34],
#  'mab': [34],
#  'specimens': [33],
#  'lines': [33],
#  'chain': [33],
#  'systematic': [33],
#  'received': [33],
#  'degradation': [33],
#  'aids': [33],
#  'rather': [33],
#  'rapidly': [33],
#  'widespread': [33],
#  'pseudoknot': [33],
#  'assessment': [33],
#  'propose': [33],
#  'history': [33],
#  'agent': [33],
#  'settings': [33],
#  'vsv': [33],
#  'fully': [33],
#  'located': [33],
#  'lethal': [33],
#  'hours': [33],
#  'liposomes': [33],
#  'oseltamivir': [33],
#  'niv': [33],
#  'objective': [32],
#  'epidemiology': [32],
#  'area': [32],
#  'forms': [32],
#  'plays': [32],
#  'administration': [32],
#  'requiring': [32],
#  'origin': [32],
#  'fatal': [32],
#  'index': [32],
#  'mass': [32],
#  'way': [32],
#  'coding': [32],
#  'relatively': [32],
#  'good': [32],
#  'values': [32],
#  'purified': [32],
#  'cost': [32],
#  'rrna': [32],
#  'survey': [32],
#  'morbidity': [32],
#  'main': [32],
#  'generally': [32],
#  'promising': [32],
#  'exhibited': [32],
#  'basic': [32],
#  'vaccinated': [32],
#  'hpai': [32],
#  'affect': [32],
#  'traditional': [32],
#  'processing': [32],
#  'complications': [31],
#  'lungs': [31],
#  'reverse': [31],
#  'require': [31],
#  'nuclear': [31],
#  'map': [31],
#  'reading': [31],
#  'smallpox': [31],
#  'made': [31],
#  'hybridization': [31],
#  'line': [31],
#  'asia': [31],
#  'material': [31],
#  'according': [31],
#  'successful': [31],
#  'reporting': [31],
#  'genotypes': [31],
#  'efforts': [31],
#  'alpha': [31],
#  'targeted': [31],
#  'complement': [31],
#  'affinity': [31],
#  'adaptive': [31],
#  'rabies': [31],
#  'taken': [31],
#  'stat': [31],
#  'transplant': [31],
#  'sign': [31],
#  'cultures': [30],
#  'strand': [30],
#  'step': [30],
#  'occurs': [30],
#  'emergency': [30],
#  'web': [30],
#  'represents': [30],
#  'escape': [30],
#  'compounds': [30],
#  'probes': [30],
#  'oligonucleotide': [30],
#  'reporter': [30],
#  'expected': [30],
#  'detailed': [30],
#  'status': [30],
#  'search': [30],
#  'candidates': [30],
#  'larger': [30],
#  'adaptation': [30],
#  'intervention': [30],
#  'performance': [30],
#  'antigenic': [30],
#  'dendritic': [30],
#  'investigation': [30],
#  'reactivity': [30],
#  'peripheral': [30],
#  'onset': [30],
#  'ili': [30],
#  'variant': [30],
#  'igg': [30],
#  'pdm': [30],
#  'hla': [30],
#  'hbv': [30],
#  'retrospective': [29],
#  'rsv': [29],
#  'manner': [29],
#  'another': [29],
#  'motif': [29],
#  'majority': [29],
#  'loss': [29],
#  'contains': [29],
#  'progression': [29],
#  'repair': [29],
#  'mapping': [29],
#  'mainly': [29],
#  'signals': [29],
#  'hypothesis': [29],
#  'directed': [29],
#  'towards': [29],
#  'effectiveness': [29],
#  'resulted': [29],
#  'neutralization': [29],
#  'presentation': [29],
#  'subunit': [29],
#  'position': [29],
#  'angiotensin': [29],
#  'component': [29],
#  'generate': [29],
#  'months': [29],
#  'imaging': [29],
#  'reproductive': [29],
#  'deaths': [29],
#  'extensive': [29],
#  'parasite': [29],
#  'peak': [29],
#  'africa': [29],
#  'metabolic': [29],
#  'rvfv': [29],
#  'versus': [28],
#  'deficient': [28],
#  'remain': [28],
#  'differential': [28],
#  'comprehensive': [28],
#  'mutants': [28],
#  'trial': [28],
#  'concentrations': [28],
#  'interest': [28],
#  'hospitals': [28],
#  'users': [28],
#  'requires': [28],
#  'rnas': [28],
#  'successfully': [28],
#  'insights': [28],
#  'subsequent': [28],
#  'eight': [28],
#  'coupled': [28],
#  'profile': [28],
#  'allow': [28],
#  'appropriate': [28],
#  'pathology': [28],
#  'computational': [28],
#  'cohort': [28],
#  'european': [28],
#  'hand': [28],
#  'version': [28],
#  'find': [28],
#  'great': [28],
#  'duration': [28],
#  'initiation': [28],
#  'sirna': [28],
#  ...}

# %%
text_rank_key_words=dict()

# %%
def get_keywords_by_textrank(sentences):
    if sentences==None:
        return None
    keywords=dict()
    nlp = spacy.load('en_core_web_sm')
    nlp.add_pipe("textrank", last=True)
    doc = nlp(" ".join(sentences))

    # examine the top-ranked phrases in the document

    for p in doc._.phrases:
        if p.rank>=0.05:
            keywords[p.text]=p.rank
    #         print("{:.4f} {:5d}  {}".format(p.rank, p.count, p.text))
    #         print(p.text)
    return keywords

# %%
 for i in range(0, len(table_to_process)):
        sentences=table_to_process.loc[i,"abstract"]
        if sentences!=None:
            keywords=get_keywords_by_textrank(sentences)
            if keywords!=None:
                text_rank_key_words.update(keywords)
                print("Text",i,"- Done")
# Out:
# Text 0 - Done
# Text 1 - Done
# Text 2 - Done
# Text 3 - Done
# Text 4 - Done
# Text 5 - Done
# Text 6 - Done
# Text 7 - Done
# Text 8 - Done
# Text 9 - Done
# Text 10 - Done
# Text 11 - Done
# Text 12 - Done
# Text 13 - Done
# Text 15 - Done
# Text 16 - Done
# Text 17 - Done
# Text 18 - Done
# Text 19 - Done
# Text 20 - Done
# Text 21 - Done
# Text 22 - Done
# Text 23 - Done
# Text 24 - Done
# Text 25 - Done
# Text 26 - Done
# Text 27 - Done
# Text 28 - Done
# Text 29 - Done
# Text 30 - Done
# Text 31 - Done
# Text 32 - Done
# Text 33 - Done
# Text 34 - Done
# Text 35 - Done
# Text 36 - Done
# Text 37 - Done
# Text 38 - Done
# Text 39 - Done
# Text 40 - Done
# Text 41 - Done
# Text 42 - Done
# Text 43 - Done
# Text 44 - Done
# Text 45 - Done
# Text 46 - Done
# Text 47 - Done
# Text 48 - Done
# Text 49 - Done
# Text 50 - Done
# Text 57 - Done
# Text 58 - Done
# Text 59 - Done
# Text 60 - Done
# Text 61 - Done
# Text 62 - Done
# Text 64 - Done
# Text 65 - Done
# Text 66 - Done
# Text 67 - Done
# Text 68 - Done
# Text 69 - Done
# Text 70 - Done
# Text 71 - Done
# Text 72 - Done
# Text 73 - Done
# Text 74 - Done
# Text 75 - Done
# Text 76 - Done
# Text 77 - Done
# Text 78 - Done
# Text 79 - Done
# Text 80 - Done
# Text 81 - Done
# Text 82 - Done
# Text 83 - Done
# Text 84 - Done
# Text 85 - Done
# Text 86 - Done
# Text 87 - Done
# Text 88 - Done
# Text 89 - Done
# Text 90 - Done
# Text 91 - Done
# Text 92 - Done
# Text 93 - Done
# Text 94 - Done
# Text 95 - Done
# Text 96 - Done
# Text 97 - Done
# Text 98 - Done
# Text 99 - Done
# Text 100 - Done
# Text 101 - Done
# Text 102 - Done
# Text 103 - Done
# Text 104 - Done
# Text 105 - Done
# Text 106 - Done
# Text 107 - Done
# Text 108 - Done
# Text 109 - Done
# Text 110 - Done
# Text 111 - Done
# Text 112 - Done
# Text 113 - Done
# Text 114 - Done
# Text 115 - Done
# Text 116 - Done
# Text 117 - Done
# Text 118 - Done
# Text 119 - Done
# Text 120 - Done
# Text 121 - Done
# Text 122 - Done
# Text 123 - Done
# Text 124 - Done
# Text 125 - Done
# Text 126 - Done
# Text 127 - Done
# Text 128 - Done
# Text 129 - Done
# Text 130 - Done
# Text 131 - Done
# Text 132 - Done
# Text 133 - Done
# Text 134 - Done
# Text 135 - Done
# Text 136 - Done
# Text 137 - Done
# Text 138 - Done
# Text 139 - Done
# Text 140 - Done
# Text 141 - Done
# Text 142 - Done
# Text 143 - Done
# Text 144 - Done
# Text 145 - Done
# Text 146 - Done
# Text 147 - Done
# Text 148 - Done
# Text 149 - Done
# Text 150 - Done
# Text 151 - Done
# Text 152 - Done
# Text 153 - Done
# Text 154 - Done
# Text 155 - Done
# Text 156 - Done
# Text 157 - Done
# Text 158 - Done
# Text 159 - Done
# Text 160 - Done
# Text 161 - Done
# Text 162 - Done
# Text 163 - Done
# Text 164 - Done
# Text 165 - Done
# Text 166 - Done
# Text 167 - Done
# Text 168 - Done
# Text 169 - Done
# Text 170 - Done
# Text 171 - Done
# Text 172 - Done
# Text 173 - Done
# Text 174 - Done
# Text 175 - Done
# Text 176 - Done
# Text 177 - Done
# Text 178 - Done
# Text 179 - Done
# Text 180 - Done
# Text 181 - Done
# Text 182 - Done
# Text 183 - Done
# Text 184 - Done
# Text 185 - Done
# Text 186 - Done
# Text 187 - Done
# Text 188 - Done
# Text 189 - Done
# Text 190 - Done
# Text 191 - Done
# Text 192 - Done
# Text 194 - Done
# Text 195 - Done
# Text 196 - Done
# Text 197 - Done
# Text 198 - Done
# Text 199 - Done
# Text 200 - Done
# Text 201 - Done
# Text 202 - Done
# Text 203 - Done
# Text 204 - Done
# Text 205 - Done
# Text 206 - Done
# Text 208 - Done
# Text 209 - Done
# Text 210 - Done
# Text 211 - Done
# Text 212 - Done
# Text 213 - Done
# Text 214 - Done
# Text 215 - Done
# Text 216 - Done
# Text 217 - Done
# Text 219 - Done
# Text 220 - Done
# Text 221 - Done
# Text 222 - Done
# Text 223 - Done
# Text 224 - Done
# Text 225 - Done
# Text 226 - Done
# Text 227 - Done
# Text 228 - Done
# Text 229 - Done
# Text 230 - Done
# Text 231 - Done
# Text 232 - Done
# Text 233 - Done
# Text 236 - Done
# Text 237 - Done
# Text 238 - Done
# Text 239 - Done
# Text 240 - Done
# Text 241 - Done
# Text 242 - Done
# Text 243 - Done
# Text 244 - Done
# Text 245 - Done
# Text 246 - Done
# Text 247 - Done
# Text 248 - Done
# Text 249 - Done
# Text 250 - Done
# Text 251 - Done
# Text 252 - Done
# Text 253 - Done
# Text 254 - Done
# Text 255 - Done
# Text 256 - Done
# Text 257 - Done
# Text 258 - Done
# Text 259 - Done
# Text 261 - Done
# Text 262 - Done
# Text 263 - Done
# Text 264 - Done
# Text 265 - Done
# Text 266 - Done
# Text 267 - Done
# Text 268 - Done
# Text 269 - Done
# Text 270 - Done
# Text 271 - Done
# Text 272 - Done
# Text 273 - Done
# Text 274 - Done
# Text 275 - Done
# Text 276 - Done
# Text 277 - Done
# Text 278 - Done
# Text 279 - Done
# Text 280 - Done
# Text 281 - Done
# Text 282 - Done
# Text 283 - Done
# Text 284 - Done
# Text 285 - Done
# Text 286 - Done
# Text 287 - Done
# Text 288 - Done
# Text 289 - Done
# Text 290 - Done
# Text 291 - Done
# Text 292 - Done
# Text 293 - Done
# Text 294 - Done
# Text 295 - Done
# Text 296 - Done
# Text 297 - Done
# Text 298 - Done
# Text 299 - Done
# Text 300 - Done
# Text 301 - Done
# Text 302 - Done
# Text 303 - Done
# Text 305 - Done
# Text 306 - Done
# Text 308 - Done
# Text 309 - Done
# Text 310 - Done
# Text 311 - Done
# Text 312 - Done
# Text 313 - Done
# Text 314 - Done
# Text 315 - Done
# Text 316 - Done
# Text 317 - Done
# Text 318 - Done
# Text 320 - Done
# Text 321 - Done
# Text 322 - Done
# Text 323 - Done
# Text 324 - Done
# Text 325 - Done
# Text 326 - Done
# Text 327 - Done
# Text 328 - Done
# Text 329 - Done
# Text 330 - Done
# Text 331 - Done
# Text 332 - Done
# Text 333 - Done
# Text 334 - Done
# Text 335 - Done
# Text 336 - Done
# Text 337 - Done
# Text 338 - Done
# Text 339 - Done
# Text 341 - Done
# Text 342 - Done
# Text 343 - Done
# Text 344 - Done
# Text 345 - Done
# Text 346 - Done
# Text 347 - Done
# Text 348 - Done
# Text 349 - Done
# Text 350 - Done
# Text 351 - Done
# Text 352 - Done
# Text 353 - Done
# Text 354 - Done
# Text 355 - Done
# Text 356 - Done
# Text 357 - Done
# Text 358 - Done
# Text 359 - Done
# Text 360 - Done
# Text 361 - Done
# Text 362 - Done
# Text 363 - Done
# Text 364 - Done
# Text 365 - Done
# Text 366 - Done
# Text 367 - Done
# Text 368 - Done
# Text 369 - Done
# Text 370 - Done
# Text 371 - Done
# Text 372 - Done
# Text 373 - Done
# Text 374 - Done
# Text 376 - Done
# Text 377 - Done
# Text 378 - Done
# Text 379 - Done
# Text 380 - Done
# Text 381 - Done
# Text 382 - Done
# Text 383 - Done
# Text 384 - Done
# Text 385 - Done
# Text 386 - Done
# Text 387 - Done
# Text 388 - Done
# Text 389 - Done
# Text 390 - Done
# Text 391 - Done
# Text 392 - Done
# Text 393 - Done
# Text 394 - Done
# Text 396 - Done
# Text 397 - Done
# Text 398 - Done
# Text 399 - Done
# Text 400 - Done
# Text 401 - Done
# Text 402 - Done
# Text 403 - Done
# Text 404 - Done
# Text 405 - Done
# Text 406 - Done
# Text 407 - Done
# Text 408 - Done
# Text 409 - Done
# Text 410 - Done
# Text 411 - Done
# Text 412 - Done
# Text 413 - Done
# Text 414 - Done
# Text 415 - Done
# Text 416 - Done
# Text 417 - Done
# Text 418 - Done
# Text 419 - Done
# Text 421 - Done
# Text 422 - Done
# Text 423 - Done
# Text 424 - Done
# Text 425 - Done
# Text 426 - Done
# Text 427 - Done
# Text 428 - Done
# Text 429 - Done
# Text 430 - Done
# Text 431 - Done
# Text 432 - Done
# Text 433 - Done
# Text 434 - Done
# Text 435 - Done
# Text 436 - Done
# Text 437 - Done
# Text 438 - Done
# Text 439 - Done
# Text 440 - Done
# Text 441 - Done
# Text 442 - Done
# Text 443 - Done
# Text 444 - Done
# Text 445 - Done
# Text 446 - Done
# Text 447 - Done
# Text 448 - Done
# Text 449 - Done
# Text 450 - Done
# Text 451 - Done
# Text 452 - Done
# Text 453 - Done
# Text 454 - Done
# Text 455 - Done
# Text 456 - Done
# Text 457 - Done
# Text 458 - Done
# Text 459 - Done
# Text 460 - Done
# Text 461 - Done
# Text 462 - Done
# Text 463 - Done
# Text 464 - Done
# Text 465 - Done
# Text 466 - Done
# Text 467 - Done
# Text 468 - Done
# Text 469 - Done
# Text 470 - Done
# Text 471 - Done
# Text 472 - Done
# Text 473 - Done
# Text 474 - Done
# Text 475 - Done
# Text 476 - Done
# Text 477 - Done
# Text 478 - Done
# Text 479 - Done
# Text 480 - Done
# Text 481 - Done
# Text 482 - Done
# Text 483 - Done
# Text 484 - Done
# Text 485 - Done
# Text 486 - Done
# Text 488 - Done
# Text 489 - Done
# Text 490 - Done
# Text 491 - Done
# Text 492 - Done
# Text 493 - Done
# Text 494 - Done
# Text 495 - Done
# Text 496 - Done
# Text 497 - Done
# Text 498 - Done
# Text 499 - Done
# Text 500 - Done
# Text 501 - Done
# Text 502 - Done
# Text 503 - Done
# Text 504 - Done
# Text 505 - Done
# Text 506 - Done
# Text 507 - Done
# Text 508 - Done
# Text 509 - Done
# Text 510 - Done
# Text 511 - Done
# Text 512 - Done
# Text 513 - Done
# Text 514 - Done
# Text 515 - Done
# Text 516 - Done
# Text 517 - Done
# Text 518 - Done
# Text 519 - Done
# Text 520 - Done
# Text 521 - Done
# Text 523 - Done
# Text 524 - Done
# Text 525 - Done
# Text 526 - Done
# Text 527 - Done
# Text 528 - Done
# Text 529 - Done
# Text 530 - Done
# Text 531 - Done
# Text 532 - Done
# Text 533 - Done
# Text 534 - Done
# Text 535 - Done
# Text 536 - Done
# Text 537 - Done
# Text 538 - Done
# Text 539 - Done
# Text 540 - Done
# Text 541 - Done
# Text 542 - Done
# Text 543 - Done
# Text 544 - Done
# Text 545 - Done
# Text 546 - Done
# Text 547 - Done
# Text 548 - Done
# Text 549 - Done
# Text 550 - Done
# Text 551 - Done
# Text 552 - Done
# Text 553 - Done
# Text 554 - Done
# Text 555 - Done
# Text 556 - Done
# Text 557 - Done
# Text 558 - Done
# Text 559 - Done
# Text 560 - Done
# Text 561 - Done
# Text 562 - Done
# Text 563 - Done
# Text 564 - Done
# Text 566 - Done
# Text 567 - Done
# Text 568 - Done
# Text 569 - Done
# Text 571 - Done
# Text 572 - Done
# Text 573 - Done
# Text 574 - Done
# Text 575 - Done
# Text 576 - Done
# Text 577 - Done
# Text 578 - Done
# Text 579 - Done
# Text 580 - Done
# Text 581 - Done
# Text 582 - Done
# Text 583 - Done
# Text 584 - Done
# Text 585 - Done
# Text 586 - Done
# Text 587 - Done
# Text 588 - Done
# Text 589 - Done
# Text 590 - Done
# Text 591 - Done
# Text 592 - Done
# Text 593 - Done
# Text 594 - Done
# Text 595 - Done
# Text 596 - Done
# Text 597 - Done
# Text 598 - Done
# Text 599 - Done
# Text 600 - Done
# Text 601 - Done
# Text 602 - Done
# Text 603 - Done
# Text 604 - Done
# Text 605 - Done
# Text 606 - Done
# Text 607 - Done
# Text 608 - Done
# Text 609 - Done
# Text 610 - Done
# Text 611 - Done
# Text 612 - Done
# Text 613 - Done
# Text 614 - Done
# Text 615 - Done
# Text 617 - Done
# Text 618 - Done
# Text 619 - Done
# Text 620 - Done
# Text 621 - Done
# Text 622 - Done
# Text 623 - Done
# Text 624 - Done
# Text 625 - Done
# Text 626 - Done
# Text 627 - Done
# Text 628 - Done
# Text 629 - Done
# Text 630 - Done
# Text 631 - Done
# Text 632 - Done
# Text 633 - Done
# Text 634 - Done
# Text 635 - Done
# Text 636 - Done
# Text 637 - Done
# Text 638 - Done
# Text 639 - Done
# Text 640 - Done
# Text 641 - Done
# Text 642 - Done
# Text 643 - Done
# Text 644 - Done
# Text 645 - Done
# Text 646 - Done
# Text 647 - Done
# Text 648 - Done
# Text 649 - Done
# Text 650 - Done
# Text 651 - Done
# Text 652 - Done
# Text 653 - Done
# Text 654 - Done
# Text 655 - Done
# Text 656 - Done
# Text 657 - Done
# Text 658 - Done
# Text 659 - Done
# Text 660 - Done
# Text 661 - Done
# Text 662 - Done
# Text 663 - Done
# Text 664 - Done
# Text 665 - Done
# Text 666 - Done
# Text 667 - Done
# Text 668 - Done
# Text 669 - Done
# Text 670 - Done
# Text 672 - Done
# Text 674 - Done
# Text 675 - Done
# Text 676 - Done
# Text 677 - Done
# Text 678 - Done
# Text 679 - Done
# Text 680 - Done
# Text 681 - Done
# Text 682 - Done
# Text 683 - Done
# Text 684 - Done
# Text 685 - Done
# Text 686 - Done
# Text 687 - Done
# Text 688 - Done
# Text 689 - Done
# Text 690 - Done
# Text 691 - Done
# Text 692 - Done
# Text 693 - Done
# Text 694 - Done
# Text 695 - Done
# Text 696 - Done
# Text 697 - Done
# Text 698 - Done
# Text 699 - Done
# Text 700 - Done
# Text 701 - Done
# Text 702 - Done
# Text 703 - Done
# Text 704 - Done
# Text 705 - Done
# Text 706 - Done
# Text 707 - Done
# Text 708 - Done
# Text 709 - Done
# Text 710 - Done
# Text 711 - Done
# Text 712 - Done
# Text 713 - Done
# Text 714 - Done
# Text 715 - Done
# Text 716 - Done
# Text 717 - Done
# Text 718 - Done
# Text 719 - Done
# Text 720 - Done
# Text 721 - Done
# Text 722 - Done
# Text 723 - Done
# Text 724 - Done
# Text 725 - Done
# Text 726 - Done
# Text 727 - Done
# Text 728 - Done
# Text 729 - Done
# Text 730 - Done
# Text 731 - Done
# Text 733 - Done
# Text 734 - Done
# Text 735 - Done
# Text 736 - Done
# Text 737 - Done
# Text 738 - Done
# Text 739 - Done
# Text 740 - Done
# Text 741 - Done
# Text 742 - Done
# Text 743 - Done
# Text 744 - Done
# Text 745 - Done
# Text 746 - Done
# Text 747 - Done
# Text 748 - Done
# Text 749 - Done
# Text 750 - Done
# Text 751 - Done
# Text 752 - Done
# Text 753 - Done
# Text 754 - Done
# Text 755 - Done
# Text 756 - Done
# Text 757 - Done
# Text 758 - Done
# Text 762 - Done
# Text 763 - Done
# Text 764 - Done
# Text 765 - Done
# Text 766 - Done
# Text 767 - Done
# Text 768 - Done
# Text 770 - Done
# Text 771 - Done
# Text 772 - Done
# Text 773 - Done
# Text 774 - Done
# Text 776 - Done
# Text 777 - Done
# Text 778 - Done
# Text 779 - Done
# Text 780 - Done
# Text 781 - Done
# Text 782 - Done
# Text 783 - Done
# Text 784 - Done
# Text 785 - Done
# Text 786 - Done
# Text 787 - Done
# Text 788 - Done
# Text 789 - Done
# Text 790 - Done
# Text 791 - Done
# Text 792 - Done
# Text 793 - Done
# Text 794 - Done
# Text 795 - Done
# Text 796 - Done
# Text 797 - Done
# Text 798 - Done
# Text 799 - Done
# Text 800 - Done
# Text 801 - Done
# Text 802 - Done
# Text 803 - Done
# Text 804 - Done
# Text 805 - Done
# Text 806 - Done
# Text 807 - Done
# Text 811 - Done
# Text 812 - Done
# Text 813 - Done
# Text 814 - Done
# Text 815 - Done
# Text 816 - Done
# Text 817 - Done
# Text 818 - Done
# Text 819 - Done
# Text 820 - Done
# Text 821 - Done
# Text 822 - Done
# Text 823 - Done
# Text 824 - Done
# Text 825 - Done
# Text 826 - Done
# Text 827 - Done
# Text 828 - Done
# Text 829 - Done
# Text 830 - Done
# Text 831 - Done
# Text 832 - Done
# Text 833 - Done
# Text 834 - Done
# Text 835 - Done
# Text 836 - Done
# Text 837 - Done
# Text 838 - Done
# Text 839 - Done
# Text 840 - Done
# Text 841 - Done
# Text 842 - Done
# Text 843 - Done
# Text 845 - Done
# Text 846 - Done
# Text 847 - Done
# Text 849 - Done
# Text 850 - Done
# Text 851 - Done
# Text 852 - Done
# Text 853 - Done
# Text 854 - Done
# Text 855 - Done
# Text 856 - Done
# Text 857 - Done
# Text 858 - Done
# Text 859 - Done
# Text 860 - Done
# Text 861 - Done
# Text 862 - Done
# Text 863 - Done
# Text 864 - Done
# Text 866 - Done
# Text 867 - Done
# Text 869 - Done
# Text 870 - Done
# Text 871 - Done
# Text 872 - Done
# Text 873 - Done
# Text 874 - Done
# Text 875 - Done
# Text 877 - Done
# Text 878 - Done
# Text 879 - Done
# Text 880 - Done
# Text 881 - Done
# Text 882 - Done
# Text 883 - Done
# Text 884 - Done
# Text 885 - Done
# Text 886 - Done
# Text 887 - Done
# Text 888 - Done
# Text 889 - Done
# Text 890 - Done
# Text 891 - Done
# Text 892 - Done
# Text 893 - Done
# Text 894 - Done
# Text 896 - Done
# Text 897 - Done
# Text 898 - Done
# Text 899 - Done
# Text 900 - Done
# Text 901 - Done
# Text 902 - Done
# Text 903 - Done
# Text 904 - Done
# Text 905 - Done
# Text 906 - Done
# Text 907 - Done
# Text 908 - Done
# Text 909 - Done
# Text 910 - Done
# Text 911 - Done
# Text 912 - Done
# Text 913 - Done
# Text 914 - Done
# Text 915 - Done
# Text 916 - Done
# Text 917 - Done
# Text 918 - Done
# Text 919 - Done
# Text 920 - Done
# Text 921 - Done
# Text 922 - Done
# Text 923 - Done
# Text 924 - Done
# Text 925 - Done
# Text 926 - Done
# Text 927 - Done
# Text 928 - Done
# Text 929 - Done
# Text 930 - Done
# Text 931 - Done
# Text 932 - Done
# Text 933 - Done
# Text 934 - Done
# Text 935 - Done
# Text 936 - Done
# Text 937 - Done
# Text 938 - Done
# Text 939 - Done
# Text 940 - Done
# Text 941 - Done
# Text 942 - Done
# Text 943 - Done
# Text 944 - Done
# Text 945 - Done
# Text 946 - Done
# Text 947 - Done
# Text 948 - Done
# Text 949 - Done
# Text 950 - Done
# Text 951 - Done
# Text 952 - Done
# Text 953 - Done
# Text 954 - Done
# Text 955 - Done
# Text 956 - Done
# Text 957 - Done
# Text 958 - Done
# Text 959 - Done
# Text 960 - Done
# Text 961 - Done
# Text 962 - Done
# Text 963 - Done
# Text 964 - Done
# Text 965 - Done
# Text 966 - Done
# Text 968 - Done
# Text 969 - Done
# Text 970 - Done
# Text 971 - Done
# Text 972 - Done
# Text 973 - Done
# Text 974 - Done
# Text 975 - Done
# Text 976 - Done
# Text 977 - Done
# Text 978 - Done
# Text 979 - Done
# Text 980 - Done
# Text 981 - Done
# Text 982 - Done
# Text 983 - Done
# Text 984 - Done
# Text 985 - Done
# Text 986 - Done
# Text 987 - Done
# Text 988 - Done
# Text 989 - Done
# Text 990 - Done
# Text 991 - Done
# Text 992 - Done
# Text 993 - Done
# Text 994 - Done
# Text 995 - Done
# Text 996 - Done
# Text 997 - Done
# Text 998 - Done
# Text 999 - Done

# %%
for keyword in gram_dict.keys():
    parts=keyword.split()
    parts="_".join(parts)
    keyword_processor.add_keyword(keyword,parts)

# %%
for keyword in text_rank_key_words.keys():
    parts=keyword.split()
    parts="_".join(parts)
    textrank_keyword_processor.add_keyword(keyword,parts)

# %%
len(keyword_processor.get_all_keywords())
# Out:
# 1868

# %%
len(textrank_keyword_processor.get_all_keywords())
# Out:
# 19754

# %%
len(text_rank_key_words)
# Out:
# 19754

# %%
def extract_keywords(text,keyword_processor):
    sentences=[]
    if text==None:
        return None
    for i in range(0, len(text)):
        keywords_found = keyword_processor.extract_keywords(text[i])
        sentences.append(" ".join(keywords_found))
    return sentences

# %%
def merge_two_keywords_methods(sentences, text_rank_key_word_processor, frequent_key_words_processor):
    if sentences==None:
        return None
    text_rank_version = extract_keywords(sentences,text_rank_key_word_processor)
    frequent_key_words_version = extract_keywords(sentences,frequent_key_words_processor)
    intersect = set(frequent_key_words_version) - set(text_rank_version)

    merged_version = text_rank_version + list(intersect)
    return merged_version

# %%
table_to_process["abstract"]=table_to_process["abstract"].apply(lambda x: merge_two_keywords_methods(x, textrank_keyword_processor, keyword_processor))
# Out:
# C:\Conda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0, len(table_to_process)):
    metadata_table.loc[i,"title"] = table_to_process.loc[i,"title"]
    metadata_table.loc[i,"abstract"] = table_to_process.loc[i,"abstract"]

# %%
metadata_table
# Out:
#      cord_uid                                       sha source_x  \
# 0    ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1    02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2    ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3    2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4    9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# ..        ...                                       ...      ...
# 995  880nqc0f  ed2de3694f5580ea38f4adf24bd1c8b46862df1f      PMC
# 996  01b0vnnm  2a7c951e191425fd9fa5ac108f07a1f02eb75872      PMC
# 997  5b29wtim  854e623d1f875e4605b2ffd3f72599d063a56cc0      PMC
# 998  z65xxk1f  3695704554777889f8232a9ea086df70bf17ff58      PMC
# 999  iuglkdcp  5a054a570f409d5c2006369f19addc98d024b6c1      PMC
#
#                                                  title  \
# 0    [clinical features culture proven mycoplasma p...
# 1    [nitric oxide pro inflammatory mediator lung d...
# 2          [surfactant protein pulmonary host defense]
# 3                       [role endothelin lung disease]
# 4    [gene expression epithelial cells response pne...
# ..                                                 ...
# 995  [mannose binding lectin deficiency acute exace...
# 996  [changing phenotype microglia homeostasis dise...
# 997  [diversity salmonella spp, serovars isolated i...
# 998  [severe childhood malaria syndromes defined pl...
# 999  [predicting pseudoknotted structures across tw...
#
#                                doi       pmcid pubmed_id license  \
# 0            10.1186/1471-2334-1-6    PMC35282  11472636   no-cc
# 1                     10.1186/rr14    PMC59543  11667967   no-cc
# 2                     10.1186/rr19    PMC59549  11667972   no-cc
# 3                     10.1186/rr44    PMC59574  11686871   no-cc
# 4                     10.1186/rr61    PMC59580  11686888   no-cc
# ..                             ...         ...       ...     ...
# 995            10.2147/copd.s33714  PMC3514010  23226013   no-cc
# 996          10.1186/2047-9158-1-9  PMC3514090  23210447   cc-by
# 997        10.1186/1746-6148-8-201  PMC3514206  23098237   cc-by
# 998   10.1371/journal.pone.0049778  PMC3514223  23226502   cc-by
# 999  10.1093/bioinformatics/bts575  PMC3516145  23044552   cc-by
#
#                                               abstract publish_time  \
# 0    [objective_retrospective_chart_review epidemio...  2001-07-04
# 1    [inflammatory_diseases respiratory_tract commo...  2000-08-15
# 2    [surfactant_protein_participates response micr...  2000-08-25
# 3    [endothelin_amino_acid_peptide_diverse_biologi...  2001-02-22
# 4    [respiratory_syncytial_virus_rsv_pneumonia_vir...  2001-05-11
# ..                                                 ...          ...
# 995  [background_mannose_binding_lectin_collectin h...  2012-11-23
# 996  [century early_description_microglia_rio many_...  2012-04-24
# 997  [background_salmonellosis_water_buffalo_bubalu...  2012-10-25
# 998  [background_cerebral_malaria serious_life clin...  2012-12-04
# 999  [motivation_laboratory_rna_structure_determina...  2012-12-01
#
#                                                authors  \
# 0                  Madani, Tariq A; Al-Ghamdi, Aisha A
# 1    Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                      Crouch, Erika C
# 3    Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4    Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# ..                                                 ...
# 995  Albert, Richard K; Connett, John; Curtis, Jeff...
# 996                    Luo, Xiao-Guang; Chen, Sheng-Di
# 997  Borriello, Giorgia; Lucibelli, Maria G; Pescia...
# 998  Burté, Florence; Brown, Biobele J.; Orimadegun...
# 999  Sperschneider, Jana; Datta, Amitava; Wise, Mic...
#
#                              journal mag_id who_covidence_id arxiv_id  \
# 0                     BMC Infect Dis   None             None    None
# 1                         Respir Res   None             None    None
# 2                         Respir Res   None             None    None
# 3                         Respir Res   None             None    None
# 4                         Respir Res   None             None    None
# ..                               ...    ...              ...      ...
# 995  Int J Chron Obstruct Pulmon Dis   None             None    None
# 996              Transl Neurodegener   None             None    None
# 997                      BMC Vet Res   None             None    None
# 998                         PLoS One   None             None    None
# 999                   Bioinformatics   None             None    None
#
#                                         pdf_json_files  \
# 0    document_parses/pdf_json/d1aafb70c066a2068b027...
# 1    document_parses/pdf_json/6b0567729c2143a66d737...
# 2    document_parses/pdf_json/06ced00a5fc04215949aa...
# 3    document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4    document_parses/pdf_json/5f48792a5fa08bed9f560...
# ..                                                 ...
# 995  document_parses/pdf_json/ed2de3694f5580ea38f4a...
# 996  document_parses/pdf_json/2a7c951e191425fd9fa5a...
# 997  document_parses/pdf_json/854e623d1f875e4605b2f...
# 998  document_parses/pdf_json/3695704554777889f8232...
# 999  document_parses/pdf_json/5a054a570f409d5c20063...
#
#                                    pmc_json_files  \
# 0      document_parses/pmc_json/PMC35282.xml.json
# 1      document_parses/pmc_json/PMC59543.xml.json
# 2      document_parses/pmc_json/PMC59549.xml.json
# 3      document_parses/pmc_json/PMC59574.xml.json
# 4      document_parses/pmc_json/PMC59580.xml.json
# ..                                            ...
# 995  document_parses/pmc_json/PMC3514010.xml.json
# 996  document_parses/pmc_json/PMC3514090.xml.json
# 997  document_parses/pmc_json/PMC3514206.xml.json
# 998  document_parses/pmc_json/PMC3514223.xml.json
# 999  document_parses/pmc_json/PMC3516145.xml.json
#
#                                                    url s2_id
# 0    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 1    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 2    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 3    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 4    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# ..                                                 ...   ...
# 995  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 996  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 997  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 998  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 999  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
#
# [1000 rows x 19 columns]

# %%
dataset = []
for i in range(0, len(table_to_process["abstract"])):
    sentences = table_to_process.loc[i,"abstract"]
    if sentences!=None:
        sentences=" ".join(sentences)
        dataset.append(sentences)
        
tfIdfVectorizer=TfidfVectorizer(use_idf=True)
tfIdf = tfIdfVectorizer.fit_transform(dataset)

# %%
def retain_best_tf_idf_keywords(sentences, index):
    if sentences==None:
        return None
    tf_idf_keyword_processor = KeywordProcessor()
    df = pd.DataFrame(tfIdf[index].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF_IDF"])
    df = df.sort_values('TF_IDF', ascending=False)
    df = df[df.TF_IDF>0.09]
    tf_idf_dict=df.T.to_dict('list')    
    for keyword in tf_idf_dict.keys():
        parts = " ".join(keyword.split("_"))
        tf_idf_keyword_processor.add_keyword(keyword,parts)
    sentences = extract_keywords(sentences,tf_idf_keyword_processor)
    return sentences

# %%
index=0
for i in range(0,len(metadata_table)):
    if table_to_process.loc[i,"abstract"]==None:
        continue
    metadata_table.loc[i,"abstract"]=retain_best_tf_idf_keywords(table_to_process.loc[i,"abstract"], index)
    index+=1

# %% [markdown]
# ## Stemming or Morphological Analysis (Lemmatisation)

# %%
def lematise_text(sentences):
    if sentences==None:
        return None
    lemmatizer = WordNetLemmatizer()
    for i in range(0, len(sentences)):
        try:
            if sentences[i] == "":
                continue
            words=sentences[i].split()
            lematised_words = [lemmatizer.lemmatize(word) for word in words]
            lematised_words = ' '.join(lematised_words)
            sentences[i]=lematised_words
        except:
            print(sentences)
            print(sentences[i])
            break
    return sentences

# %%
metadata_table["abstract"]=metadata_table["abstract"].apply(lambda x: lematise_text(x))

# %% [markdown]
# ## Indexing

# %%
for i in range(0,len(metadata_table)):
    metadata_table.iloc[i].to_json('covid.json')
    f = open('covid.json')
    docket_content = f.read()
    row=json.loads(docket_content)
    try:
        es.index(index='covid', id=i, body=row)
    except:
        traceback.print_exc() 
        print("Error:", "row #"+str(i))

# %% [markdown]
# ## Searching

# %%
query={
  "query": {
    "match_phrase":{"publish_time":"2000-08-15"}
  }
}

# %%
res = es.search(index="covid", body=query)

# %%
documents=[]
for i in range(0, len(res['hits']['hits'])):
    doc=res['hits']['hits'][i]['_source']
    documents.append(doc)

# %%
pprint.pprint(documents)
# Out:
# [{'abstract': ['inflammatory disease respiratory tract commonly associated '
#                'elevated production nitric oxide index dependent oxidative '
#                'stress',
#                'property various line evidence support contribution lung '
#                'injury several disease model',
#                'basis biochemical evidence dependent oxidation formation '
#                'alternative mechanism phagocyte heme protein eosinophil '
#                'peroxidase condition inflammation',
#                'overwhelming literature generation activity respiratory tract '
#                'scope commentary review area',
#                'recent evidence concept presumed contribution inflammatory '
#                'disease lung',
#                'literature generation respiratory tract area',
#                'inflammatory disease respiratory tract commonly nitric oxide '
#                'dependent oxidative stress',
#                'basis evidence dependent formation although alternative '
#                'condition inflammation',
#                'although anti anti inflammatory anti property line evidence '
#                'lung injury',
#                'evidence inflammatory disease lung'],
#   'arxiv_id': 'None ',
#   'authors': 'Vliet, Albert van der; Eiserich, Jason P; Cross, Carroll E',
#   'cord_uid': '02tnwd4m',
#   'doi': '10.1186/rr14',
#   'journal': 'Respir Res',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/6b0567729c2143a66d737eb0a2f63f2dce2e5a7d.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC59543.xml.json',
#   'pmcid': 'PMC59543',
#   'publish_time': '2000-08-15 ',
#   'pubmed_id': '11667967',
#   's2_id': None,
#   'sha': '6b0567729c2143a66d737eb0a2f63f2dce2e5a7d',
#   'source_x': 'PMC',
#   'title': ['nitric oxide pro inflammatory mediator lung disease'],
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC59543/',
#   'who_covidence_id': None}]

# %%
# es.indices.create(index = 'covid', body = request_body)

# %% [markdown]
# 1. Зберегти рядок у формат джісон
# 2. Відкрити інший інший файл у форматі джісон
# 3. Присвоїти файл до елементу рядка
# 4. Додати рядок у список рядків
# 5. Зберегти все в еластіксерч

# %%
# i=0

# file_link=table.loc[i,link_collumn]
# try:
#     if file_link==None:
#         print("ERROR:", i, "-", file_link)
#         table.loc[i,link_collumn]="Undefined"     
#     else:
#         res=re.findall('document_parses/pdf_json/\w+\.json|document_parses/pmc_json/\w+\.xml.json',file_link)
#         if len(res)>0:
#             file_link=res[0]
#         else:
#             print("ERROR:", i, "-", file_link)
#             table.loc[i,link_collumn]="Undefined"

#     f = open(file_link)
#     file_content = f.read()

#     table.iloc[i].to_json('row.json')
#     f = open('row.json')
#     row_content = f.read()
#     row_json_content=json.loads(row_content)
#     row_json_content[link_collumn]=file_content

# except:
#     print("ERROR:", i, "-", file_link)
#     traceback.print_exc()
#     table.loc[i,link_collumn]="Undefined"

# %%
# def load_article_files(table, link_collumn='pdf_json_files', filename='covid.json', file_link_start_part='document_parses/pdf_json/'):
#     for i in range(0,len(table)):
#         file_link=table.loc[i,link_collumn]
#         try:
#             if file_link==None:
#                 print("ERROR:", i, "-", file_link)
#                 table.loc[i,link_collumn]="Undefined"
#                 continue
#             else:
#                 res=re.findall('document_parses/pdf_json/\w+\.json|document_parses/pmc_json/\w+\.xml.json',file_link)
#                 if len(res)>0:
#                     file_link=res[0]
#                 else:
#                     print("ERROR:", i, "-", file_link)
#                     table.loc[i,link_collumn]="Undefined"
#                     continue
                    
#             f = open(file_link)
#             file_content = f.read()
            
#             table.iloc[i].to_json('row.json')
#             f = open('row.json')
#             row_content = f.read()
#             row_json_content=json.loads(row_content)
#             table.loc[i,link_collumn]=file_content
            
#         except:
#             print("ERROR:", i, "-", file_link)
#             traceback.print_exc()
#             table.loc[i,link_collumn]="Undefined"
#     return table

# %%
# load_article_files(metadata_table,link_collumn='pdf_json_files', filename='covid.json').head(2)

# %%
# load_article_files(metadata_table,link_collumn='pmc_json_files', filename='covid.json',file_link_start_part='document_parses/pmc_json/')

# %%
# directory = 'covid.json'

# %%
# for i in range(0,1):
# #     pdf_link=metadata_table.loc[i,'pdf_json_files']
# #     pmc_json=metadata_table.loc[i,'pmc_json_files']

# #     pdf_json = json.loads(metadata_table.loc[i,'pdf_json_files']) if pdf_link!="Undefined" else pdf_link
# #     pmc_json = json.loads(metadata_table.loc[i,'pmc_json_files']) if pmc_json!="Undefined" else pmc_json
#     metadata_table.iloc[i].to_json('covid.json')
#     f = open(directory)
#     docket_content = f.read()
#     row=json.loads(docket_content)
# #     row['pdf_json_files']=pdf_json
# #     row['pmc_json_files']=pmc_json
#     try:
#         es.index(index='covid', doc_type='docket', id=i, body=row)
#     except:
#         traceback.print_exc() 
#         print("Error:", "row #"+str(i))
#         continue

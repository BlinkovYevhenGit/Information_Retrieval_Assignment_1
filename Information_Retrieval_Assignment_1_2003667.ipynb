# %%
# !pip install unidecode
# !pip install gensim
# !pip install flashtext
# Out:
# Requirement already satisfied: unidecode in c:\conda\lib\site-packages (1.2.0)
# Requirement already satisfied: gensim in c:\conda\lib\site-packages (3.8.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\conda\lib\site-packages (from gensim) (3.0.0)
# Requirement already satisfied: six>=1.5.0 in c:\conda\lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\conda\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\conda\lib\site-packages (from gensim) (1.18.4)
# Requirement already satisfied: Cython==0.29.14 in c:\conda\lib\site-packages (from gensim) (0.29.14)
# Requirement already satisfied: requests in c:\conda\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\conda\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.8)
# Requirement already satisfied: flashtext in c:\conda\lib\site-packages (2.7)

# %%
import json
import re
import traceback 
from pyspark.sql import SparkSession
from elasticsearch import Elasticsearch, helpers
import requests, json, os, csv
from nltk.corpus import stopwords
import string
import unidecode
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
from flashtext import KeywordProcessor
import spacy
import pytextrank
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
from nltk.stem import WordNetLemmatizer
import pprint
from IPython.display import display

# %%
s_top_words = set(stopwords.words('english'))

# %% [markdown]
# ## Data loading

# %%
def load_data(path = 'metadata.csv'):
    spark = SparkSession \
    .builder \
    .appName("ElasticSpark-1") \
    .config("spark.driver.extraClassPath", "/path/elasticsearch-hadoop-7.6.2/dist/elasticsearch-spark-20_2.11-7.6.2.jar") \
    .config("spark.es.port","9200") \
    .config("spark.driver.memory", "8G") \
    .config("spark.executor.memory", "12G") \
    .getOrCreate()
    metadata_df = spark.read.csv(path, multiLine=True, header=True)
    metadata_df.show(1)
    metadata_df = metadata_df.select("*").limit(1000)
    metadata_df.show(3)
    metadata_table = metadata_df.toPandas()
    print("Data loaded.")
    display(metadata_table)
    metadata_table["pr_title"]=metadata_table["title"]
    metadata_table["pr_abstract"]=metadata_table["abstract"]
    return metadata_table

# %%
def create_index(es_index="covid"):
    res = requests.get('http://localhost:9200')
    print (res.content)
    es = Elasticsearch([{'host': 'localhost', 'port': '9200'}])
    mapping = {
        'settings':{
            'number_of_shards': 1, 
            'number_of_replicas': 1
        },
        'mappings': {
            'properties': {
                'cord_uid': {
                    'index': 'true', 
                    'type': 'text'
                },
                'sha': {
                    'index': 'true', 
                    'type': 'text'
                },
                'source_x': {
                    'index': 'true', 
                    'type': 'text'
                },
                'title': {
                    'index': 'true',
                    'type': 'text', 
                    'similarity': 'BM25'
                },
                'pr_title': {
                    'index': 'true',
                    'type': 'text', 
                    'similarity': 'BM25'
                },
                'doi': {
                    'index': 'true', 
                    'type': 'text'
                },
                'pmcid': {
                    'index': 'true',
                    'type': 'text'
                },
                'license': {
                    'index': 'true',
                    'type': 'text'
                },
                'abstract': {
                    'index': 'true',
                    'type': 'text',
                    'similarity': 'BM25'
                },
                'pr_abstract': {
                    'index': 'true',
                    'type': 'text',
                    'similarity': 'BM25'
                },
                'publish_time': {
                    'index': 'true', 
                    'type': 'text'
                },
                'authors': {
                    'index': 'true',
                    'type': 'text'
                },
                'journal': {
                    'index': 'true',
                    'type': 'text'
                },
                'who_covidence_id': {
                    'index': 'true',
                    'type': 'text'
                },
                'arxiv_id': {
                    'index': 'true',
                    'type': 'text'
                },
                'pdf_json_files': {
                    'index': 'true',
                    'type': 'text'
                },
                'pmc_json_files': {
                    'index': 'true', 
                    'type': 'text'
                },
                'url': {
                    'index': 'true',
                    'type': 'text'
                },
                's2_id': {
                    'index': 'true', 
                    'type': 'text'
                }
             }
         }
    }
    if es.indices.exists(es_index):
        es.indices.delete(es_index) 

    es.indices.create(index=es_index,body=mapping)
    return es

# %% [markdown]
# ## Sentence Splitting, Tokenization and Normalization

# %%
class TextNormalizer:
    def __init__(self):
        self.punctuation_table = str.maketrans('','',string.punctuation)

    def normalize_text(self,text):
        if text==None:
            return None
        try: 
            normalized_sentences = []
            text = re.sub(' +',' ', text)
            text = unidecode.unidecode(text)
            text = text.lower()
            sentences = sent_tokenize(text)
        except:
            print("ERROR:", text)
            traceback.print_exc()
            return None
        
        for sentence in sentences:
            #remove punctuation
            sentence=re.sub("["+string.punctuation+"\d*]"," ",sentence)
            #strip leading/trailing whitespace
            sentence = sentence.strip()
            words = word_tokenize(sentence)
            new_sentence = ' '.join(words) #we want to keep it as before to extract phrases
            normalized_sentences.append(new_sentence)
        return normalized_sentences

# %%
def normalize_table(metadata_table):
    normaliser = TextNormalizer()
    
    table_to_process=metadata_table[["pr_title","pr_abstract"]]
    table_to_process["pr_title"]=table_to_process["pr_title"].apply(lambda x: normaliser.normalize_text(x))
    table_to_process["pr_abstract"]=table_to_process["pr_abstract"].apply(lambda x: normaliser.normalize_text(x))
    
    for i in range(0, len(table_to_process)):
        metadata_table.loc[i,"pr_title"] = table_to_process.loc[i,"pr_title"]
        metadata_table.loc[i,"pr_abstract"] = table_to_process.loc[i,"pr_abstract"]
    return metadata_table

# %% [markdown]
# ## Selecting key words

# %%
def remove_stop_words(text):
    if text==None:
        return
    for index,sentence in enumerate(text):
        sentence = sentence.split(" ") #performing tokenisation
        sentence = [word for word in sentence if word not in s_top_words and len(word)>2]
        sentence=" ".join(sentence)
        text[index]=sentence
    return text

# %%
def get_words_corpus(table):
    words_corpus=[]
    for i in range(0, len(table)):
        row=table.loc[i]
        title_sentences = row["pr_title"]
        abstract_sentences = row["pr_abstract"]
        
        if title_sentences!=None:
            for i in range(0,len(title_sentences)):
                words_corpus.extend(title_sentences[i].split())
                
        if  abstract_sentences!=None:
            for i in range(0,len(abstract_sentences)):
                words_corpus.extend(abstract_sentences[i].split())
    return words_corpus

# %%
def get_keywords_by_textrank(sentences):
    if sentences==None:
        return None
    keywords=dict()
    nlp = spacy.load('en_core_web_sm')
    nlp.add_pipe("textrank", last=True)
    doc = nlp(" ".join(sentences))

    # examine the top-ranked phrases in the document

    for p in doc._.phrases:
        if p.rank>=0.05:
            keywords[p.text]=p.rank
    #         print("{:.4f} {:5d}  {}".format(p.rank, p.count, p.text))
    #         print(p.text)
    return keywords

# %%
def extract_keywords(text,keyword_processor):
    sentences=[]
    if text==None:
        return None
    for i in range(0, len(text)):
        keywords_found = keyword_processor.extract_keywords(text[i])
        sentences.append(" ".join(keywords_found))
    return sentences

# %%
def merge_two_keywords_methods(sentences, text_rank_key_word_processor, frequent_key_words_processor):
    if sentences==None:
        return None
    text_rank_version = extract_keywords(sentences,text_rank_key_word_processor)
    frequent_key_words_version = extract_keywords(sentences,frequent_key_words_processor)
    intersect = set(frequent_key_words_version) - set(text_rank_version)

    merged_version = text_rank_version + list(intersect)
    return merged_version

# %%
def retain_best_tf_idf_keywords(sentences, index, tfIdf,tfIdfVectorizer):
    if sentences==None:
        return None
    tf_idf_keyword_processor = KeywordProcessor()
    df = pd.DataFrame(tfIdf[index].T.todense(), index=tfIdfVectorizer.get_feature_names(), columns=["TF_IDF"])
    df = df.sort_values('TF_IDF', ascending=False)
    df = df[df.TF_IDF>0.09]
    tf_idf_dict=df.T.to_dict('list')    
    for keyword in tf_idf_dict.keys():
        parts = " ".join(keyword.split("_"))
        tf_idf_keyword_processor.add_keyword(keyword,parts)
    sentences = extract_keywords(sentences,tf_idf_keyword_processor)
    return sentences

# %%
def select_best_keywords(metadata_table):
    table_to_process=metadata_table[["pr_title","pr_abstract"]]
    table_to_process["pr_title"]=table_to_process["pr_title"].apply(lambda x: remove_stop_words(x))
    table_to_process["pr_abstract"]=table_to_process["pr_abstract"].apply(lambda x: remove_stop_words(x))
    
    print("Text Data after removing of stop-words")
    display(table_to_process)

    words_corpus=get_words_corpus(table_to_process)
    print(len(words_corpus))

    dist = nltk.FreqDist(words_corpus) #Creating a distribution of words' frequencies
    grams=dist.most_common(1000) #Obtaining the most frequent words
    bigrams = nltk.collocations.BigramAssocMeasures()
    trigrams = nltk.collocations.TrigramAssocMeasures()

    bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(words_corpus)
    trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(words_corpus)

    print("Showing first",2000,"top-freqent words in the corpus")
    grams = pd.DataFrame(grams) 
    grams.index = range(1,len(grams)+1)
    grams.columns = ["Word", "Frequency"]
    display(grams)
    
    bi_filter=7
    print("Showing bigrams in the corpus found by Pointwise Mutual Information method")
    print("Applying frequency filter: a bigramm occurs more than",bi_filter,"times")
    bigramFinder.apply_freq_filter(bi_filter)
    bigramPMITable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)
    bigramPMITable["bigram"]=bigramPMITable["bigram"].apply(lambda x: ' '.join(x))
    display(bigramPMITable)

    tri_filter=5
    print("Showing trigrams in the corpus found by Pointwise Mutual Information method")
    print("Applying frequency filter: a trigramm occurs more than",tri_filter,"times")
    trigramFinder.apply_freq_filter(tri_filter)
    trigramPMITable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['trigram','PMI']).sort_values(by='PMI', ascending=False)
    trigramPMITable["trigram"]=trigramPMITable["trigram"].apply(lambda x: ' '.join(x))
    display(trigramPMITable)

    gram_dict=grams.set_index('Word').T.to_dict('list')
    bigramPMIDict=bigramPMITable.set_index('bigram').T.to_dict('list')
    trigramPMIDict=trigramPMITable.set_index('trigram').T.to_dict('list')

    keyword_processor = KeywordProcessor()
    textrank_keyword_processor = KeywordProcessor()

    gram_dict.update(bigramPMIDict)
    bigramPMIDict.update(trigramPMIDict)

#     print(gram_dict)
    print("Extracting keywords from texts using Pointwise Mutual Information method and TextRank")
    text_rank_key_words=dict()
    for i in range(0, len(table_to_process)):
        sentences=table_to_process.loc[i,"pr_abstract"]
        if sentences!=None:
            keywords=get_keywords_by_textrank(sentences)
            if keywords!=None:
                text_rank_key_words.update(keywords)
                print("Text",i,"- Done")

    for keyword in gram_dict.keys():
        parts=keyword.split()
        parts="_".join(parts)
        keyword_processor.add_keyword(keyword,parts)

    for keyword in text_rank_key_words.keys():
        parts=keyword.split()
        parts="_".join(parts)
        textrank_keyword_processor.add_keyword(keyword,parts)

    
    print(len(keyword_processor.get_all_keywords()))
    print(len(textrank_keyword_processor.get_all_keywords()))
    print(len(text_rank_key_words))

    table_to_process["pr_abstract"]=table_to_process["pr_abstract"].apply(lambda x: merge_two_keywords_methods(x, textrank_keyword_processor, keyword_processor))     

    for i in range(0, len(table_to_process)):
        metadata_table.loc[i,"pr_title"] = table_to_process.loc[i,"pr_title"]
        metadata_table.loc[i,"pr_abstract"] = table_to_process.loc[i,"pr_abstract"]

    print("Comparison of Text Data after Keywords Extraction using Pointwise Mutual Information method and TextRank")
    display(metadata_table[["title","pr_title","abstract","pr_abstract"]])

    print("Extracting keywords from texts using TF/IDF")
    dataset = []
    for i in range(0, len(table_to_process["pr_abstract"])):
        sentences = table_to_process.loc[i,"pr_abstract"]
        if sentences!=None:
            sentences=" ".join(sentences)
            dataset.append(sentences)

    tfIdfVectorizer=TfidfVectorizer(use_idf=True)
    tfIdf = tfIdfVectorizer.fit_transform(dataset)

    index=0
    for i in range(0,len(metadata_table)):
        if table_to_process.loc[i,"pr_abstract"]==None:
            continue
        metadata_table.loc[i,"pr_abstract"]=retain_best_tf_idf_keywords(table_to_process.loc[i,"pr_abstract"], index,tfIdf,tfIdfVectorizer)
        index+=1
    return metadata_table

# %% [markdown]
# ## Stemming or Morphological Analysis (Lemmatisation)

# %%
def lemmatise_text(sentences):
    if sentences==None:
        return None
    lemmatizer = WordNetLemmatizer()
    for i in range(0, len(sentences)):
        try:
            if sentences[i] == "":
                continue
            words=sentences[i].split()
            lemmatised_words = [lemmatizer.lemmatize(word) for word in words]
            lemmatised_words = ' '.join(lemmatised_words)
            sentences[i]=lemmatised_words
        except:
            print(sentences)
            print(sentences[i])
            traceback.print_exc()
            break
    return sentences

# %% [markdown]
# ## Indexing

# %%
def index_table(es,metadata_table,es_index="covid"):
    for i in range(0,len(metadata_table)):
        metadata_table.iloc[i].to_json(es_index+'.json')
        f = open(es_index+'.json')
        docket_content = f.read()
        row=json.loads(docket_content)
        try:
            es.index(index=es_index, id=i, body=row)
        except:
            traceback.print_exc() 
            print("Error:", "row #"+str(i))

# %% [markdown]
# ## Searching

# %%
def search(es, es_index="covid",
    query={
          "query": {
            "match_phrase":{"publish_time":"2000-08-15"}
          }
        }):
    res = es.search(index=es_index, body=query)
    documents=[]
    for i in range(0, len(res['hits']['hits'])):
        doc=res['hits']['hits'][i]['_source']
        documents.append(doc)
    return documents

# %% [markdown]
# ## Running of the program

# %%
def run_program(path = 'metadata.csv',es_index="covid", query={
              "query": {
                "match_phrase":{"publish_time":"2000-08-15"}
              }
            }):
    #Data loading
    print("Data loading")
    metadata_table= load_data(path)
    print("pr_title and pr_abstract columns have been added")
    display(metadata_table)
    
    #Indexing
    print("Creating index -",es_index)
    es=create_index(es_index)
    print("Indexing")
    index_table(es,metadata_table,es_index=es_index)
    print("Data indexed.")

    #Sentence splitting, text tokenisation and normalisation
    print("Sentence splitting, text tokenisation and normalisation")
    metadata_table=normalize_table(metadata_table)
    print("Comparison of Text Data after Sentence splitting, text tokenisation and normalisation step")
    display(metadata_table[["title","pr_title","abstract","pr_abstract"]])

    #Selecting keywords
    print("Selecting keywords")
    metadata_table=select_best_keywords(metadata_table)
    print("Comparison of Text Data after Selecting keywords step")
    display(metadata_table[["title","pr_title","abstract","pr_abstract"]])
    
    #Text lemmatisation
    print("Text lemmatisation")
    metadata_table["pr_abstract"]=metadata_table["pr_abstract"].apply(lambda x: lemmatise_text(x))
    metadata_table["pr_title"]=metadata_table["pr_title"].apply(lambda x: lemmatise_text(x))
    print("Comparison of Text Data after Applied Lemmatisation")
    display(metadata_table[["title","pr_title","abstract","pr_abstract"]])

    #Indexing
    print("Creating index -",es_index)
    es=create_index(es_index)
    print("Indexing")
    index_table(es,metadata_table,es_index=es_index)
    
    #Searching in ElasticSearch
    print("Searching in ElasticSearch")
    documents=search(es, es_index=es_index, query=query)
    print("Retrieved documents:")
    pprint.pprint(documents)
    
    return documents,es

# %%
documents,es=run_program(path = 'metadata.csv',es_index="covid", query={
              "query": {
                "match_phrase":{"publish_time":"2000-08-15"}
              }
            })
print("Retrieved documents:")
pprint.pprint(documents)
# Out:
# Data loading
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |cord_uid|                 sha|source_x|               title|                 doi|   pmcid|pubmed_id|license|            abstract|publish_time|             authors|       journal|mag_id|who_covidence_id|arxiv_id|      pdf_json_files|      pmc_json_files|                 url|s2_id|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |ug7v899j|d1aafb70c066a2068...|     PMC|Clinical features...|10.1186/1471-2334...|PMC35282| 11472636|  no-cc|OBJECTIVE: This r...|  2001-07-04|Madani, Tariq A; ...|BMC Infect Dis|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# only showing top 1 row
#
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |cord_uid|                 sha|source_x|               title|                 doi|   pmcid|pubmed_id|license|            abstract|publish_time|             authors|       journal|mag_id|who_covidence_id|arxiv_id|      pdf_json_files|      pmc_json_files|                 url|s2_id|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# |ug7v899j|d1aafb70c066a2068...|     PMC|Clinical features...|10.1186/1471-2334...|PMC35282| 11472636|  no-cc|OBJECTIVE: This r...|  2001-07-04|Madani, Tariq A; ...|BMC Infect Dis|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# |02tnwd4m|6b0567729c2143a66...|     PMC|Nitric oxide: a p...|        10.1186/rr14|PMC59543| 11667967|  no-cc|Inflammatory dise...|  2000-08-15|Vliet, Albert van...|    Respir Res|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# |ejv2xln0|06ced00a5fc042159...|     PMC|Surfactant protei...|        10.1186/rr19|PMC59549| 11667972|  no-cc|Surfactant protei...|  2000-08-25|     Crouch, Erika C|    Respir Res|  null|            null|    null|document_parses/p...|document_parses/p...|https://www.ncbi....| null|
# +--------+--------------------+--------+--------------------+--------------------+--------+---------+-------+--------------------+------------+--------------------+--------------+------+----------------+--------+--------------------+--------------------+--------------------+-----+
# only showing top 3 rows
#
# Data loaded.
#      cord_uid                                       sha source_x  \
# 0    ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1    02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2    ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3    2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4    9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# ..        ...                                       ...      ...
# 995  880nqc0f  ed2de3694f5580ea38f4adf24bd1c8b46862df1f      PMC
# 996  01b0vnnm  2a7c951e191425fd9fa5ac108f07a1f02eb75872      PMC
# 997  5b29wtim  854e623d1f875e4605b2ffd3f72599d063a56cc0      PMC
# 998  z65xxk1f  3695704554777889f8232a9ea086df70bf17ff58      PMC
# 999  iuglkdcp  5a054a570f409d5c2006369f19addc98d024b6c1      PMC
#
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                doi       pmcid pubmed_id license  \
# 0            10.1186/1471-2334-1-6    PMC35282  11472636   no-cc
# 1                     10.1186/rr14    PMC59543  11667967   no-cc
# 2                     10.1186/rr19    PMC59549  11667972   no-cc
# 3                     10.1186/rr44    PMC59574  11686871   no-cc
# 4                     10.1186/rr61    PMC59580  11686888   no-cc
# ..                             ...         ...       ...     ...
# 995            10.2147/copd.s33714  PMC3514010  23226013   no-cc
# 996          10.1186/2047-9158-1-9  PMC3514090  23210447   cc-by
# 997        10.1186/1746-6148-8-201  PMC3514206  23098237   cc-by
# 998   10.1371/journal.pone.0049778  PMC3514223  23226502   cc-by
# 999  10.1093/bioinformatics/bts575  PMC3516145  23044552   cc-by
#
#                                               abstract publish_time  \
# 0    OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1    Inflammatory diseases of the respiratory tract...   2000-08-15
# 2    Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4    Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
# ..                                                 ...          ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...   2012-11-23
# 996  It has been nearly a century since the early d...   2012-04-24
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...   2012-10-25
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...   2012-12-04
# 999  Motivation: Laboratory RNA structure determina...   2012-12-01
#
#                                                authors  \
# 0                  Madani, Tariq A; Al-Ghamdi, Aisha A
# 1    Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                      Crouch, Erika C
# 3    Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4    Domachowske, Joseph B; Bonville, Cynthia A; Ro...
# ..                                                 ...
# 995  Albert, Richard K; Connett, John; Curtis, Jeff...
# 996                    Luo, Xiao-Guang; Chen, Sheng-Di
# 997  Borriello, Giorgia; Lucibelli, Maria G; Pescia...
# 998  Burté, Florence; Brown, Biobele J.; Orimadegun...
# 999  Sperschneider, Jana; Datta, Amitava; Wise, Mic...
#
#                              journal mag_id who_covidence_id arxiv_id  \
# 0                     BMC Infect Dis   None             None     None
# 1                         Respir Res   None             None     None
# 2                         Respir Res   None             None     None
# 3                         Respir Res   None             None     None
# 4                         Respir Res   None             None     None
# ..                               ...    ...              ...      ...
# 995  Int J Chron Obstruct Pulmon Dis   None             None     None
# 996              Transl Neurodegener   None             None     None
# 997                      BMC Vet Res   None             None     None
# 998                         PLoS One   None             None     None
# 999                   Bioinformatics   None             None     None
#
#                                         pdf_json_files  \
# 0    document_parses/pdf_json/d1aafb70c066a2068b027...
# 1    document_parses/pdf_json/6b0567729c2143a66d737...
# 2    document_parses/pdf_json/06ced00a5fc04215949aa...
# 3    document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4    document_parses/pdf_json/5f48792a5fa08bed9f560...
# ..                                                 ...
# 995  document_parses/pdf_json/ed2de3694f5580ea38f4a...
# 996  document_parses/pdf_json/2a7c951e191425fd9fa5a...
# 997  document_parses/pdf_json/854e623d1f875e4605b2f...
# 998  document_parses/pdf_json/3695704554777889f8232...
# 999  document_parses/pdf_json/5a054a570f409d5c20063...
#
#                                    pmc_json_files  \
# 0      document_parses/pmc_json/PMC35282.xml.json
# 1      document_parses/pmc_json/PMC59543.xml.json
# 2      document_parses/pmc_json/PMC59549.xml.json
# 3      document_parses/pmc_json/PMC59574.xml.json
# 4      document_parses/pmc_json/PMC59580.xml.json
# ..                                            ...
# 995  document_parses/pmc_json/PMC3514010.xml.json
# 996  document_parses/pmc_json/PMC3514090.xml.json
# 997  document_parses/pmc_json/PMC3514206.xml.json
# 998  document_parses/pmc_json/PMC3514223.xml.json
# 999  document_parses/pmc_json/PMC3516145.xml.json
#
#                                                    url s2_id
# 0    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 1    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 2    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 3    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 4    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# ..                                                 ...   ...
# 995  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 996  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 997  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 998  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 999  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
#
# [1000 rows x 19 columns]
# pr_title and pr_abstract columns have been added
#      cord_uid                                       sha source_x  \
# 0    ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1    02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2    ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3    2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4    9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# ..        ...                                       ...      ...
# 995  880nqc0f  ed2de3694f5580ea38f4adf24bd1c8b46862df1f      PMC
# 996  01b0vnnm  2a7c951e191425fd9fa5ac108f07a1f02eb75872      PMC
# 997  5b29wtim  854e623d1f875e4605b2ffd3f72599d063a56cc0      PMC
# 998  z65xxk1f  3695704554777889f8232a9ea086df70bf17ff58      PMC
# 999  iuglkdcp  5a054a570f409d5c2006369f19addc98d024b6c1      PMC
#
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                doi       pmcid pubmed_id license  \
# 0            10.1186/1471-2334-1-6    PMC35282  11472636   no-cc
# 1                     10.1186/rr14    PMC59543  11667967   no-cc
# 2                     10.1186/rr19    PMC59549  11667972   no-cc
# 3                     10.1186/rr44    PMC59574  11686871   no-cc
# 4                     10.1186/rr61    PMC59580  11686888   no-cc
# ..                             ...         ...       ...     ...
# 995            10.2147/copd.s33714  PMC3514010  23226013   no-cc
# 996          10.1186/2047-9158-1-9  PMC3514090  23210447   cc-by
# 997        10.1186/1746-6148-8-201  PMC3514206  23098237   cc-by
# 998   10.1371/journal.pone.0049778  PMC3514223  23226502   cc-by
# 999  10.1093/bioinformatics/bts575  PMC3516145  23044552   cc-by
#
#                                               abstract publish_time  ...  \
# 0    OBJECTIVE: This retrospective chart review des...   2001-07-04  ...
# 1    Inflammatory diseases of the respiratory tract...   2000-08-15  ...
# 2    Surfactant protein-D (SP-D) participates in th...   2000-08-25  ...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22  ...
# 4    Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11  ...
# ..                                                 ...          ...  ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...   2012-11-23  ...
# 996  It has been nearly a century since the early d...   2012-04-24  ...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...   2012-10-25  ...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...   2012-12-04  ...
# 999  Motivation: Laboratory RNA structure determina...   2012-12-01  ...
#
#                              journal mag_id who_covidence_id arxiv_id  \
# 0                     BMC Infect Dis   None             None     None
# 1                         Respir Res   None             None     None
# 2                         Respir Res   None             None     None
# 3                         Respir Res   None             None     None
# 4                         Respir Res   None             None     None
# ..                               ...    ...              ...      ...
# 995  Int J Chron Obstruct Pulmon Dis   None             None     None
# 996              Transl Neurodegener   None             None     None
# 997                      BMC Vet Res   None             None     None
# 998                         PLoS One   None             None     None
# 999                   Bioinformatics   None             None     None
#
#                                         pdf_json_files  \
# 0    document_parses/pdf_json/d1aafb70c066a2068b027...
# 1    document_parses/pdf_json/6b0567729c2143a66d737...
# 2    document_parses/pdf_json/06ced00a5fc04215949aa...
# 3    document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4    document_parses/pdf_json/5f48792a5fa08bed9f560...
# ..                                                 ...
# 995  document_parses/pdf_json/ed2de3694f5580ea38f4a...
# 996  document_parses/pdf_json/2a7c951e191425fd9fa5a...
# 997  document_parses/pdf_json/854e623d1f875e4605b2f...
# 998  document_parses/pdf_json/3695704554777889f8232...
# 999  document_parses/pdf_json/5a054a570f409d5c20063...
#
#                                    pmc_json_files  \
# 0      document_parses/pmc_json/PMC35282.xml.json
# 1      document_parses/pmc_json/PMC59543.xml.json
# 2      document_parses/pmc_json/PMC59549.xml.json
# 3      document_parses/pmc_json/PMC59574.xml.json
# 4      document_parses/pmc_json/PMC59580.xml.json
# ..                                            ...
# 995  document_parses/pmc_json/PMC3514010.xml.json
# 996  document_parses/pmc_json/PMC3514090.xml.json
# 997  document_parses/pmc_json/PMC3514206.xml.json
# 998  document_parses/pmc_json/PMC3514223.xml.json
# 999  document_parses/pmc_json/PMC3516145.xml.json
#
#                                                    url s2_id  \
# 0    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 1    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 2    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 3    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# 4    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  None
# ..                                                 ...   ...
# 995  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 996  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 997  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 998  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
# 999  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...  None
#
#                                               pr_title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                            pr_abstract
# 0    OBJECTIVE: This retrospective chart review des...
# 1    Inflammatory diseases of the respiratory tract...
# 2    Surfactant protein-D (SP-D) participates in th...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4    Respiratory syncytial virus (RSV) and pneumoni...
# ..                                                 ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...
# 996  It has been nearly a century since the early d...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...
# 999  Motivation: Laboratory RNA structure determina...
#
# [1000 rows x 21 columns]
# Creating index - covid
# b'{\n  "name" : "DESKTOP-K0D65LT",\n  "cluster_name" : "elasticsearch",\n  "cluster_uuid" : "P8VwA_sWSl-ykHakwwPzXQ",\n  "version" : {\n    "number" : "7.10.2",\n    "build_flavor" : "default",\n    "build_type" : "zip",\n    "build_hash" : "747e1cc71def077253878a59143c1f785afa92b9",\n    "build_date" : "2021-01-13T00:42:12.435326Z",\n    "build_snapshot" : false,\n    "lucene_version" : "8.7.0",\n    "minimum_wire_compatibility_version" : "6.8.0",\n    "minimum_index_compatibility_version" : "6.0.0-beta1"\n  },\n  "tagline" : "You Know, for Search"\n}\n'
# Indexing
# Data indexed.
# Sentence splitting, text tokenisation and normalisation
# C:\Conda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Conda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Comparison of Text Data after Sentence splitting, text tokenisation and normalisation step
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                               pr_title  \
# 0    [clinical features of culture proven mycoplasm...
# 1    [nitric oxide a pro inflammatory mediator in l...
# 2    [surfactant protein d and pulmonary host defense]
# 3                 [role of endothelin in lung disease]
# 4    [gene expression in epithelial cells in respon...
# ..                                                 ...
# 995  [mannose binding lectin deficiency and acute e...
# 996  [the changing phenotype of microglia from home...
# 997  [diversity of salmonella spp, serovars isolate...
# 998  [severe childhood malaria syndromes defined by...
# 999  [predicting pseudoknotted structures across tw...
#
#                                               abstract  \
# 0    OBJECTIVE: This retrospective chart review des...
# 1    Inflammatory diseases of the respiratory tract...
# 2    Surfactant protein-D (SP-D) participates in th...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4    Respiratory syncytial virus (RSV) and pneumoni...
# ..                                                 ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...
# 996  It has been nearly a century since the early d...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...
# 999  Motivation: Laboratory RNA structure determina...
#
#                                            pr_abstract
# 0    [objective this retrospective chart review des...
# 1    [inflammatory diseases of the respiratory trac...
# 2    [surfactant protein d sp d participates in the...
# 3    [endothelin et is a amino acid peptide with di...
# 4    [respiratory syncytial virus rsv and pneumonia...
# ..                                                 ...
# 995  [background mannose binding lectin is a collec...
# 996  [it has been nearly a century since the early ...
# 997  [background salmonellosis in water buffalo bub...
# 998  [background cerebral malaria cm and severe mal...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 4 columns]
# Selecting keywords
# Text Data after removing of stop-words
# C:\Conda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Conda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                               pr_title  \
# 0    [clinical features culture proven mycoplasma p...
# 1    [nitric oxide pro inflammatory mediator lung d...
# 2          [surfactant protein pulmonary host defense]
# 3                       [role endothelin lung disease]
# 4    [gene expression epithelial cells response pne...
# ..                                                 ...
# 995  [mannose binding lectin deficiency acute exace...
# 996  [changing phenotype microglia homeostasis dise...
# 997  [diversity salmonella spp, serovars isolated i...
# 998  [severe childhood malaria syndromes defined pl...
# 999  [predicting pseudoknotted structures across tw...
#
#                                            pr_abstract
# 0    [objective retrospective chart review describe...
# 1    [inflammatory diseases respiratory tract commo...
# 2    [surfactant protein participates innate respon...
# 3    [endothelin amino acid peptide diverse biologi...
# 4    [respiratory syncytial virus rsv pneumonia vir...
# ..                                                 ...
# 995  [background mannose binding lectin collectin i...
# 996  [nearly century since early description microg...
# 997  [background salmonellosis water buffalo bubalu...
# 998  [background cerebral malaria severe malarial a...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 2 columns]
# 133627
# Showing first 2000 top-freqent words in the corpus
#             Word  Frequency
# 1          virus        985
# 2      influenza        945
# 3      infection        740
# 4          cells        711
# 5       patients        587
# ...          ...        ...
# 996         find         28
# 997        great         28
# 998     duration         28
# 999   initiation         28
# 1000       sirna         28
#
# [1000 rows x 2 columns]
# Showing bigrams in the corpus found by Pointwise Mutual Information method
# Applying frequency filter: a bigramm occurs more than 7 times
#                      bigram        PMI
# 0               rift valley  13.857927
# 1     endoplasmic reticulum  13.705924
# 2    bronchoalveolar lavage  13.327412
# 3           coronary artery  13.327412
# 4      vesicular stomatitis  13.327412
# ..                      ...        ...
# 863             cells cells   1.665403
# 864           disease virus   1.581372
# 865       infection results   1.548103
# 866          pandemic virus   1.325173
# 867         infection human   1.179704
#
# [868 rows x 2 columns]
# Showing trigrams in the corpus found by Pointwise Mutual Information method
# Applying frequency filter: a trigramm occurs more than 5 times
#                                   trigram        PMI
# 0                           mov avg cusum  29.411848
# 1            cortex magnoliae officinalis  29.148813
# 2            systemic lupus erythematosus  25.663387
# 3             autoimmune hemolytic anemia  25.052889
# 4    methicillin resistant staphylococcus  24.947180
# ..                                    ...        ...
# 219           influenza virus replication   9.049636
# 220            influenza virus infections   8.849042
# 221          pandemic influenza infection   8.659061
# 222              response influenza virus   8.532673
# 223                 human influenza virus   7.425360
#
# [224 rows x 2 columns]
# Extracting keywords from texts using Pointwise Mutual Information method and TextRank
# Text 0 - Done
# Text 1 - Done
# Text 2 - Done
# Text 3 - Done
# Text 4 - Done
# Text 5 - Done
# Text 6 - Done
# Text 7 - Done
# Text 8 - Done
# Text 9 - Done
# Text 10 - Done
# Text 11 - Done
# Text 12 - Done
# Text 13 - Done
# Text 15 - Done
# Text 16 - Done
# Text 17 - Done
# Text 18 - Done
# Text 19 - Done
# Text 20 - Done
# Text 21 - Done
# Text 22 - Done
# Text 23 - Done
# Text 24 - Done
# Text 25 - Done
# Text 26 - Done
# Text 27 - Done
# Text 28 - Done
# Text 29 - Done
# Text 30 - Done
# Text 31 - Done
# Text 32 - Done
# Text 33 - Done
# Text 34 - Done
# Text 35 - Done
# Text 36 - Done
# Text 37 - Done
# Text 38 - Done
# Text 39 - Done
# Text 40 - Done
# Text 41 - Done
# Text 42 - Done
# Text 43 - Done
# Text 44 - Done
# Text 45 - Done
# Text 46 - Done
# Text 47 - Done
# Text 48 - Done
# Text 49 - Done
# Text 50 - Done
# Text 57 - Done
# Text 58 - Done
# Text 59 - Done
# Text 60 - Done
# Text 61 - Done
# Text 62 - Done
# Text 64 - Done
# Text 65 - Done
# Text 66 - Done
# Text 67 - Done
# Text 68 - Done
# Text 69 - Done
# Text 70 - Done
# Text 71 - Done
# Text 72 - Done
# Text 73 - Done
# Text 74 - Done
# Text 75 - Done
# Text 76 - Done
# Text 77 - Done
# Text 78 - Done
# Text 79 - Done
# Text 80 - Done
# Text 81 - Done
# Text 82 - Done
# Text 83 - Done
# Text 84 - Done
# Text 85 - Done
# Text 86 - Done
# Text 87 - Done
# Text 88 - Done
# Text 89 - Done
# Text 90 - Done
# Text 91 - Done
# Text 92 - Done
# Text 93 - Done
# Text 94 - Done
# Text 95 - Done
# Text 96 - Done
# Text 97 - Done
# Text 98 - Done
# Text 99 - Done
# Text 100 - Done
# Text 101 - Done
# Text 102 - Done
# Text 103 - Done
# Text 104 - Done
# Text 105 - Done
# Text 106 - Done
# Text 107 - Done
# Text 108 - Done
# Text 109 - Done
# Text 110 - Done
# Text 111 - Done
# Text 112 - Done
# Text 113 - Done
# Text 114 - Done
# Text 115 - Done
# Text 116 - Done
# Text 117 - Done
# Text 118 - Done
# Text 119 - Done
# Text 120 - Done
# Text 121 - Done
# Text 122 - Done
# Text 123 - Done
# Text 124 - Done
# Text 125 - Done
# Text 126 - Done
# Text 127 - Done
# Text 128 - Done
# Text 129 - Done
# Text 130 - Done
# Text 131 - Done
# Text 132 - Done
# Text 133 - Done
# Text 134 - Done
# Text 135 - Done
# Text 136 - Done
# Text 137 - Done
# Text 138 - Done
# Text 139 - Done
# Text 140 - Done
# Text 141 - Done
# Text 142 - Done
# Text 143 - Done
# Text 144 - Done
# Text 145 - Done
# Text 146 - Done
# Text 147 - Done
# Text 148 - Done
# Text 149 - Done
# Text 150 - Done
# Text 151 - Done
# Text 152 - Done
# Text 153 - Done
# Text 154 - Done
# Text 155 - Done
# Text 156 - Done
# Text 157 - Done
# Text 158 - Done
# Text 159 - Done
# Text 160 - Done
# Text 161 - Done
# Text 162 - Done
# Text 163 - Done
# Text 164 - Done
# Text 165 - Done
# Text 166 - Done
# Text 167 - Done
# Text 168 - Done
# Text 169 - Done
# Text 170 - Done
# Text 171 - Done
# Text 172 - Done
# Text 173 - Done
# Text 174 - Done
# Text 175 - Done
# Text 176 - Done
# Text 177 - Done
# Text 178 - Done
# Text 179 - Done
# Text 180 - Done
# Text 181 - Done
# Text 182 - Done
# Text 183 - Done
# Text 184 - Done
# Text 185 - Done
# Text 186 - Done
# Text 187 - Done
# Text 188 - Done
# Text 189 - Done
# Text 190 - Done
# Text 191 - Done
# Text 192 - Done
# Text 194 - Done
# Text 195 - Done
# Text 196 - Done
# Text 197 - Done
# Text 198 - Done
# Text 199 - Done
# Text 200 - Done
# Text 201 - Done
# Text 202 - Done
# Text 203 - Done
# Text 204 - Done
# Text 205 - Done
# Text 206 - Done
# Text 208 - Done
# Text 209 - Done
# Text 210 - Done
# Text 211 - Done
# Text 212 - Done
# Text 213 - Done
# Text 214 - Done
# Text 215 - Done
# Text 216 - Done
# Text 217 - Done
# Text 219 - Done
# Text 220 - Done
# Text 221 - Done
# Text 222 - Done
# Text 223 - Done
# Text 224 - Done
# Text 225 - Done
# Text 226 - Done
# Text 227 - Done
# Text 228 - Done
# Text 229 - Done
# Text 230 - Done
# Text 231 - Done
# Text 232 - Done
# Text 233 - Done
# Text 236 - Done
# Text 237 - Done
# Text 238 - Done
# Text 239 - Done
# Text 240 - Done
# Text 241 - Done
# Text 242 - Done
# Text 243 - Done
# Text 244 - Done
# Text 245 - Done
# Text 246 - Done
# Text 247 - Done
# Text 248 - Done
# Text 249 - Done
# Text 250 - Done
# Text 251 - Done
# Text 252 - Done
# Text 253 - Done
# Text 254 - Done
# Text 255 - Done
# Text 256 - Done
# Text 257 - Done
# Text 258 - Done
# Text 259 - Done
# Text 261 - Done
# Text 262 - Done
# Text 263 - Done
# Text 264 - Done
# Text 265 - Done
# Text 266 - Done
# Text 267 - Done
# Text 268 - Done
# Text 269 - Done
# Text 270 - Done
# Text 271 - Done
# Text 272 - Done
# Text 273 - Done
# Text 274 - Done
# Text 275 - Done
# Text 276 - Done
# Text 277 - Done
# Text 278 - Done
# Text 279 - Done
# Text 280 - Done
# Text 281 - Done
# Text 282 - Done
# Text 283 - Done
# Text 284 - Done
# Text 285 - Done
# Text 286 - Done
# Text 287 - Done
# Text 288 - Done
# Text 289 - Done
# Text 290 - Done
# Text 291 - Done
# Text 292 - Done
# Text 293 - Done
# Text 294 - Done
# Text 295 - Done
# Text 296 - Done
# Text 297 - Done
# Text 298 - Done
# Text 299 - Done
# Text 300 - Done
# Text 301 - Done
# Text 302 - Done
# Text 303 - Done
# Text 305 - Done
# Text 306 - Done
# Text 308 - Done
# Text 309 - Done
# Text 310 - Done
# Text 311 - Done
# Text 312 - Done
# Text 313 - Done
# Text 314 - Done
# Text 315 - Done
# Text 316 - Done
# Text 317 - Done
# Text 318 - Done
# Text 320 - Done
# Text 321 - Done
# Text 322 - Done
# Text 323 - Done
# Text 324 - Done
# Text 325 - Done
# Text 326 - Done
# Text 327 - Done
# Text 328 - Done
# Text 329 - Done
# Text 330 - Done
# Text 331 - Done
# Text 332 - Done
# Text 333 - Done
# Text 334 - Done
# Text 335 - Done
# Text 336 - Done
# Text 337 - Done
# Text 338 - Done
# Text 339 - Done
# Text 341 - Done
# Text 342 - Done
# Text 343 - Done
# Text 344 - Done
# Text 345 - Done
# Text 346 - Done
# Text 347 - Done
# Text 348 - Done
# Text 349 - Done
# Text 350 - Done
# Text 351 - Done
# Text 352 - Done
# Text 353 - Done
# Text 354 - Done
# Text 355 - Done
# Text 356 - Done
# Text 357 - Done
# Text 358 - Done
# Text 359 - Done
# Text 360 - Done
# Text 361 - Done
# Text 362 - Done
# Text 363 - Done
# Text 364 - Done
# Text 365 - Done
# Text 366 - Done
# Text 367 - Done
# Text 368 - Done
# Text 369 - Done
# Text 370 - Done
# Text 371 - Done
# Text 372 - Done
# Text 373 - Done
# Text 374 - Done
# Text 376 - Done
# Text 377 - Done
# Text 378 - Done
# Text 379 - Done
# Text 380 - Done
# Text 381 - Done
# Text 382 - Done
# Text 383 - Done
# Text 384 - Done
# Text 385 - Done
# Text 386 - Done
# Text 387 - Done
# Text 388 - Done
# Text 389 - Done
# Text 390 - Done
# Text 391 - Done
# Text 392 - Done
# Text 393 - Done
# Text 394 - Done
# Text 396 - Done
# Text 397 - Done
# Text 398 - Done
# Text 399 - Done
# Text 400 - Done
# Text 401 - Done
# Text 402 - Done
# Text 403 - Done
# Text 404 - Done
# Text 405 - Done
# Text 406 - Done
# Text 407 - Done
# Text 408 - Done
# Text 409 - Done
# Text 410 - Done
# Text 411 - Done
# Text 412 - Done
# Text 413 - Done
# Text 414 - Done
# Text 415 - Done
# Text 416 - Done
# Text 417 - Done
# Text 418 - Done
# Text 419 - Done
# Text 421 - Done
# Text 422 - Done
# Text 423 - Done
# Text 424 - Done
# Text 425 - Done
# Text 426 - Done
# Text 427 - Done
# Text 428 - Done
# Text 429 - Done
# Text 430 - Done
# Text 431 - Done
# Text 432 - Done
# Text 433 - Done
# Text 434 - Done
# Text 435 - Done
# Text 436 - Done
# Text 437 - Done
# Text 438 - Done
# Text 439 - Done
# Text 440 - Done
# Text 441 - Done
# Text 442 - Done
# Text 443 - Done
# Text 444 - Done
# Text 445 - Done
# Text 446 - Done
# Text 447 - Done
# Text 448 - Done
# Text 449 - Done
# Text 450 - Done
# Text 451 - Done
# Text 452 - Done
# Text 453 - Done
# Text 454 - Done
# Text 455 - Done
# Text 456 - Done
# Text 457 - Done
# Text 458 - Done
# Text 459 - Done
# Text 460 - Done
# Text 461 - Done
# Text 462 - Done
# Text 463 - Done
# Text 464 - Done
# Text 465 - Done
# Text 466 - Done
# Text 467 - Done
# Text 468 - Done
# Text 469 - Done
# Text 470 - Done
# Text 471 - Done
# Text 472 - Done
# Text 473 - Done
# Text 474 - Done
# Text 475 - Done
# Text 476 - Done
# Text 477 - Done
# Text 478 - Done
# Text 479 - Done
# Text 480 - Done
# Text 481 - Done
# Text 482 - Done
# Text 483 - Done
# Text 484 - Done
# Text 485 - Done
# Text 486 - Done
# Text 488 - Done
# Text 489 - Done
# Text 490 - Done
# Text 491 - Done
# Text 492 - Done
# Text 493 - Done
# Text 494 - Done
# Text 495 - Done
# Text 496 - Done
# Text 497 - Done
# Text 498 - Done
# Text 499 - Done
# Text 500 - Done
# Text 501 - Done
# Text 502 - Done
# Text 503 - Done
# Text 504 - Done
# Text 505 - Done
# Text 506 - Done
# Text 507 - Done
# Text 508 - Done
# Text 509 - Done
# Text 510 - Done
# Text 511 - Done
# Text 512 - Done
# Text 513 - Done
# Text 514 - Done
# Text 515 - Done
# Text 516 - Done
# Text 517 - Done
# Text 518 - Done
# Text 519 - Done
# Text 520 - Done
# Text 521 - Done
# Text 523 - Done
# Text 524 - Done
# Text 525 - Done
# Text 526 - Done
# Text 527 - Done
# Text 528 - Done
# Text 529 - Done
# Text 530 - Done
# Text 531 - Done
# Text 532 - Done
# Text 533 - Done
# Text 534 - Done
# Text 535 - Done
# Text 536 - Done
# Text 537 - Done
# Text 538 - Done
# Text 539 - Done
# Text 540 - Done
# Text 541 - Done
# Text 542 - Done
# Text 543 - Done
# Text 544 - Done
# Text 545 - Done
# Text 546 - Done
# Text 547 - Done
# Text 548 - Done
# Text 549 - Done
# Text 550 - Done
# Text 551 - Done
# Text 552 - Done
# Text 553 - Done
# Text 554 - Done
# Text 555 - Done
# Text 556 - Done
# Text 557 - Done
# Text 558 - Done
# Text 559 - Done
# Text 560 - Done
# Text 561 - Done
# Text 562 - Done
# Text 563 - Done
# Text 564 - Done
# Text 566 - Done
# Text 567 - Done
# Text 568 - Done
# Text 569 - Done
# Text 571 - Done
# Text 572 - Done
# Text 573 - Done
# Text 574 - Done
# Text 575 - Done
# Text 576 - Done
# Text 577 - Done
# Text 578 - Done
# Text 579 - Done
# Text 580 - Done
# Text 581 - Done
# Text 582 - Done
# Text 583 - Done
# Text 584 - Done
# Text 585 - Done
# Text 586 - Done
# Text 587 - Done
# Text 588 - Done
# Text 589 - Done
# Text 590 - Done
# Text 591 - Done
# Text 592 - Done
# Text 593 - Done
# Text 594 - Done
# Text 595 - Done
# Text 596 - Done
# Text 597 - Done
# Text 598 - Done
# Text 599 - Done
# Text 600 - Done
# Text 601 - Done
# Text 602 - Done
# Text 603 - Done
# Text 604 - Done
# Text 605 - Done
# Text 606 - Done
# Text 607 - Done
# Text 608 - Done
# Text 609 - Done
# Text 610 - Done
# Text 611 - Done
# Text 612 - Done
# Text 613 - Done
# Text 614 - Done
# Text 615 - Done
# Text 617 - Done
# Text 618 - Done
# Text 619 - Done
# Text 620 - Done
# Text 621 - Done
# Text 622 - Done
# Text 623 - Done
# Text 624 - Done
# Text 625 - Done
# Text 626 - Done
# Text 627 - Done
# Text 628 - Done
# Text 629 - Done
# Text 630 - Done
# Text 631 - Done
# Text 632 - Done
# Text 633 - Done
# Text 634 - Done
# Text 635 - Done
# Text 636 - Done
# Text 637 - Done
# Text 638 - Done
# Text 639 - Done
# Text 640 - Done
# Text 641 - Done
# Text 642 - Done
# Text 643 - Done
# Text 644 - Done
# Text 645 - Done
# Text 646 - Done
# Text 647 - Done
# Text 648 - Done
# Text 649 - Done
# Text 650 - Done
# Text 651 - Done
# Text 652 - Done
# Text 653 - Done
# Text 654 - Done
# Text 655 - Done
# Text 656 - Done
# Text 657 - Done
# Text 658 - Done
# Text 659 - Done
# Text 660 - Done
# Text 661 - Done
# Text 662 - Done
# Text 663 - Done
# Text 664 - Done
# Text 665 - Done
# Text 666 - Done
# Text 667 - Done
# Text 668 - Done
# Text 669 - Done
# Text 670 - Done
# Text 672 - Done
# Text 674 - Done
# Text 675 - Done
# Text 676 - Done
# Text 677 - Done
# Text 678 - Done
# Text 679 - Done
# Text 680 - Done
# Text 681 - Done
# Text 682 - Done
# Text 683 - Done
# Text 684 - Done
# Text 685 - Done
# Text 686 - Done
# Text 687 - Done
# Text 688 - Done
# Text 689 - Done
# Text 690 - Done
# Text 691 - Done
# Text 692 - Done
# Text 693 - Done
# Text 694 - Done
# Text 695 - Done
# Text 696 - Done
# Text 697 - Done
# Text 698 - Done
# Text 699 - Done
# Text 700 - Done
# Text 701 - Done
# Text 702 - Done
# Text 703 - Done
# Text 704 - Done
# Text 705 - Done
# Text 706 - Done
# Text 707 - Done
# Text 708 - Done
# Text 709 - Done
# Text 710 - Done
# Text 711 - Done
# Text 712 - Done
# Text 713 - Done
# Text 714 - Done
# Text 715 - Done
# Text 716 - Done
# Text 717 - Done
# Text 718 - Done
# Text 719 - Done
# Text 720 - Done
# Text 721 - Done
# Text 722 - Done
# Text 723 - Done
# Text 724 - Done
# Text 725 - Done
# Text 726 - Done
# Text 727 - Done
# Text 728 - Done
# Text 729 - Done
# Text 730 - Done
# Text 731 - Done
# Text 733 - Done
# Text 734 - Done
# Text 735 - Done
# Text 736 - Done
# Text 737 - Done
# Text 738 - Done
# Text 739 - Done
# Text 740 - Done
# Text 741 - Done
# Text 742 - Done
# Text 743 - Done
# Text 744 - Done
# Text 745 - Done
# Text 746 - Done
# Text 747 - Done
# Text 748 - Done
# Text 749 - Done
# Text 750 - Done
# Text 751 - Done
# Text 752 - Done
# Text 753 - Done
# Text 754 - Done
# Text 755 - Done
# Text 756 - Done
# Text 757 - Done
# Text 758 - Done
# Text 762 - Done
# Text 763 - Done
# Text 764 - Done
# Text 765 - Done
# Text 766 - Done
# Text 767 - Done
# Text 768 - Done
# Text 770 - Done
# Text 771 - Done
# Text 772 - Done
# Text 773 - Done
# Text 774 - Done
# Text 776 - Done
# Text 777 - Done
# Text 778 - Done
# Text 779 - Done
# Text 780 - Done
# Text 781 - Done
# Text 782 - Done
# Text 783 - Done
# Text 784 - Done
# Text 785 - Done
# Text 786 - Done
# Text 787 - Done
# Text 788 - Done
# Text 789 - Done
# Text 790 - Done
# Text 791 - Done
# Text 792 - Done
# Text 793 - Done
# Text 794 - Done
# Text 795 - Done
# Text 796 - Done
# Text 797 - Done
# Text 798 - Done
# Text 799 - Done
# Text 800 - Done
# Text 801 - Done
# Text 802 - Done
# Text 803 - Done
# Text 804 - Done
# Text 805 - Done
# Text 806 - Done
# Text 807 - Done
# Text 811 - Done
# Text 812 - Done
# Text 813 - Done
# Text 814 - Done
# Text 815 - Done
# Text 816 - Done
# Text 817 - Done
# Text 818 - Done
# Text 819 - Done
# Text 820 - Done
# Text 821 - Done
# Text 822 - Done
# Text 823 - Done
# Text 824 - Done
# Text 825 - Done
# Text 826 - Done
# Text 827 - Done
# Text 828 - Done
# Text 829 - Done
# Text 830 - Done
# Text 831 - Done
# Text 832 - Done
# Text 833 - Done
# Text 834 - Done
# Text 835 - Done
# Text 836 - Done
# Text 837 - Done
# Text 838 - Done
# Text 839 - Done
# Text 840 - Done
# Text 841 - Done
# Text 842 - Done
# Text 843 - Done
# Text 845 - Done
# Text 846 - Done
# Text 847 - Done
# Text 849 - Done
# Text 850 - Done
# Text 851 - Done
# Text 852 - Done
# Text 853 - Done
# Text 854 - Done
# Text 855 - Done
# Text 856 - Done
# Text 857 - Done
# Text 858 - Done
# Text 859 - Done
# Text 860 - Done
# Text 861 - Done
# Text 862 - Done
# Text 863 - Done
# Text 864 - Done
# Text 866 - Done
# Text 867 - Done
# Text 869 - Done
# Text 870 - Done
# Text 871 - Done
# Text 872 - Done
# Text 873 - Done
# Text 874 - Done
# Text 875 - Done
# Text 877 - Done
# Text 878 - Done
# Text 879 - Done
# Text 880 - Done
# Text 881 - Done
# Text 882 - Done
# Text 883 - Done
# Text 884 - Done
# Text 885 - Done
# Text 886 - Done
# Text 887 - Done
# Text 888 - Done
# Text 889 - Done
# Text 890 - Done
# Text 891 - Done
# Text 892 - Done
# Text 893 - Done
# Text 894 - Done
# Text 896 - Done
# Text 897 - Done
# Text 898 - Done
# Text 899 - Done
# Text 900 - Done
# Text 901 - Done
# Text 902 - Done
# Text 903 - Done
# Text 904 - Done
# Text 905 - Done
# Text 906 - Done
# Text 907 - Done
# Text 908 - Done
# Text 909 - Done
# Text 910 - Done
# Text 911 - Done
# Text 912 - Done
# Text 913 - Done
# Text 914 - Done
# Text 915 - Done
# Text 916 - Done
# Text 917 - Done
# Text 918 - Done
# Text 919 - Done
# Text 920 - Done
# Text 921 - Done
# Text 922 - Done
# Text 923 - Done
# Text 924 - Done
# Text 925 - Done
# Text 926 - Done
# Text 927 - Done
# Text 928 - Done
# Text 929 - Done
# Text 930 - Done
# Text 931 - Done
# Text 932 - Done
# Text 933 - Done
# Text 934 - Done
# Text 935 - Done
# Text 936 - Done
# Text 937 - Done
# Text 938 - Done
# Text 939 - Done
# Text 940 - Done
# Text 941 - Done
# Text 942 - Done
# Text 943 - Done
# Text 944 - Done
# Text 945 - Done
# Text 946 - Done
# Text 947 - Done
# Text 948 - Done
# Text 949 - Done
# Text 950 - Done
# Text 951 - Done
# Text 952 - Done
# Text 953 - Done
# Text 954 - Done
# Text 955 - Done
# Text 956 - Done
# Text 957 - Done
# Text 958 - Done
# Text 959 - Done
# Text 960 - Done
# Text 961 - Done
# Text 962 - Done
# Text 963 - Done
# Text 964 - Done
# Text 965 - Done
# Text 966 - Done
# Text 968 - Done
# Text 969 - Done
# Text 970 - Done
# Text 971 - Done
# Text 972 - Done
# Text 973 - Done
# Text 974 - Done
# Text 975 - Done
# Text 976 - Done
# Text 977 - Done
# Text 978 - Done
# Text 979 - Done
# Text 980 - Done
# Text 981 - Done
# Text 982 - Done
# Text 983 - Done
# Text 984 - Done
# Text 985 - Done
# Text 986 - Done
# Text 987 - Done
# Text 988 - Done
# Text 989 - Done
# Text 990 - Done
# Text 991 - Done
# Text 992 - Done
# Text 993 - Done
# Text 994 - Done
# Text 995 - Done
# Text 996 - Done
# Text 997 - Done
# Text 998 - Done
# Text 999 - Done
# 1868
# 19754
# 19754
# C:\Conda\lib\site-packages\ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Comparison of Text Data after Keywords Extraction using Pointwise Mutual Information method and TextRank
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                               pr_title  \
# 0    [clinical features culture proven mycoplasma p...
# 1    [nitric oxide pro inflammatory mediator lung d...
# 2          [surfactant protein pulmonary host defense]
# 3                       [role endothelin lung disease]
# 4    [gene expression epithelial cells response pne...
# ..                                                 ...
# 995  [mannose binding lectin deficiency acute exace...
# 996  [changing phenotype microglia homeostasis dise...
# 997  [diversity salmonella spp, serovars isolated i...
# 998  [severe childhood malaria syndromes defined pl...
# 999  [predicting pseudoknotted structures across tw...
#
#                                               abstract  \
# 0    OBJECTIVE: This retrospective chart review des...
# 1    Inflammatory diseases of the respiratory tract...
# 2    Surfactant protein-D (SP-D) participates in th...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4    Respiratory syncytial virus (RSV) and pneumoni...
# ..                                                 ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...
# 996  It has been nearly a century since the early d...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...
# 999  Motivation: Laboratory RNA structure determina...
#
#                                            pr_abstract
# 0    [objective_retrospective_chart_review epidemio...
# 1    [inflammatory_diseases respiratory_tract commo...
# 2    [surfactant_protein_participates response micr...
# 3    [endothelin_amino_acid_peptide_diverse_biologi...
# 4    [respiratory_syncytial_virus_rsv_pneumonia_vir...
# ..                                                 ...
# 995  [background_mannose_binding_lectin_collectin h...
# 996  [century early_description_microglia_rio many_...
# 997  [background_salmonellosis_water_buffalo_bubalu...
# 998  [background_cerebral_malaria serious_life clin...
# 999  [motivation_laboratory_rna_structure_determina...
#
# [1000 rows x 4 columns]
# Extracting keywords from texts using TF/IDF
# Comparison of Text Data after Selecting keywords step
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                               pr_title  \
# 0    [clinical features culture proven mycoplasma p...
# 1    [nitric oxide pro inflammatory mediator lung d...
# 2          [surfactant protein pulmonary host defense]
# 3                       [role endothelin lung disease]
# 4    [gene expression epithelial cells response pne...
# ..                                                 ...
# 995  [mannose binding lectin deficiency acute exace...
# 996  [changing phenotype microglia homeostasis dise...
# 997  [diversity salmonella spp, serovars isolated i...
# 998  [severe childhood malaria syndromes defined pl...
# 999  [predicting pseudoknotted structures across tw...
#
#                                               abstract  \
# 0    OBJECTIVE: This retrospective chart review des...
# 1    Inflammatory diseases of the respiratory tract...
# 2    Surfactant protein-D (SP-D) participates in th...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4    Respiratory syncytial virus (RSV) and pneumoni...
# ..                                                 ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...
# 996  It has been nearly a century since the early d...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...
# 999  Motivation: Laboratory RNA structure determina...
#
#                                            pr_abstract
# 0    [objective retrospective chart review epidemio...
# 1    [inflammatory diseases respiratory tract commo...
# 2    [surfactant protein participates response micr...
# 3    [endothelin amino acid peptide diverse biologi...
# 4    [respiratory syncytial virus rsv pneumonia vir...
# ..                                                 ...
# 995  [background mannose binding lectin collectin h...
# 996  [century early description microglia rio many ...
# 997  [, , present study, water buffalo calves typhi...
# 998  [background cerebral malaria serious life clin...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 4 columns]
# Text lemmatisation
# Comparison of Text Data after Applied Lemmatisation
#                                                  title  \
# 0    Clinical features of culture-proven Mycoplasma...
# 1    Nitric oxide: a pro-inflammatory mediator in l...
# 2      Surfactant protein-D and pulmonary host defense
# 3                 Role of endothelin-1 in lung disease
# 4    Gene expression in epithelial cells in respons...
# ..                                                 ...
# 995  Mannose-binding lectin deficiency and acute ex...
# 996  The changing phenotype of microglia from homeo...
# 997  Diversity of Salmonella spp. serovars isolated...
# 998  Severe Childhood Malaria Syndromes Defined by ...
# 999  Predicting pseudoknotted structures across two...
#
#                                               pr_title  \
# 0    [clinical feature culture proven mycoplasma pn...
# 1    [nitric oxide pro inflammatory mediator lung d...
# 2          [surfactant protein pulmonary host defense]
# 3                       [role endothelin lung disease]
# 4    [gene expression epithelial cell response pneu...
# ..                                                 ...
# 995  [mannose binding lectin deficiency acute exace...
# 996  [changing phenotype microglia homeostasis dise...
# 997  [diversity salmonella spp, serovars isolated i...
# 998  [severe childhood malaria syndrome defined pla...
# 999  [predicting pseudoknotted structure across two...
#
#                                               abstract  \
# 0    OBJECTIVE: This retrospective chart review des...
# 1    Inflammatory diseases of the respiratory tract...
# 2    Surfactant protein-D (SP-D) participates in th...
# 3    Endothelin-1 (ET-1) is a 21 amino acid peptide...
# 4    Respiratory syncytial virus (RSV) and pneumoni...
# ..                                                 ...
# 995  BACKGROUND: Mannose-binding lectin is a collec...
# 996  It has been nearly a century since the early d...
# 997  BACKGROUND: Salmonellosis in water buffalo (Bu...
# 998  BACKGROUND: Cerebral malaria (CM) and severe m...
# 999  Motivation: Laboratory RNA structure determina...
#
#                                            pr_abstract
# 0    [objective retrospective chart review epidemio...
# 1    [inflammatory disease respiratory tract common...
# 2    [surfactant protein participates response micr...
# 3    [endothelin amino acid peptide diverse biologi...
# 4    [respiratory syncytial virus rsv pneumonia vir...
# ..                                                 ...
# 995  [background mannose binding lectin collectin h...
# 996  [century early description microglia rio many ...
# 997  [, , present study, water buffalo calf typhimu...
# 998  [background cerebral malaria serious life clin...
# 999  [motivation laboratory rna structure determina...
#
# [1000 rows x 4 columns]
# Creating index - covid
# b'{\n  "name" : "DESKTOP-K0D65LT",\n  "cluster_name" : "elasticsearch",\n  "cluster_uuid" : "P8VwA_sWSl-ykHakwwPzXQ",\n  "version" : {\n    "number" : "7.10.2",\n    "build_flavor" : "default",\n    "build_type" : "zip",\n    "build_hash" : "747e1cc71def077253878a59143c1f785afa92b9",\n    "build_date" : "2021-01-13T00:42:12.435326Z",\n    "build_snapshot" : false,\n    "lucene_version" : "8.7.0",\n    "minimum_wire_compatibility_version" : "6.8.0",\n    "minimum_index_compatibility_version" : "6.0.0-beta1"\n  },\n  "tagline" : "You Know, for Search"\n}\n'
# Indexing
# Searching in ElasticSearch
# Retrieved documents:
# [{'abstract': 'Inflammatory diseases of the respiratory tract are commonly '
#               'associated with elevated production of nitric oxide (NO•) and '
#               'increased indices of NO• -dependent oxidative stress. Although '
#               'NO• is known to have anti-microbial, anti-inflammatory and '
#               'anti-oxidant properties, various lines of evidence support the '
#               'contribution of NO• to lung injury in several disease models. '
#               'On the basis of biochemical evidence, it is often presumed that '
#               'such NO• -dependent oxidations are due to the formation of the '
#               'oxidant peroxynitrite, although alternative mechanisms '
#               'involving the phagocyte-derived heme proteins myeloperoxidase '
#               'and eosinophil peroxidase might be operative during conditions '
#               'of inflammation. Because of the overwhelming literature on NO• '
#               'generation and activities in the respiratory tract, it would be '
#               'beyond the scope of this commentary to review this area '
#               'comprehensively. Instead, it focuses on recent evidence and '
#               'concepts of the presumed contribution of NO• to inflammatory '
#               'diseases of the lung.',
#   'arxiv_id': None,
#   'authors': 'Vliet, Albert van der; Eiserich, Jason P; Cross, Carroll E',
#   'cord_uid': '02tnwd4m',
#   'doi': '10.1186/rr14',
#   'journal': 'Respir Res',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/6b0567729c2143a66d737eb0a2f63f2dce2e5a7d.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC59543.xml.json',
#   'pmcid': 'PMC59543',
#   'pr_abstract': ['inflammatory disease respiratory tract commonly associated '
#                   'elevated production nitric oxide index dependent oxidative '
#                   'stress',
#                   'property various line evidence support contribution lung '
#                   'injury several disease model',
#                   'basis biochemical evidence dependent oxidation formation '
#                   'alternative mechanism phagocyte heme protein eosinophil '
#                   'peroxidase condition inflammation',
#                   'overwhelming literature generation activity respiratory '
#                   'tract scope commentary review area',
#                   'recent evidence concept presumed contribution inflammatory '
#                   'disease lung',
#                   'literature generation respiratory tract area',
#                   'basis evidence dependent formation although alternative '
#                   'condition inflammation',
#                   'inflammatory disease respiratory tract commonly nitric '
#                   'oxide dependent oxidative stress',
#                   'although anti anti inflammatory anti property line evidence '
#                   'lung injury',
#                   'evidence inflammatory disease lung'],
#   'pr_title': ['nitric oxide pro inflammatory mediator lung disease'],
#   'publish_time': '2000-08-15',
#   'pubmed_id': '11667967',
#   's2_id': None,
#   'sha': '6b0567729c2143a66d737eb0a2f63f2dce2e5a7d',
#   'source_x': 'PMC',
#   'title': 'Nitric oxide: a pro-inflammatory mediator in lung disease?',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC59543/',
#   'who_covidence_id': None}]
# Retrieved documents:
# [{'abstract': 'Inflammatory diseases of the respiratory tract are commonly '
#               'associated with elevated production of nitric oxide (NO•) and '
#               'increased indices of NO• -dependent oxidative stress. Although '
#               'NO• is known to have anti-microbial, anti-inflammatory and '
#               'anti-oxidant properties, various lines of evidence support the '
#               'contribution of NO• to lung injury in several disease models. '
#               'On the basis of biochemical evidence, it is often presumed that '
#               'such NO• -dependent oxidations are due to the formation of the '
#               'oxidant peroxynitrite, although alternative mechanisms '
#               'involving the phagocyte-derived heme proteins myeloperoxidase '
#               'and eosinophil peroxidase might be operative during conditions '
#               'of inflammation. Because of the overwhelming literature on NO• '
#               'generation and activities in the respiratory tract, it would be '
#               'beyond the scope of this commentary to review this area '
#               'comprehensively. Instead, it focuses on recent evidence and '
#               'concepts of the presumed contribution of NO• to inflammatory '
#               'diseases of the lung.',
#   'arxiv_id': None,
#   'authors': 'Vliet, Albert van der; Eiserich, Jason P; Cross, Carroll E',
#   'cord_uid': '02tnwd4m',
#   'doi': '10.1186/rr14',
#   'journal': 'Respir Res',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/6b0567729c2143a66d737eb0a2f63f2dce2e5a7d.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC59543.xml.json',
#   'pmcid': 'PMC59543',
#   'pr_abstract': ['inflammatory disease respiratory tract commonly associated '
#                   'elevated production nitric oxide index dependent oxidative '
#                   'stress',
#                   'property various line evidence support contribution lung '
#                   'injury several disease model',
#                   'basis biochemical evidence dependent oxidation formation '
#                   'alternative mechanism phagocyte heme protein eosinophil '
#                   'peroxidase condition inflammation',
#                   'overwhelming literature generation activity respiratory '
#                   'tract scope commentary review area',
#                   'recent evidence concept presumed contribution inflammatory '
#                   'disease lung',
#                   'literature generation respiratory tract area',
#                   'basis evidence dependent formation although alternative '
#                   'condition inflammation',
#                   'inflammatory disease respiratory tract commonly nitric '
#                   'oxide dependent oxidative stress',
#                   'although anti anti inflammatory anti property line evidence '
#                   'lung injury',
#                   'evidence inflammatory disease lung'],
#   'pr_title': ['nitric oxide pro inflammatory mediator lung disease'],
#   'publish_time': '2000-08-15',
#   'pubmed_id': '11667967',
#   's2_id': None,
#   'sha': '6b0567729c2143a66d737eb0a2f63f2dce2e5a7d',
#   'source_x': 'PMC',
#   'title': 'Nitric oxide: a pro-inflammatory mediator in lung disease?',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC59543/',
#   'who_covidence_id': None}]

# %%
documents=search(es, es_index="covid",
    query={
          "query": {
            "match_phrase":{"publish_time":"2000-08-15"}
          }
        })
print("Retrieved documents:")
pprint.pprint(documents)
# Out:
# Retrieved documents:
# [{'abstract': 'Inflammatory diseases of the respiratory tract are commonly '
#               'associated with elevated production of nitric oxide (NO•) and '
#               'increased indices of NO• -dependent oxidative stress. Although '
#               'NO• is known to have anti-microbial, anti-inflammatory and '
#               'anti-oxidant properties, various lines of evidence support the '
#               'contribution of NO• to lung injury in several disease models. '
#               'On the basis of biochemical evidence, it is often presumed that '
#               'such NO• -dependent oxidations are due to the formation of the '
#               'oxidant peroxynitrite, although alternative mechanisms '
#               'involving the phagocyte-derived heme proteins myeloperoxidase '
#               'and eosinophil peroxidase might be operative during conditions '
#               'of inflammation. Because of the overwhelming literature on NO• '
#               'generation and activities in the respiratory tract, it would be '
#               'beyond the scope of this commentary to review this area '
#               'comprehensively. Instead, it focuses on recent evidence and '
#               'concepts of the presumed contribution of NO• to inflammatory '
#               'diseases of the lung.',
#   'arxiv_id': None,
#   'authors': 'Vliet, Albert van der; Eiserich, Jason P; Cross, Carroll E',
#   'cord_uid': '02tnwd4m',
#   'doi': '10.1186/rr14',
#   'journal': 'Respir Res',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/6b0567729c2143a66d737eb0a2f63f2dce2e5a7d.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC59543.xml.json',
#   'pmcid': 'PMC59543',
#   'pr_abstract': ['inflammatory disease respiratory tract commonly associated '
#                   'elevated production nitric oxide index dependent oxidative '
#                   'stress',
#                   'property various line evidence support contribution lung '
#                   'injury several disease model',
#                   'basis biochemical evidence dependent oxidation formation '
#                   'alternative mechanism phagocyte heme protein eosinophil '
#                   'peroxidase condition inflammation',
#                   'overwhelming literature generation activity respiratory '
#                   'tract scope commentary review area',
#                   'recent evidence concept presumed contribution inflammatory '
#                   'disease lung',
#                   'literature generation respiratory tract area',
#                   'basis evidence dependent formation although alternative '
#                   'condition inflammation',
#                   'inflammatory disease respiratory tract commonly nitric '
#                   'oxide dependent oxidative stress',
#                   'although anti anti inflammatory anti property line evidence '
#                   'lung injury',
#                   'evidence inflammatory disease lung'],
#   'pr_title': ['nitric oxide pro inflammatory mediator lung disease'],
#   'publish_time': '2000-08-15',
#   'pubmed_id': '11667967',
#   's2_id': None,
#   'sha': '6b0567729c2143a66d737eb0a2f63f2dce2e5a7d',
#   'source_x': 'PMC',
#   'title': 'Nitric oxide: a pro-inflammatory mediator in lung disease?',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC59543/',
#   'who_covidence_id': None}]

# %%
documents=search(es, es_index="covid",
    query={
          "query": {
            "match_phrase":{"pr_abstract":"biological diversity"}
          }
        })
print("Retrieved documents:")
pprint.pprint(documents)
# Out:
# Retrieved documents:
# [{'abstract': 'Sapovirus is a genus of caliciviruses that are known to cause '
#               'enteric disease in humans and animals. There is considerable '
#               'genetic diversity among the sapoviruses, which are classified '
#               'into different genogroups based on phylogenetic analysis of the '
#               'full-length capsid protein sequence. While several mammalian '
#               'species, including humans, pigs, minks, and dogs, have been '
#               'identified as animal hosts for sapoviruses, there were no '
#               'reports of sapoviruses in bats in spite of their biological '
#               'diversity. In this report, we present the results of a targeted '
#               'surveillance study in different bat species in Hong Kong. Five '
#               'of the 321 specimens from the bat species, Hipposideros pomona, '
#               'were found to be positive for sapoviruses by RT-PCR. Complete '
#               'or nearly full-length genome sequences of approximately 7.7 kb '
#               'in length were obtained for three strains, which showed similar '
#               'organization of the genome compared to other sapoviruses. '
#               'Interestingly, they possess many genomic features atypical of '
#               'most sapoviruses, like high G+C content and minimal CpG '
#               'suppression. Phylogenetic analysis of the viral proteins '
#               'suggested that the bat sapovirus descended from an ancestral '
#               'sapovirus lineage and is most closely related to the porcine '
#               'sapoviruses. Codon usage analysis showed that the bat sapovirus '
#               'genome has greater codon usage bias relative to other sapovirus '
#               'genomes. In summary, we report the discovery and genomic '
#               'characterization of the first bat calicivirus, which appears to '
#               'have evolved under different conditions after early divergence '
#               'from other sapovirus lineages.',
#   'arxiv_id': None,
#   'authors': 'Tse, Herman; Chan, Wan-Mui; Li, Kenneth S. M.; Lau, Susanna K. '
#              'P.; Woo, Patrick C. Y.; Yuen, Kwok-Yung',
#   'cord_uid': 'alyn1i00',
#   'doi': '10.1371/journal.pone.0034987',
#   'journal': 'PLoS One',
#   'license': 'cc-by',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/dbf7ea2d45fff41a73853c26e5fca9862fd0edcc.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC3325917.xml.json',
#   'pmcid': 'PMC3325917',
#   'pr_abstract': ['sapovirus genus caliciviruses cause enteric disease human '
#                   'animal',
#                   'considerable genetic diversity sapoviruses classified '
#                   'different genogroups based phylogenetic analysis full '
#                   'length capsid protein sequence',
#                   'several mammalian specie human mink dog animal host '
#                   'sapoviruses report sapoviruses bat biological diversity',
#                   'surveillance study specie hong kong',
#                   'specie positive sapoviruses',
#                   'full length genome sequence strain similar organization '
#                   'genome sapoviruses',
#                   'many genomic feature atypical sapoviruses',
#                   'phylogenetic analysis viral protein bat sapovirus ancestral '
#                   'sapovirus lineage closely related porcine sapoviruses',
#                   'codon usage analysis bat sapovirus genome greater codon '
#                   'usage bias relative sapovirus genome',
#                   'summary report discovery genomic characterization first bat '
#                   'calicivirus different condition early divergence sapovirus '
#                   'lineage',
#                   'specie human report',
#                   'full length genome sequence strain genome',
#                   'codon usage genome codon usage genome',
#                   'different phylogenetic analysis full length',
#                   'cause human animal',
#                   'report different specie hong kong',
#                   'phylogenetic analysis viral protein',
#                   'genomic',
#                   'report genomic different',
#                   'specie'],
#   'pr_title': ['discovery genomic characterization novel bat sapovirus unusual '
#                'genomic feature phylogenetic position'],
#   'publish_time': '2012-04-13',
#   'pubmed_id': '22514697',
#   's2_id': None,
#   'sha': 'dbf7ea2d45fff41a73853c26e5fca9862fd0edcc',
#   'source_x': 'PMC',
#   'title': 'Discovery and Genomic Characterization of a Novel Bat Sapovirus '
#            'with Unusual Genomic Features and Phylogenetic Position',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3325917/',
#   'who_covidence_id': None}]

# %%
documents=search(es, es_index="covid",
    query={
          "query": {
            "match_phrase":{"abstract":"biological diversity"}
          }
        })
print("Retrieved documents:")
pprint.pprint(documents)
# Out:
# Retrieved documents:
# [{'abstract': 'Horizontal DNA transfer is an important factor of evolution and '
#               'participates in biological diversity. Unfortunately, the '
#               'location and length of horizontal transfers (HTs) are known for '
#               'very few species. The usage of short oligonucleotides in a '
#               'sequence (the so-called genomic signature) has been shown to be '
#               'species-specific even in DNA fragments as short as 1 kb. The '
#               'genomic signature is therefore proposed as a tool to detect '
#               'HTs. Since DNA transfers originate from species with a '
#               'signature different from those of the recipient species, the '
#               'analysis of local variations of signature along recipient '
#               'genome may allow for detecting exogenous DNA. The strategy '
#               'consists in (i) scanning the genome with a sliding window, and '
#               'calculating the corresponding local signature (ii) evaluating '
#               'its deviation from the signature of the whole genome and (iii) '
#               'looking for similar signatures in a database of genomic '
#               'signatures. A total of 22 prokaryote genomes are analyzed in '
#               'this way. It has been observed that atypical regions make up '
#               '∼6% of each genome on the average. Most of the claimed HTs as '
#               'well as new ones are detected. The origin of putative DNA '
#               'transfers is looked for among ∼12 000 species. Donor species '
#               'are proposed and sometimes strongly suggested, considering '
#               'similarity of signatures. Among the species studied, Bacillus '
#               'subtilis, Haemophilus Influenzae and Escherichia coli are '
#               'investigated by many authors and give the opportunity to '
#               'perform a thorough comparison of most of the bioinformatics '
#               'methods used to detect HTs.',
#   'arxiv_id': None,
#   'authors': 'Dufraigne, Christine; Fertil, Bernard; Lespinats, Sylvain; '
#              'Giron, Alain; Deschavanne, Patrick',
#   'cord_uid': 'yba7mdtb',
#   'doi': '10.1093/nar/gni004',
#   'journal': 'Nucleic Acids Res',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/f1d1b9694aa43c837d9b758cb2d45d8a24d293e3.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC546175.xml.json',
#   'pmcid': 'PMC546175',
#   'pr_abstract': ['dna important factor evolution',
#                   'hts specie',
#                   'short oligonucleotides sequence genomic signature specie',
#                   'genomic signature tool hts',
#                   'dna transfer specie different recipient specie analysis '
#                   'local variation signature recipient genome dna',
#                   'strategy genome sliding window deviation signature whole '
#                   'genome database',
#                   'genome analyzed way',
#                   'observed atypical region genome average',
#                   'hts new one',
#                   'origin putative dna transfer specie',
#                   'specie similarity signature',
#                   'specie studied bacillus subtilis haemophilus many author '
#                   'thorough comparison bioinformatics method hts',
#                   'genome',
#                   'specie proposed',
#                   'dna',
#                   'genome',
#                   'short genomic dna short',
#                   'specie',
#                   'dna specie',
#                   'genomic proposed tool detect',
#                   'dna specie specie local genome dna',
#                   'specie detect',
#                   'strategy genome local whole genome database genomic',
#                   ''],
#   'pr_title': ['detection characterization horizontal transfer prokaryote '
#                'using genomic signature'],
#   'publish_time': '2005-01-13',
#   'pubmed_id': '15653627',
#   's2_id': None,
#   'sha': 'f1d1b9694aa43c837d9b758cb2d45d8a24d293e3',
#   'source_x': 'PMC',
#   'title': 'Detection and characterization of horizontal transfers in '
#            'prokaryotes using genomic signature',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC546175/',
#   'who_covidence_id': None},
#  {'abstract': 'Sapovirus is a genus of caliciviruses that are known to cause '
#               'enteric disease in humans and animals. There is considerable '
#               'genetic diversity among the sapoviruses, which are classified '
#               'into different genogroups based on phylogenetic analysis of the '
#               'full-length capsid protein sequence. While several mammalian '
#               'species, including humans, pigs, minks, and dogs, have been '
#               'identified as animal hosts for sapoviruses, there were no '
#               'reports of sapoviruses in bats in spite of their biological '
#               'diversity. In this report, we present the results of a targeted '
#               'surveillance study in different bat species in Hong Kong. Five '
#               'of the 321 specimens from the bat species, Hipposideros pomona, '
#               'were found to be positive for sapoviruses by RT-PCR. Complete '
#               'or nearly full-length genome sequences of approximately 7.7 kb '
#               'in length were obtained for three strains, which showed similar '
#               'organization of the genome compared to other sapoviruses. '
#               'Interestingly, they possess many genomic features atypical of '
#               'most sapoviruses, like high G+C content and minimal CpG '
#               'suppression. Phylogenetic analysis of the viral proteins '
#               'suggested that the bat sapovirus descended from an ancestral '
#               'sapovirus lineage and is most closely related to the porcine '
#               'sapoviruses. Codon usage analysis showed that the bat sapovirus '
#               'genome has greater codon usage bias relative to other sapovirus '
#               'genomes. In summary, we report the discovery and genomic '
#               'characterization of the first bat calicivirus, which appears to '
#               'have evolved under different conditions after early divergence '
#               'from other sapovirus lineages.',
#   'arxiv_id': None,
#   'authors': 'Tse, Herman; Chan, Wan-Mui; Li, Kenneth S. M.; Lau, Susanna K. '
#              'P.; Woo, Patrick C. Y.; Yuen, Kwok-Yung',
#   'cord_uid': 'alyn1i00',
#   'doi': '10.1371/journal.pone.0034987',
#   'journal': 'PLoS One',
#   'license': 'cc-by',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/dbf7ea2d45fff41a73853c26e5fca9862fd0edcc.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC3325917.xml.json',
#   'pmcid': 'PMC3325917',
#   'pr_abstract': ['sapovirus genus caliciviruses cause enteric disease human '
#                   'animal',
#                   'considerable genetic diversity sapoviruses classified '
#                   'different genogroups based phylogenetic analysis full '
#                   'length capsid protein sequence',
#                   'several mammalian specie human mink dog animal host '
#                   'sapoviruses report sapoviruses bat biological diversity',
#                   'surveillance study specie hong kong',
#                   'specie positive sapoviruses',
#                   'full length genome sequence strain similar organization '
#                   'genome sapoviruses',
#                   'many genomic feature atypical sapoviruses',
#                   'phylogenetic analysis viral protein bat sapovirus ancestral '
#                   'sapovirus lineage closely related porcine sapoviruses',
#                   'codon usage analysis bat sapovirus genome greater codon '
#                   'usage bias relative sapovirus genome',
#                   'summary report discovery genomic characterization first bat '
#                   'calicivirus different condition early divergence sapovirus '
#                   'lineage',
#                   'specie human report',
#                   'full length genome sequence strain genome',
#                   'codon usage genome codon usage genome',
#                   'different phylogenetic analysis full length',
#                   'cause human animal',
#                   'report different specie hong kong',
#                   'phylogenetic analysis viral protein',
#                   'genomic',
#                   'report genomic different',
#                   'specie'],
#   'pr_title': ['discovery genomic characterization novel bat sapovirus unusual '
#                'genomic feature phylogenetic position'],
#   'publish_time': '2012-04-13',
#   'pubmed_id': '22514697',
#   's2_id': None,
#   'sha': 'dbf7ea2d45fff41a73853c26e5fca9862fd0edcc',
#   'source_x': 'PMC',
#   'title': 'Discovery and Genomic Characterization of a Novel Bat Sapovirus '
#            'with Unusual Genomic Features and Phylogenetic Position',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3325917/',
#   'who_covidence_id': None}]

# %%
documents=search(es, es_index="covid",
    query={
          "query": {
            "match_all":{}
          }
        })
print("Retrieved documents:")
pprint.pprint(documents)
# Out:
# Retrieved documents:
# [{'abstract': 'Nidovirus subgenomic mRNAs contain a leader sequence derived '
#               'from the 5′ end of the genome fused to different sequences '
#               '(‘bodies’) derived from the 3′ end. Their generation involves a '
#               'unique mechanism of discontinuous subgenomic RNA synthesis that '
#               'resembles copy-choice RNA recombination. During this process, '
#               'the nascent RNA strand is transferred from one site in the '
#               'template to another, during either plus or minus strand '
#               'synthesis, to yield subgenomic RNA molecules. Central to this '
#               'process are transcription-regulating sequences (TRSs), which '
#               'are present at both template sites and ensure the fidelity of '
#               'strand transfer. Here we present results of a comprehensive '
#               'co-variation mutagenesis study of equine arteritis virus TRSs, '
#               'demonstrating that discontinuous RNA synthesis depends not only '
#               'on base pairing between sense leader TRS and antisense body '
#               'TRS, but also on the primary sequence of the body TRS. While '
#               'the leader TRS merely plays a targeting role for strand '
#               'transfer, the body TRS fulfils multiple functions. The '
#               'sequences of mRNA leader–body junctions of TRS mutants strongly '
#               'suggested that the discontinuous step occurs during minus '
#               'strand synthesis.',
#   'arxiv_id': None,
#   'authors': 'Pasternak, Alexander O.; van den Born, Erwin; Spaan, Willy J.M.; '
#              'Snijder, Eric J.',
#   'cord_uid': 'zjufx4fo',
#   'doi': '10.1093/emboj/20.24.7220',
#   'journal': 'The EMBO Journal',
#   'license': 'green-oa',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/b2897e1277f56641193a6db73825f707eed3e4c9.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC125340.xml.json',
#   'pmcid': 'PMC125340',
#   'pr_abstract': ['nidovirus subgenomic mrna leader sequence end genome '
#                   'different sequence body end',
#                   'unique mechanism discontinuous subgenomic rna synthesis rna',
#                   'process rna site strand synthesis subgenomic rna molecule',
#                   'central process transcription sequence trss present '
#                   'template site',
#                   'present result comprehensive variation mutagenesis study '
#                   'equine arteritis virus trss discontinuous rna synthesis '
#                   'base pairing sense leader trs antisense body primary '
#                   'sequence body',
#                   'role strand transfer body trs fulfils multiple function',
#                   'sequence mrna leader body junction trs mutant discontinuous '
#                   'step strand synthesis',
#                   'process rna strand site strand synthesis rna',
#                   'rna synthesis rna recombination',
#                   'process sequence present strand transfer',
#                   'sequence derived end sequence derived end',
#                   'sequence strand synthesis',
#                   'present rna synthesis sequence',
#                   'strand transfer'],
#   'pr_title': ['sequence requirement rna strand transfer nidovirus '
#                'discontinuous subgenomic rna synthesis'],
#   'publish_time': '2001-12-17',
#   'pubmed_id': '11742998',
#   's2_id': None,
#   'sha': 'b2897e1277f56641193a6db73825f707eed3e4c9',
#   'source_x': 'PMC',
#   'title': 'Sequence requirements for RNA strand transfer during nidovirus '
#            'discontinuous subgenomic RNA synthesis',
#   'url': 'http://europepmc.org/articles/pmc125340?pdf=render',
#   'who_covidence_id': None},
#  {'abstract': 'Recent evidence suggests that critically ill patients are able '
#               'to tolerate lower levels of haemoglobin than was previously '
#               'believed. It is our goal to show that transfusing to a level of '
#               '100 g/l does not improve mortality and other clinically '
#               'important outcomes in a critical care setting. Although many '
#               'questions remain, many laboratory and clinical studies, '
#               'including a recent randomized controlled trial (RCT), have '
#               'established that transfusing to normal haemoglobin '
#               'concentrations does not improve organ failure and mortality in '
#               'the critically ill patient. In addition, a restrictive '
#               'transfusion strategy will reduce exposure to allogeneic '
#               'transfusions, result in more efficient use of red blood cells '
#               '(RBCs), save blood overall, and decrease health care costs.',
#   'arxiv_id': None,
#   'authors': 'Alvarez, Gonzalo; Hébert, Paul C; Szick, Sharyn',
#   'cord_uid': '5yhe786e',
#   'doi': '10.1186/cc987',
#   'journal': 'Crit Care',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/3bb07ea10432f7738413dff9816809cc90f03f99.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC137267.xml.json',
#   'pmcid': 'PMC137267',
#   'pr_abstract': ['recent evidence critically ill patient lower level '
#                   'haemoglobin',
#                   'goal show transfusing level mortality outcome critical care '
#                   'setting',
#                   'many question many laboratory clinical study recent '
#                   'randomized controlled trial rct transfusing normal '
#                   'haemoglobin concentration organ failure mortality',
#                   'addition strategy exposure transfusion blood cell blood '
#                   'overall decrease health care cost',
#                   'many remain many clinical study recent randomized '
#                   'controlled trial established normal concentration improve '
#                   'organ failure mortality critically ill',
#                   'recent critically ill able lower',
#                   'addition strategy reduce exposure blood cell blood health '
#                   'care',
#                   'improve mortality outcome critical care'],
#   'pr_title': ['debate transfusing normal haemoglobin level improve outcome'],
#   'publish_time': '2001-03-08',
#   'pubmed_id': '11299062',
#   's2_id': None,
#   'sha': '3bb07ea10432f7738413dff9816809cc90f03f99',
#   'source_x': 'PMC',
#   'title': 'Debate: Transfusing to normal haemoglobin levels will not improve '
#            'outcome',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC137267/',
#   'who_covidence_id': None},
#  {'abstract': 'The 21st International Symposium on Intensive Care and '
#               'Emergency Medicine was dominated by the results of recent '
#               'clinical trials in sepsis and acute respiratory distress '
#               'syndrome (ARDS). The promise of extracorporeal liver '
#               'replacement therapy and noninvasive ventilation were other '
#               'areas of interest. Ethical issues also received attention. '
#               "Overall, the 'state of the art' lectures, pro/con debates, "
#               'seminars and tutorials were of a high standard. The meeting was '
#               'marked by a sense of renewed enthusiasm that positive progress '
#               'is occurring in intensive care medicine.',
#   'arxiv_id': None,
#   'authors': 'Ball, Jonathan; Venn, Richard',
#   'cord_uid': '8zchiykl',
#   'doi': '10.1186/cc1013',
#   'journal': 'Crit Care',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/5806726a24dc91de3954001effbdffd7a82d54e2.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC137274.xml.json',
#   'pmcid': 'PMC137274',
#   'pr_abstract': ['international symposium intensive care emergency medicine '
#                   'result recent clinical trial sepsis acute respiratory '
#                   'distress syndrome ards',
#                   'extracorporeal liver replacement therapy noninvasive '
#                   'ventilation area',
#                   'ethical issue attention',
#                   'overall state art lecture pro con debate seminar tutorial',
#                   'meeting sense renewed enthusiasm positive progress '
#                   'intensive care medicine',
#                   'overall state standard',
#                   'international intensive care emergency medicine result '
#                   'recent clinical trial sepsis acute respiratory distress '
#                   'syndrome ards',
#                   'positive intensive care medicine',
#                   'liver therapy ventilation area interest',
#                   'received'],
#   'pr_title': ['international symposium intensive care emergency medicine '
#                'brussels belgium march'],
#   'publish_time': '2001-05-02',
#   'pubmed_id': '11353930',
#   's2_id': None,
#   'sha': '5806726a24dc91de3954001effbdffd7a82d54e2',
#   'source_x': 'PMC',
#   'title': 'The 21st International Symposium on Intensive Care and Emergency '
#            'Medicine, Brussels, Belgium, 20-23 March 2001',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC137274/',
#   'who_covidence_id': None},
#  {'abstract': 'Heme oxygenase-1 (HO-1), an inducible stress protein, confers '
#               'cytoprotection against oxidative stress in vitro and in vivo. '
#               'In addition to its physiological role in heme degradation, HO-1 '
#               'may influence a number of cellular processes, including growth, '
#               'inflammation, and apoptosis. By virtue of anti-inflammatory '
#               'effects, HO-1 limits tissue damage in response to '
#               'proinflammatory stimuli and prevents allograft rejection after '
#               'transplantation. The transcriptional upregulation of HO-1 '
#               'responds to many agents, such as hypoxia, bacterial '
#               'lipopolysaccharide, and reactive oxygen/nitrogen species. HO-1 '
#               'and its constitutively expressed isozyme, heme oxygenase-2, '
#               'catalyze the rate-limiting step in the conversion of heme to '
#               'its metabolites, bilirubin IXα, ferrous iron, and carbon '
#               'monoxide (CO). The mechanisms by which HO-1 provides protection '
#               'most likely involve its enzymatic reaction products. '
#               'Remarkably, administration of CO at low concentrations can '
#               'substitute for HO-1 with respect to anti-inflammatory and '
#               'anti-apoptotic effects, suggesting a role for CO as a key '
#               'mediator of HO-1 function. Chronic, low-level, exogenous '
#               'exposure to CO from cigarette smoking contributes to the '
#               'importance of CO in pulmonary medicine. The implications of the '
#               'HO-1/CO system in pulmonary diseases will be discussed in this '
#               'review, with an emphasis on inflammatory states.',
#   'arxiv_id': None,
#   'authors': 'Slebos, Dirk-Jan; Ryter, Stefan W; Choi, Augustine MK',
#   'cord_uid': '8qnrcgnk',
#   'doi': '10.1186/1465-9921-4-7',
#   'journal': 'Respir Res',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/faaf1022ccfe93b032c5608097a53543ba24aedb.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC193681.xml.json',
#   'pmcid': 'PMC193681',
#   'pr_abstract': ['heme oxygenase inducible stress protein cytoprotection '
#                   'oxidative stress',
#                   'addition role heme degradation number cellular process '
#                   'growth inflammation apoptosis',
#                   'anti inflammatory effect tissue damage response '
#                   'proinflammatory stimulus prevents transplantation',
#                   'many agent bacterial lipopolysaccharide reactive oxygen '
#                   'nitrogen specie',
#                   '',
#                   'mechanism protection enzymatic reaction product',
#                   'low concentration anti inflammatory anti apoptotic effect '
#                   'role function',
#                   'exposure importance',
#                   'system disease review emphasis inflammatory state',
#                   'implication system pulmonary disease state',
#                   'transcriptional reactive oxygen',
#                   'mechanism protection reaction',
#                   'low exposure importance pulmonary medicine',
#                   'anti inflammatory effect damage',
#                   'addition role degradation influence growth inflammation '
#                   'apoptosis',
#                   'stress oxidative stress vitro vivo',
#                   'administration low concentration anti inflammatory effect '
#                   'role function',
#                   'step'],
#   'pr_title': ['heme oxygenase carbon monoxide pulmonary medicine'],
#   'publish_time': '2003-08-07',
#   'pubmed_id': '12964953',
#   's2_id': None,
#   'sha': 'faaf1022ccfe93b032c5608097a53543ba24aedb',
#   'source_x': 'PMC',
#   'title': 'Heme oxygenase-1 and carbon monoxide in pulmonary medicine',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC193681/',
#   'who_covidence_id': None},
#  {'abstract': 'This report describes the design and implementation of the '
#               'Real-time Outbreak and Disease Surveillance (RODS) system, a '
#               'computer-based public health surveillance system for early '
#               'detection of disease outbreaks. Hospitals send RODS data from '
#               'clinical encounters over virtual private networks and leased '
#               'lines using the Health Level 7 (HL7) message protocol. The data '
#               'are sent in real time. RODS automatically classifies the '
#               'registration chief complaint from the visit into one of seven '
#               'syndrome categories using Bayesian classifiers. It stores the '
#               'data in a relational database, aggregates the data for analysis '
#               'using data warehousing techniques, applies univariate and '
#               'multivariate statistical detection algorithms to the data, and '
#               'alerts users of when the algorithms identify anomalous patterns '
#               'in the syndrome counts. RODS also has a Web-based user '
#               'interface that supports temporal and spatial analyses. RODS '
#               'processes sales of over-the-counter health care products in a '
#               'similar manner but receives such data in batch mode on a daily '
#               'basis. RODS was used during the 2002 Winter Olympics and '
#               'currently operates in two states—Pennsylvania and Utah. It has '
#               'been and continues to be a resource for implementing, '
#               'evaluating, and applying new methods of public health '
#               'surveillance.',
#   'arxiv_id': None,
#   'authors': 'Tsui, Fu-Chiang; Espino, Jeremy U.; Dato, Virginia M.; '
#              'Gesteland, Per H.; Hutman, Judith; Wagner, Michael M.',
#   'cord_uid': 'jg13scgo',
#   'doi': '10.1197/jamia.m1345',
#   'journal': 'Journal of the American Medical Informatics Association',
#   'license': 'bronze-oa',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/5b44feca5d6ffaaeb66501fa84cc6dd44d06660a.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC212776.xml.json',
#   'pmcid': 'PMC212776',
#   'pr_abstract': ['design real time surveillance rod system public health '
#                   'surveillance system detection',
#                   'hospital rod data clinical encounter virtual private '
#                   'network health',
#                   'data real time',
#                   'rod registration chief complaint visit',
#                   'data database data data warehousing technique multivariate '
#                   'statistical detection algorithm data user anomalous pattern '
#                   'syndrome',
#                   'rod also web based user interface analysis',
#                   'rod sale counter health care product similar manner data '
#                   'batch mode basis',
#                   'rod winter olympics state',
#                   'public health surveillance',
#                   'design real time system public health detection',
#                   'data database data data detection data user syndrome',
#                   'syndrome',
#                   'analysis',
#                   'state',
#                   'data basis',
#                   'public health surveillance',
#                   'hospital data health'],
#   'pr_title': ['technical description rod real time public health surveillance '
#                'system'],
#   'publish_time': '2003-09-01',
#   'pubmed_id': '12807803',
#   's2_id': None,
#   'sha': '5b44feca5d6ffaaeb66501fa84cc6dd44d06660a',
#   'source_x': 'PMC',
#   'title': 'Technical Description of RODS: A Real-time Public Health '
#            'Surveillance System',
#   'url': 'https://academic.oup.com/jamia/article-pdf/10/5/399/2352016/10-5-399.pdf',
#   'who_covidence_id': None},
#  {'abstract': 'Regulation of ornithine decarboxylase in vertebrates involves a '
#               'negative feedback mechanism requiring the protein antizyme. '
#               'Here we show that a similar mechanism exists in the fission '
#               'yeast Schizosaccharomyces pombe. The expression of mammalian '
#               'antizyme genes requires a specific +1 translational frameshift. '
#               'The efficiency of the frameshift event reflects cellular '
#               'polyamine levels creating the autoregulatory feedback loop. As '
#               'shown here, the yeast antizyme gene and several newly '
#               'identified antizyme genes from different nematodes also require '
#               'a ribosomal frameshift event for their expression. Twelve '
#               'nucleotides around the frameshift site are identical between '
#               'S.pombe and the mammalian counterparts. The core element for '
#               'this frameshifting is likely to have been present in the last '
#               'common ancestor of yeast, nematodes and mammals.',
#   'arxiv_id': None,
#   'authors': 'Ivanov, Ivaylo P.; Matsufuji, Senya; Murakami, Yasuko; '
#              'Gesteland, Raymond F.; Atkins, John F.',
#   'cord_uid': '5tkvsudh',
#   'doi': '10.1093/emboj/19.8.1907',
#   'journal': 'EMBO J',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC302018.xml.json',
#   'pmcid': 'PMC302018',
#   'pr_abstract': ['regulation ornithine decarboxylase vertebrate negative '
#                   'feedback mechanism protein antizyme',
#                   'similar mechanism yeast',
#                   'expression gene',
#                   'efficiency cellular polyamine level autoregulatory feedback '
#                   'loop',
#                   'yeast antizyme gene several newly identified antizyme gene '
#                   'different nematode expression',
#                   'nucleotide frameshift site identical pombe mammalian '
#                   'counterpart',
#                   'core element frameshifting last common ancestor yeast '
#                   'mammal',
#                   'regulation negative mechanism requiring',
#                   'mechanism yeast',
#                   'mammalian',
#                   'efficiency loop',
#                   'expression mammalian gene requires',
#                   'yeast newly identified gene require ribosomal expression',
#                   'core frameshifting yeast'],
#   'pr_title': ['conservation polyamine regulation translational frameshifting '
#                'yeast mammal'],
#   'publish_time': '2000-04-17',
#   'pubmed_id': '10775274',
#   's2_id': None,
#   'sha': '9d4e3e8eb092d5ed282d0aa4aadcaa8b7165b5e9',
#   'source_x': 'PMC',
#   'title': 'Conservation of polyamine regulation by translational '
#            'frameshifting from yeast to mammals',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302018/',
#   'who_covidence_id': None},
#  {'abstract': 'Heterogeneous nuclear ribonucleoprotein (hnRNP A1) is involved '
#               'in pre-mRNA splicing in the nucleus and translational '
#               'regulation in the cytoplasm. In the present study, we '
#               'demonstrate that hnRNP A1 also participates in the '
#               'transcription and replication of a cytoplasmic RNA virus, mouse '
#               'hepatitis virus (MHV). Overexpression of hnRNP A1 accelerated '
#               'the kinetics of viral RNA synthesis, whereas the expression in '
#               'the cytoplasm of a dominant-negative hnRNP A1 mutant that lacks '
#               'the nuclear transport domain significantly delayed it. The '
#               'hnRNP A1 mutant caused a global inhibition of viral mRNA '
#               'transcription and genomic replication, and also a preferential '
#               'inhibition of the replication of defective-interfering RNAs. '
#               'Similar to the wild-type hnRNP A1, the hnRNP A1 mutant '
#               'complexed with an MHV polymerase gene product, the nucleocapsid '
#               'protein and the viral RNA. However, in contrast to the '
#               'wild-type hnRNP A1, the mutant protein failed to bind a 250 kDa '
#               'cellular protein, suggesting that the recruitment of cellular '
#               'proteins by hnRNP A1 is important for MHV RNA synthesis. Our '
#               'findings establish the importance of cellular factors in viral '
#               'RNA-dependent RNA synthesis.',
#   'arxiv_id': None,
#   'authors': 'Shi, Stephanie T.; Huang, Peiyong; Li, Hsin-Pai; Lai, Michael '
#              'M.C.',
#   'cord_uid': '6lvn10f4',
#   'doi': '10.1093/emboj/19.17.4701',
#   'journal': 'The EMBO Journal',
#   'license': 'green-oa',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/14e0cac6e86d62859e6c9f1351ab67466d89e5b3.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC302072.xml.json',
#   'pmcid': 'PMC302072',
#   'pr_abstract': ['heterogeneous nuclear ribonucleoprotein hnrnp mrna nucleus '
#                   'translational regulation',
#                   'present study demonstrate hnrnp transcription replication '
#                   'cytoplasmic rna virus mouse hepatitis virus',
#                   'overexpression hnrnp kinetics viral rna synthesis '
#                   'expression dominant negative hnrnp mutant nuclear transport '
#                   'domain',
#                   'hnrnp mutant global inhibition viral mrna transcription '
#                   'genomic replication preferential inhibition replication '
#                   'defective interfering rna',
#                   'similar wild type hnrnp hnrnp mutant gene protein viral rna',
#                   'wild type hnrnp mutant protein bind kda cellular protein '
#                   'recruitment cellular protein hnrnp',
#                   'importance cellular factor viral rna dependent rna '
#                   'synthesis',
#                   'wild type mutant gene protein viral rna',
#                   'viral rna expression dominant negative mutant nuclear',
#                   'nuclear mrna',
#                   'mutant inhibition mrna transcription replication inhibition '
#                   'replication',
#                   'wild type mutant protein cellular protein rna synthesis',
#                   'cellular viral rna rna synthesis',
#                   'present study demonstrate transcription replication'],
#   'pr_title': ['heterogeneous nuclear ribonucleoprotein regulates rna '
#                'synthesis cytoplasmic virus'],
#   'publish_time': '2000-09-01',
#   'pubmed_id': '10970862',
#   's2_id': None,
#   'sha': '14e0cac6e86d62859e6c9f1351ab67466d89e5b3',
#   'source_x': 'PMC',
#   'title': 'Heterogeneous nuclear ribonucleoprotein A1 regulates RNA synthesis '
#            'of a cytoplasmic virus',
#   'url': 'http://europepmc.org/articles/pmc302072?pdf=render',
#   'who_covidence_id': None},
#  {'abstract': 'The UBA domain is a conserved sequence motif among '
#               'polyubiquitin binding proteins. For the first time, we '
#               'demonstrate a systematic, high throughput approach to '
#               'identification of UBA domain-interacting proteins from a '
#               'proteome-wide perspective. Using the rabbit reticulocyte lysate '
#               'in vitro expression cloning system, we have successfully '
#               'identified eleven proteins that interact with p62’s UBA domain, '
#               'and the majority of the eleven proteins are associated with '
#               'neurodegenerative disorders, such as Alzheimer’s disease. '
#               'Therefore, p62 may play a novel regulatory role through its UBA '
#               'domain. Our approach provides an easy route to the '
#               'characterization of UBA domain interacting proteins and its '
#               'application will unfold the important roles that the UBA domain '
#               'plays.',
#   'arxiv_id': None,
#   'authors': 'Pridgeon, Julia W.; Geetha, Thangiah; Wooten, Marie W.',
#   'cord_uid': 'tvxpckxo',
#   'doi': '10.1251/bpo66',
#   'journal': 'Biol Proced Online',
#   'license': 'no-cc',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/d09b79026117ec9faebba46a8d13aa9b23ec751e.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC302190.xml.json',
#   'pmcid': 'PMC302190',
#   'pr_abstract': ['uba domain',
#                   'first time uba domain protein',
#                   'eleven protein eleven protein',
#                   'uba domain',
#                   'approach uba domain',
#                   'approach uba domain protein uba domain',
#                   'protein uba domain protein',
#                   'first time approach uba domain protein',
#                   'uba domain protein',
#                   'uba domain'],
#   'pr_title': ['method identify uba domain interacting protein'],
#   'publish_time': '2003-12-12',
#   'pubmed_id': '14702098',
#   's2_id': None,
#   'sha': 'd09b79026117ec9faebba46a8d13aa9b23ec751e',
#   'source_x': 'PMC',
#   'title': "A Method to Identify p62's UBA Domain Interacting Proteins",
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302190/',
#   'who_covidence_id': None},
#  {'abstract': 'We examined the role of the microtubule cytoskeleton during '
#               'vaccinia virus infection. We found that newly assembled virus '
#               'particles accumulate in the vicinity of the '
#               'microtubule-organizing centre in a microtubule- and '
#               'dynein–dynactin complex-dependent fashion. Microtubules are '
#               'required for efficient intracellular mature virus (IMV) '
#               'formation and are essential for intracellular enveloped virus '
#               '(IEV) assembly. As infection proceeds, the microtubule '
#               'cytoskeleton becomes dramatically reorganized in a fashion '
#               'reminiscent of overexpression of microtubule-associated '
#               'proteins (MAPs). Consistent with this, we report that the '
#               'vaccinia proteins A10L and L4R have MAP-like properties and '
#               'mediate direct binding of viral cores to microtubules in vitro. '
#               'In addition, vaccinia infection also results in severe '
#               'reduction of proteins at the centrosome and loss of centrosomal '
#               'microtubule nucleation efficiency. This represents the first '
#               'example of viral-induced disruption of centrosome function. '
#               'Further studies with vaccinia will provide insights into the '
#               'role of microtubules during viral pathogenesis and regulation '
#               'of centrosome function.',
#   'arxiv_id': None,
#   'authors': 'Ploubidou, Aspasia; Moreau, Violaine; Ashman, Keith; Reckmann, '
#              'Inge; González, Cayetano; Way, Michael',
#   'cord_uid': 'mcuixluu',
#   'doi': '10.1093/emboj/19.15.3932',
#   'journal': 'The EMBO Journal',
#   'license': 'green-oa',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/44102e3e69e70ad2a73e753133283334ce1f8736.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC306617.xml.json',
#   'pmcid': 'PMC306617',
#   'pr_abstract': ['examined role microtubule cytoskeleton vaccinia virus '
#                   'infection',
#                   'newly assembled virus particle',
#                   'microtubule efficient intracellular mature virus imv '
#                   'formation essential intracellular virus assembly',
#                   'infection microtubule cytoskeleton fashion reminiscent '
#                   'overexpression microtubule associated protein',
#                   'consistent report vaccinia protein map property direct '
#                   'binding viral core microtubule',
#                   'addition vaccinia infection severe reduction protein loss '
#                   'efficiency',
#                   'first example function',
#                   'study vaccinia insight role microtubule viral pathogenesis '
#                   'regulation centrosome function',
#                   'role virus infection',
#                   'infection protein',
#                   'intracellular virus intracellular virus',
#                   'newly virus particle',
#                   'consistent protein map property direct viral',
#                   'represents first viral function',
#                   'infection reduction protein loss efficiency',
#                   'study insight role viral function'],
#   'pr_title': ['vaccinia virus infection disrupts microtubule organization '
#                'centrosome function'],
#   'publish_time': '2000-08-01',
#   'pubmed_id': '10921875',
#   's2_id': None,
#   'sha': '44102e3e69e70ad2a73e753133283334ce1f8736',
#   'source_x': 'PMC',
#   'title': 'Vaccinia virus infection disrupts microtubule organization and '
#            'centrosome function',
#   'url': 'http://europepmc.org/articles/pmc306617?pdf=render',
#   'who_covidence_id': None},
#  {'abstract': 'BACKGROUND: The present study aimed to provide information on '
#               'awareness of the attributable fraction of cancer causes among '
#               'the Japanese general population. METHODS: A nationwide '
#               'representative sample of 2,000 Japanese aged 20 or older was '
#               'asked about their perception and level of concern about various '
#               'environmental and genetic risk factors in relation to cancer '
#               'prevention, as a part of an Omnibus Survey. Interviews were '
#               'conducted with 1,355 subjects (609 men and 746 women). RESULTS: '
#               'Among 12 risk factor candidates, the attributable fraction of '
#               'cancer-causing viral and bacterial infection was considered '
#               'highest (51%), followed by that of tobacco smoking (43%), '
#               'stress (39%), and endocrine-disrupting chemicals (37%). On the '
#               'other hand, the attributable fractions of cancer by charred '
#               'fish and meat (21%) and alcohol drinking (22%) were considered '
#               'low compared with other risk factor candidates. For most risk '
#               'factors, attributable fraction responses were higher in women '
#               'than in men. As a whole, the subjects tended to respond with '
#               'higher values than those estimated by epidemiologic evidence in '
#               'the West. The attributable fraction of cancer speculated to be '
#               'genetically determined was 32%, while 36% of cancer was '
#               'considered preventable by improving lifestyle. CONCLUSION: Our '
#               'results suggest that awareness of the attributable fraction of '
#               'cancer causes in the Japanese general population tends to be '
#               'dominated by cancer-causing infection, occupational exposure, '
#               'air pollution and food additives rather than major lifestyle '
#               'factors such as diet.',
#   'arxiv_id': None,
#   'authors': 'Inoue, Manami; Iwasaki, Motoki; Otani, Tetsuya; Sasazuki, '
#              'Shizuka; Tsugane, Shoichiro',
#   'cord_uid': 'bnnl700a',
#   'doi': '10.1186/1471-2458-6-2',
#   'journal': 'BMC Public Health',
#   'license': 'cc-by',
#   'mag_id': None,
#   'pdf_json_files': 'document_parses/pdf_json/a78fd1b34372e1e54bf2a192d04aa36670cea307.json',
#   'pmc_json_files': 'document_parses/pmc_json/PMC1351169.xml.json',
#   'pmcid': 'PMC1351169',
#   'pr_abstract': ['background present study information awareness attributable '
#                   'fraction cancer japanese general population',
#                   'sample perception level concern risk factor prevention part',
#                   'subject men woman',
#                   'risk factor candidate attributable fraction cancer viral '
#                   'bacterial infection tobacco smoking stress endocrine',
#                   'hand fish meat alcohol drinking risk factor candidate',
#                   'risk factor response woman',
#                   'higher value estimated epidemiologic evidence',
#                   'attributable fraction cancer genetically determined cancer',
#                   'awareness attributable fraction cancer japanese general '
#                   'population infection exposure major lifestyle factor diet',
#                   'information cancer cause general population',
#                   'hand cancer considered risk factor candidate',
#                   'risk factor response higher woman',
#                   'risk factor candidate cancer infection considered',
#                   'woman',
#                   'higher',
#                   'cancer cause general population cancer infection exposure',
#                   'cancer cancer considered',
#                   'sample risk factor cancer prevention part'],
#   'pr_title': ['public awareness risk factor cancer among japanese general '
#                'population population based survey'],
#   'publish_time': '2006-01-10',
#   'pubmed_id': '16403223',
#   's2_id': None,
#   'sha': 'a78fd1b34372e1e54bf2a192d04aa36670cea307',
#   'source_x': 'PMC',
#   'title': 'Public awareness of risk factors for cancer among the Japanese '
#            'general population: A population-based survey',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1351169/',
#   'who_covidence_id': None}]
